# %% [markdown]
# 导入数据

# %%
import json

DATA_INFO_PATH = r"C:/Users/yyy/Desktop/course project/BCIC2A/dataset_info_fixed.json"

with open(DATA_INFO_PATH, "r", encoding="utf-8") as f:
    info = json.load(f)

category_list = info["dataset"]["category_list"]
channels = info["dataset"]["channels"]
target_sampling_rate = info["processing"]["target_sampling_rate"]
window_sec = info["processing"]["window_sec"]

print("=== Dataset Intro ===")
print("Categories:", category_list)
print("Channels (count):", len(channels))
print("Channels:", channels)
print("Target Sampling Rate (Hz):", target_sampling_rate)
print("Window Size (sec):", window_sec)
# Out:
# === Dataset Intro ===
# Categories: ['left', 'right', 'foot', 'tongue']
# Channels (count): 22
# Channels: ['FZ', 'FC3', 'FC1', 'FCZ', 'FC2', 'FC4', 'C5', 'C3', 'C1', 'CZ', 'C2', 'C4', 'C6', 'CP3', 'CP1', 'CPZ', 'CP2', 'CP4', 'P1', 'PZ', 'P2', 'POZ']
# Target Sampling Rate (Hz): 200.0
# Window Size (sec): 1.0

# %% [markdown]
# ## 1) 设定数据路径并检查数据形状
# 这一格会选择数据集（`DATA_NAME`），并读取 `train/val/test` 的基本信息，先确认维度是否符合预期。

# %%
import h5py
import numpy as np
DATA_NAME = "BCIC2A"
INDEX_PATH_TRAIN = r"C:/Users/yyy/Desktop/course project/BCIC2A/train.h5"
INDEX_PATH_VAL = r"C:/Users/yyy/Desktop/course project/BCIC2A/val.h5"
INDEX_PATH_TEST = r"C:/Users/yyy/Desktop/course project/BCIC2A/test_x_only.h5"

with h5py.File(INDEX_PATH_TRAIN, "r") as f:
    print("keys:", list(f.keys()))
    print("x dtype:", f["X"].dtype)
    print("x shape:", f["X"].shape)
    print("y dtype:", f["y"].dtype)
    print("y shape:", f["y"].shape)
    y = f["y"][()]
    print("unique:", np.unique(y))
    print(INDEX_PATH_TEST)
# Out:
# keys: ['X', 'y']
# x dtype: float32
# x shape: (720, 22, 800)
# y dtype: int64
# y shape: (720,)
# unique: [0 1 2 3]
# C:/Users/yyy/Desktop/course project/BCIC2A/test_x_only.h5

# %%
import os

print(os.path.exists(INDEX_PATH_TEST))
print(os.path.getsize(INDEX_PATH_TEST))
# Out:
# True
# 25346048

# %% [markdown]
# ## 模型：EEGNet
# EEGNet 的本质是一个“结构上受约束的 CNN”，通过“时间卷积 + 空间卷积（depthwise）+ 可分离卷积（separable）”分阶段提取 EEG 的时域、频域和空间特征。
#
# 卷积结构版本，利用时序与通道方向的局部模式，适合 EEG 信号特征提取。常用于作为baseline

# %%
import torch
import torch.nn as nn


class EEGNet(nn.Module):
    def __init__(
        self,
        chans,
        time_point=800,
        num_classes=4,
        f1=8,
        d=2,
        pk1=4,
        pk2=8,
        dp=0.5,
        max_norm1=1,
        norm=nn.Identity()
    ):
        super().__init__()

        f2 = f1 * d
        self.norm = norm

       # Temporal Convolution
        self.block1 = nn.Sequential(
            nn.Conv2d(
                1, f1,
                kernel_size=(1, 100),  # <--- 修改：从 64 改为 100
                padding=(0, 50),       # <--- 修改：从 32 改为 50
                bias=False
            ),
            nn.BatchNorm2d(f1)
        )

        # Depthwise Spatial Convolution
        self.block2 = nn.Sequential(
            nn.Conv2d(
                f1,
                d * f1,
                kernel_size=(chans, 1),
                groups=f1,
                bias=False
            ),
            nn.BatchNorm2d(d * f1),
            nn.ELU(),
            nn.AvgPool2d((1, pk1), stride=pk1),
            nn.Dropout(dp)
        )

        # Separable Convolution
        self.block3 = nn.Sequential(
            nn.Conv2d(
                d * f1,
                f2,
                kernel_size=(1, 16),
                groups=f2,
                padding=(0, 8),
                bias=False
            ),
            nn.Conv2d(
                f2,
                f2,
                kernel_size=1,
                bias=False
            ),
            nn.BatchNorm2d(f2),
            nn.ELU(),
            nn.AvgPool2d((1, pk2), stride=pk2),
            nn.Dropout(dp)
        )

        # Max norm
        self._apply_max_norm(self.block2[0], max_norm1)

        # 自动计算特征维度
        with torch.no_grad():
            dummy = torch.zeros(1, chans, time_point)  # (B, C, T)
            dummy = self._forward_features(dummy)
            self.embed_dim = dummy.shape[1]

        print("EEGNet embed_dim =", self.embed_dim)

        # 分类层
        self.classifier = nn.Linear(self.embed_dim, num_classes)

    def _apply_max_norm(self, layer, max_norm):
        for name, param in layer.named_parameters():
            if "weight" in name:
                param.data = torch.renorm(
                    param.data,
                    p=2,
                    dim=0,
                    maxnorm=max_norm
                )

    def _forward_features(self, x):
        """
        x: (B, C, T)
        """
        x = self.norm(x)

        # 如果输入单个样本 (C, T)
        if x.dim() == 2:
            x = x.unsqueeze(0)

        # (B, C, T) -> (B, 1, C, T)
        x = x.unsqueeze(1)

        x = self.block1(x)
        x = self.block2(x)
        x = self.block3(x)

        x = x.flatten(start_dim=1)
        return x

    def forward(self, x):
        x = self._forward_features(x)
        x = self.classifier(x)
        return x

# %% [markdown]
# ## 准备 DataLoader 并训练/验证
# 这一格完成数据加载、损失函数与优化器设置，然后执行训练循环并记录 `train/val` 指标与曲线。

# %%
import h5py
import copy
import random
import numpy as np
import torch
import torch.nn as nn
import matplotlib.pyplot as plt

from torch.utils.data import DataLoader
from TEST_DATASET import TrainDataset, TestDataset


# =====================================================
# 固定随机种子
# =====================================================
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)

set_seed(42)


# =====================================================
# Gaussian noise 增强
# =====================================================
def add_gaussian_noise(x, noise_std=0.02):
    """
    x shape: (B, C, T)
    """
    noise = torch.randn_like(x) * noise_std
    return x + noise


# =====================================================
# Channel dropout 增强
# =====================================================
def channel_dropout(x, drop_prob=0.05):
    """
    x shape: (B, C, T)
    随机丢弃部分 EEG 通道。
    """
    if drop_prob <= 0:
        return x

    mask = torch.rand(
        x.shape[0],
        x.shape[1],
        1,
        device=x.device
    ) > drop_prob

    return x * mask


# =====================================================
# Random crop：训练用
# =====================================================
def random_crop(x, crop_len=750):
    """
    x shape: (B, C, T)
    从 800 点随机裁成 750 点。
    """
    T = x.shape[-1]

    if T == crop_len:
        return x

    start = random.randint(0, T - crop_len)
    end = start + crop_len

    return x[:, :, start:end]


# =====================================================
# Crop TTA：验证 / 测试用
# =====================================================
def crop_tta_predict(model, x, crop_len=750, starts=[0, 25, 50]):
    """
    x shape: (B, C, T)
    对同一个样本取多个 crop，平均 logits。
    """
    logits_sum = 0

    for start in starts:

        end = start + crop_len
        x_crop = x[:, :, start:end]

        logits_sum += model(x_crop)

    return logits_sum / len(starts)


# =====================================================
# 参数
# =====================================================
CHANNELS = 22
CLASSES = 4

BATCH_SIZE = 32
EPOCHS = 1000

LR = 1e-3
WEIGHT_DECAY = 5e-4

PATIENCE = 60
MIN_DELTA = 0.001

MIN_LR = 1e-6

CROP_LEN = 750
CROP_STARTS = [0, 5, 10, 15, 20, 25, 30, 35, 40, 45, 50]  # 11 crops

NOISE_STD = 0.02
CHANNEL_DROP_PROB = 0.05


# =====================================================
# 数据
# =====================================================
train_ds = TrainDataset(INDEX_PATH_TRAIN)
val_ds = TrainDataset(INDEX_PATH_VAL)
test_ds = TestDataset(INDEX_PATH_TEST)


# =====================================================
# 标准化：只用 train 统计量
# 注意：先标准化 800 点，再在训练/验证时裁成 750 点
# =====================================================
mean = train_ds.x.mean(dim=(0, 2), keepdim=True)
std = train_ds.x.std(dim=(0, 2), keepdim=True) + 1e-6

train_ds.x = (train_ds.x - mean) / std
val_ds.x = (val_ds.x - mean) / std
test_ds.x = (test_ds.x - mean) / std


train_loader = DataLoader(
    train_ds,
    batch_size=BATCH_SIZE,
    shuffle=True,
    drop_last=False
)

val_loader = DataLoader(
    val_ds,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_loader = DataLoader(
    test_ds,
    batch_size=1,
    shuffle=False
)


# =====================================================
# 模型
# 注意：time_point 改成 750
# =====================================================
model = EEGNet(
    chans=CHANNELS,
    time_point=CROP_LEN,
    num_classes=CLASSES,
    f1=16,
    d=2,
    pk1=4,
    pk2=8,
    dp=0.5
)

device = torch.device(
    "cuda" if torch.cuda.is_available() else "cpu"
)

model = model.to(device)


# =====================================================
# Loss
# =====================================================
criterion = nn.CrossEntropyLoss(
    label_smoothing=0.05
)


# =====================================================
# Optimizer
# =====================================================
optimizer = torch.optim.AdamW(
    model.parameters(),
    lr=LR,
    weight_decay=WEIGHT_DECAY
)


# =====================================================
# Scheduler：CosineAnnealingLR
# 注意：后面用 scheduler.step()，不要传 epoch_val_acc
# =====================================================
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(
    optimizer,
    T_max=EPOCHS,
    eta_min=MIN_LR
)


# =====================================================
# 记录
# =====================================================
train_losses = []
val_losses = []
train_accuracies = []
val_accuracies = []

best_val_acc = 0.0
best_epoch = 0
early_stop_counter = 0

best_model_state = copy.deepcopy(
    model.state_dict()
)


# =====================================================
# 训练循环
# =====================================================
for epoch in range(EPOCHS):

    # =================================================
    # Train
    # =================================================
    model.train()

    train_loss_sum = 0.0
    train_correct = 0
    train_num = 0

    for data, label in train_loader:

        data = data.to(device)
        label = label.to(device)

        # ---------------------------------------------
        # 训练增强：Gaussian noise + channel dropout
        # ---------------------------------------------
        data = add_gaussian_noise(
            data,
            noise_std=NOISE_STD
        )

        data = channel_dropout(
            data,
            drop_prob=CHANNEL_DROP_PROB
        )

        def mixup(x, y, alpha=0.4):
            lam = np.random.beta(alpha, alpha)
            idx = torch.randperm(x.size(0), device=x.device)
            x_mix = lam * x + (1 - lam) * x[idx]
            y_a, y_b = y, y[idx]
            return x_mix, y_a, y_b, lam
# loss = lam * criterion(out, ya) + (1-lam) * criterion(out, yb)

        # ---------------------------------------------
        # Sliding window：训练时随机 crop
        # 原始 800 点 -> 750 点
        # ---------------------------------------------
        data = random_crop(
            data,
            crop_len=CROP_LEN
        )

        optimizer.zero_grad()

        output = model(data)

        loss = criterion(
            output,
            label
        )

        loss.backward()

        torch.nn.utils.clip_grad_norm_(
            model.parameters(),
            max_norm=5.0
        )

        optimizer.step()

        batch_size = label.size(0)

        train_loss_sum += loss.item() * batch_size
        train_num += batch_size

        pred = torch.argmax(
            output,
            dim=1
        )

        train_correct += (
            pred == label
        ).sum().item()

    epoch_train_loss = train_loss_sum / train_num
    epoch_train_acc = train_correct / train_num

    train_losses.append(epoch_train_loss)
    train_accuracies.append(epoch_train_acc)

    # =================================================
    # Validation
    # =================================================
    model.eval()

    val_loss_sum = 0.0
    val_correct = 0
    val_num = 0

    with torch.no_grad():

        for val_data, val_label in val_loader:

            val_data = val_data.to(device)
            val_label = val_label.to(device)

            # -----------------------------------------
            # 验证时用 crop TTA
            # [0:750], [25:775], [50:800]
            # -----------------------------------------
            val_output = crop_tta_predict(
                model,
                val_data,
                crop_len=CROP_LEN,
                starts=CROP_STARTS
            )

            val_loss = criterion(
                val_output,
                val_label
            )

            batch_size = val_label.size(0)

            val_loss_sum += val_loss.item() * batch_size
            val_num += batch_size

            val_pred = torch.argmax(
                val_output,
                dim=1
            )

            val_correct += (
                val_pred == val_label
            ).sum().item()

    epoch_val_loss = val_loss_sum / val_num
    epoch_val_acc = val_correct / val_num

    val_losses.append(epoch_val_loss)
    val_accuracies.append(epoch_val_acc)

    # =================================================
    # CosineAnnealingLR 正确 step
    # =================================================
    scheduler.step()

    current_lr = optimizer.param_groups[0]["lr"]

    print(
        f"Epoch [{epoch+1:03d}/{EPOCHS}] | "
        f"Train Loss: {epoch_train_loss:.4f} | "
        f"Train Acc: {epoch_train_acc:.4f} | "
        f"Val Loss: {epoch_val_loss:.4f} | "
        f"Val Acc: {epoch_val_acc:.4f} | "
        f"LR: {current_lr:.6f}"
    )

    # =================================================
    # 保存 Val acc 最好的 epoch
    # =================================================
    if epoch_val_acc > best_val_acc + MIN_DELTA:

        best_val_acc = epoch_val_acc
        best_epoch = epoch + 1
        early_stop_counter = 0

        best_model_state = copy.deepcopy(
            model.state_dict()
        )

        print(
            f"✅ Best model updated at epoch {best_epoch}"
        )

    else:

        early_stop_counter += 1

        print(
            f"EarlyStopping Counter: "
            f"{early_stop_counter}/{PATIENCE}"
        )

        if early_stop_counter >= PATIENCE:
            print("\n🛑 Early Stopping Triggered!")
            break


# =====================================================
# 加载最佳模型
# =====================================================
model.load_state_dict(best_model_state)


# =====================================================
# 输出结果
# =====================================================
print("\n" + "=" * 60)
print(f"Best Epoch        : {best_epoch}")
print(f"Best Val Accuracy : {best_val_acc:.4f}")
print("=" * 60)


# =====================================================
# Loss 曲线
# =====================================================
plt.figure(figsize=(8, 5))

plt.plot(train_losses, label="Train Loss")
plt.plot(val_losses, label="Val Loss")

plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Train / Val Loss Curve")
plt.legend()
plt.grid(True)
plt.show()


# =====================================================
# Accuracy 曲线
# =====================================================
plt.figure(figsize=(8, 5))

plt.plot(train_accuracies, label="Train Accuracy")
plt.plot(val_accuracies, label="Val Accuracy")

plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Accuracy Curve")
plt.legend()
plt.grid(True)
plt.show()


# =====================================================
# Test 单个样本推理检查
# =====================================================
model.eval()

with torch.no_grad():

    test_data = next(iter(test_loader))
    test_data = test_data.to(device)

    test_pred = crop_tta_predict(
        model,
        test_data,
        crop_len=CROP_LEN,
        starts=CROP_STARTS
    )

    pred_class = torch.argmax(
        test_pred,
        dim=1
    )

    print("-" * 50)
    print("Test input shape :", test_data.shape)
    print("Test output shape:", test_pred.shape)
    print("Predicted class  :", pred_class.item())
# Out:
# EEGNet embed_dim = 736
# Epoch [001/1000] | Train Loss: 1.4327 | Train Acc: 0.2667 | Val Loss: 1.3460 | Val Acc: 0.3639 | LR: 0.001000
# ✅ Best model updated at epoch 1
# Epoch [002/1000] | Train Loss: 1.3868 | Train Acc: 0.2861 | Val Loss: 1.3321 | Val Acc: 0.3667 | LR: 0.001000
# ✅ Best model updated at epoch 2
# Epoch [003/1000] | Train Loss: 1.3435 | Train Acc: 0.3486 | Val Loss: 1.2956 | Val Acc: 0.4194 | LR: 0.001000
# ✅ Best model updated at epoch 3
# Epoch [004/1000] | Train Loss: 1.3290 | Train Acc: 0.3764 | Val Loss: 1.3037 | Val Acc: 0.4111 | LR: 0.001000
# EarlyStopping Counter: 1/60
# Epoch [005/1000] | Train Loss: 1.3246 | Train Acc: 0.3694 | Val Loss: 1.2561 | Val Acc: 0.4250 | LR: 0.001000
# ✅ Best model updated at epoch 5
# Epoch [006/1000] | Train Loss: 1.2895 | Train Acc: 0.4319 | Val Loss: 1.2644 | Val Acc: 0.4556 | LR: 0.001000
# ✅ Best model updated at epoch 6
# Epoch [007/1000] | Train Loss: 1.2679 | Train Acc: 0.4306 | Val Loss: 1.2494 | Val Acc: 0.4556 | LR: 0.001000
# EarlyStopping Counter: 1/60
# Epoch [008/1000] | Train Loss: 1.2489 | Train Acc: 0.4583 | Val Loss: 1.2326 | Val Acc: 0.4639 | LR: 0.001000
# ✅ Best model updated at epoch 8
# Epoch [009/1000] | Train Loss: 1.2270 | Train Acc: 0.4750 | Val Loss: 1.2290 | Val Acc: 0.4861 | LR: 0.001000
# ✅ Best model updated at epoch 9
# Epoch [010/1000] | Train Loss: 1.2313 | Train Acc: 0.4792 | Val Loss: 1.2364 | Val Acc: 0.4583 | LR: 0.001000
# EarlyStopping Counter: 1/60
# Epoch [011/1000] | Train Loss: 1.1903 | Train Acc: 0.4861 | Val Loss: 1.2295 | Val Acc: 0.4611 | LR: 0.001000
# EarlyStopping Counter: 2/60
# Epoch [012/1000] | Train Loss: 1.1802 | Train Acc: 0.4944 | Val Loss: 1.2322 | Val Acc: 0.4667 | LR: 0.001000
# EarlyStopping Counter: 3/60
# Epoch [013/1000] | Train Loss: 1.1803 | Train Acc: 0.4889 | Val Loss: 1.2087 | Val Acc: 0.4722 | LR: 0.001000
# EarlyStopping Counter: 4/60
# Epoch [014/1000] | Train Loss: 1.1562 | Train Acc: 0.5014 | Val Loss: 1.2346 | Val Acc: 0.4611 | LR: 0.001000
# EarlyStopping Counter: 5/60
# Epoch [015/1000] | Train Loss: 1.1386 | Train Acc: 0.5347 | Val Loss: 1.2100 | Val Acc: 0.4750 | LR: 0.000999
# EarlyStopping Counter: 6/60
# Epoch [016/1000] | Train Loss: 1.1923 | Train Acc: 0.5069 | Val Loss: 1.2404 | Val Acc: 0.4750 | LR: 0.000999
# EarlyStopping Counter: 7/60
# Epoch [017/1000] | Train Loss: 1.1467 | Train Acc: 0.5111 | Val Loss: 1.2140 | Val Acc: 0.4806 | LR: 0.000999
# EarlyStopping Counter: 8/60
# Epoch [018/1000] | Train Loss: 1.1310 | Train Acc: 0.5236 | Val Loss: 1.1847 | Val Acc: 0.5083 | LR: 0.000999
# ✅ Best model updated at epoch 18
# Epoch [019/1000] | Train Loss: 1.1229 | Train Acc: 0.5528 | Val Loss: 1.2028 | Val Acc: 0.4722 | LR: 0.000999
# EarlyStopping Counter: 1/60
# Epoch [020/1000] | Train Loss: 1.1127 | Train Acc: 0.5472 | Val Loss: 1.1755 | Val Acc: 0.5028 | LR: 0.000999
# EarlyStopping Counter: 2/60
# Epoch [021/1000] | Train Loss: 1.1411 | Train Acc: 0.5361 | Val Loss: 1.2589 | Val Acc: 0.4722 | LR: 0.000999
# EarlyStopping Counter: 3/60
# Epoch [022/1000] | Train Loss: 1.1382 | Train Acc: 0.5375 | Val Loss: 1.1697 | Val Acc: 0.5139 | LR: 0.000999
# ✅ Best model updated at epoch 22
# Epoch [023/1000] | Train Loss: 1.1326 | Train Acc: 0.5514 | Val Loss: 1.1698 | Val Acc: 0.4944 | LR: 0.000999
# EarlyStopping Counter: 1/60
# Epoch [024/1000] | Train Loss: 1.0997 | Train Acc: 0.5639 | Val Loss: 1.1766 | Val Acc: 0.5222 | LR: 0.000999
# ✅ Best model updated at epoch 24
# Epoch [025/1000] | Train Loss: 1.1200 | Train Acc: 0.5514 | Val Loss: 1.1406 | Val Acc: 0.5389 | LR: 0.000998
# ✅ Best model updated at epoch 25
# Epoch [026/1000] | Train Loss: 1.1587 | Train Acc: 0.5139 | Val Loss: 1.1713 | Val Acc: 0.4889 | LR: 0.000998
# EarlyStopping Counter: 1/60
# Epoch [027/1000] | Train Loss: 1.0843 | Train Acc: 0.5833 | Val Loss: 1.1762 | Val Acc: 0.4944 | LR: 0.000998
# EarlyStopping Counter: 2/60
# Epoch [028/1000] | Train Loss: 1.1557 | Train Acc: 0.5181 | Val Loss: 1.1832 | Val Acc: 0.5000 | LR: 0.000998
# EarlyStopping Counter: 3/60
# Epoch [029/1000] | Train Loss: 1.1141 | Train Acc: 0.5472 | Val Loss: 1.1719 | Val Acc: 0.4889 | LR: 0.000998
# EarlyStopping Counter: 4/60
# Epoch [030/1000] | Train Loss: 1.1200 | Train Acc: 0.5347 | Val Loss: 1.1576 | Val Acc: 0.5194 | LR: 0.000998
# EarlyStopping Counter: 5/60
# Epoch [031/1000] | Train Loss: 1.0895 | Train Acc: 0.6028 | Val Loss: 1.1437 | Val Acc: 0.5389 | LR: 0.000998
# EarlyStopping Counter: 6/60
# Epoch [032/1000] | Train Loss: 1.0781 | Train Acc: 0.5792 | Val Loss: 1.1386 | Val Acc: 0.5556 | LR: 0.000997
# ✅ Best model updated at epoch 32
# Epoch [033/1000] | Train Loss: 1.1149 | Train Acc: 0.5403 | Val Loss: 1.1700 | Val Acc: 0.5083 | LR: 0.000997
# EarlyStopping Counter: 1/60
# Epoch [034/1000] | Train Loss: 1.0666 | Train Acc: 0.5639 | Val Loss: 1.2000 | Val Acc: 0.5056 | LR: 0.000997
# EarlyStopping Counter: 2/60
# Epoch [035/1000] | Train Loss: 1.1017 | Train Acc: 0.5556 | Val Loss: 1.1421 | Val Acc: 0.5333 | LR: 0.000997
# EarlyStopping Counter: 3/60
# Epoch [036/1000] | Train Loss: 1.0773 | Train Acc: 0.5653 | Val Loss: 1.1577 | Val Acc: 0.5306 | LR: 0.000997
# EarlyStopping Counter: 4/60
# Epoch [037/1000] | Train Loss: 1.1026 | Train Acc: 0.5667 | Val Loss: 1.1607 | Val Acc: 0.5139 | LR: 0.000997
# EarlyStopping Counter: 5/60
# Epoch [038/1000] | Train Loss: 1.0754 | Train Acc: 0.5750 | Val Loss: 1.1466 | Val Acc: 0.5444 | LR: 0.000996
# EarlyStopping Counter: 6/60
# Epoch [039/1000] | Train Loss: 1.0673 | Train Acc: 0.5625 | Val Loss: 1.1274 | Val Acc: 0.5444 | LR: 0.000996
# EarlyStopping Counter: 7/60
# Epoch [040/1000] | Train Loss: 1.0385 | Train Acc: 0.5889 | Val Loss: 1.1176 | Val Acc: 0.5528 | LR: 0.000996
# EarlyStopping Counter: 8/60
# Epoch [041/1000] | Train Loss: 1.0453 | Train Acc: 0.5917 | Val Loss: 1.1352 | Val Acc: 0.5222 | LR: 0.000996
# EarlyStopping Counter: 9/60
# Epoch [042/1000] | Train Loss: 1.0446 | Train Acc: 0.6028 | Val Loss: 1.1413 | Val Acc: 0.5444 | LR: 0.000996
# EarlyStopping Counter: 10/60
# Epoch [043/1000] | Train Loss: 1.0258 | Train Acc: 0.5750 | Val Loss: 1.1307 | Val Acc: 0.5528 | LR: 0.000995
# EarlyStopping Counter: 11/60
# Epoch [044/1000] | Train Loss: 1.0197 | Train Acc: 0.6139 | Val Loss: 1.1672 | Val Acc: 0.5389 | LR: 0.000995
# EarlyStopping Counter: 12/60
# Epoch [045/1000] | Train Loss: 1.0493 | Train Acc: 0.5931 | Val Loss: 1.1348 | Val Acc: 0.5278 | LR: 0.000995
# EarlyStopping Counter: 13/60
# Epoch [046/1000] | Train Loss: 1.0342 | Train Acc: 0.5944 | Val Loss: 1.1391 | Val Acc: 0.5250 | LR: 0.000995
# EarlyStopping Counter: 14/60
# Epoch [047/1000] | Train Loss: 1.0838 | Train Acc: 0.5611 | Val Loss: 1.1631 | Val Acc: 0.5167 | LR: 0.000995
# EarlyStopping Counter: 15/60
# Epoch [048/1000] | Train Loss: 1.0362 | Train Acc: 0.5972 | Val Loss: 1.1045 | Val Acc: 0.5444 | LR: 0.000994
# EarlyStopping Counter: 16/60
# Epoch [049/1000] | Train Loss: 1.0576 | Train Acc: 0.5569 | Val Loss: 1.1351 | Val Acc: 0.5333 | LR: 0.000994
# EarlyStopping Counter: 17/60
# Epoch [050/1000] | Train Loss: 1.0566 | Train Acc: 0.6042 | Val Loss: 1.1232 | Val Acc: 0.5139 | LR: 0.000994
# EarlyStopping Counter: 18/60
# Epoch [051/1000] | Train Loss: 1.0879 | Train Acc: 0.5694 | Val Loss: 1.1389 | Val Acc: 0.5389 | LR: 0.000994
# EarlyStopping Counter: 19/60
# Epoch [052/1000] | Train Loss: 1.0317 | Train Acc: 0.6000 | Val Loss: 1.1372 | Val Acc: 0.5389 | LR: 0.000993
# EarlyStopping Counter: 20/60
# Epoch [053/1000] | Train Loss: 1.0182 | Train Acc: 0.5750 | Val Loss: 1.0966 | Val Acc: 0.5472 | LR: 0.000993
# EarlyStopping Counter: 21/60
# Epoch [054/1000] | Train Loss: 1.0055 | Train Acc: 0.6014 | Val Loss: 1.1122 | Val Acc: 0.5500 | LR: 0.000993
# EarlyStopping Counter: 22/60
# Epoch [055/1000] | Train Loss: 1.0263 | Train Acc: 0.5958 | Val Loss: 1.1153 | Val Acc: 0.5417 | LR: 0.000993
# EarlyStopping Counter: 23/60
# Epoch [056/1000] | Train Loss: 1.0339 | Train Acc: 0.5903 | Val Loss: 1.1061 | Val Acc: 0.5222 | LR: 0.000992
# EarlyStopping Counter: 24/60
# Epoch [057/1000] | Train Loss: 0.9967 | Train Acc: 0.6139 | Val Loss: 1.1013 | Val Acc: 0.5333 | LR: 0.000992
# EarlyStopping Counter: 25/60
# Epoch [058/1000] | Train Loss: 1.0257 | Train Acc: 0.5958 | Val Loss: 1.0988 | Val Acc: 0.5556 | LR: 0.000992
# EarlyStopping Counter: 26/60
# Epoch [059/1000] | Train Loss: 1.0607 | Train Acc: 0.5958 | Val Loss: 1.1243 | Val Acc: 0.5389 | LR: 0.000991
# EarlyStopping Counter: 27/60
# Epoch [060/1000] | Train Loss: 1.0162 | Train Acc: 0.6208 | Val Loss: 1.1150 | Val Acc: 0.5444 | LR: 0.000991
# EarlyStopping Counter: 28/60
# Epoch [061/1000] | Train Loss: 1.0264 | Train Acc: 0.5903 | Val Loss: 1.0849 | Val Acc: 0.5694 | LR: 0.000991
# ✅ Best model updated at epoch 61
# Epoch [062/1000] | Train Loss: 0.9987 | Train Acc: 0.6069 | Val Loss: 1.1074 | Val Acc: 0.5556 | LR: 0.000991
# EarlyStopping Counter: 1/60
# Epoch [063/1000] | Train Loss: 1.0175 | Train Acc: 0.6097 | Val Loss: 1.0952 | Val Acc: 0.5444 | LR: 0.000990
# EarlyStopping Counter: 2/60
# Epoch [064/1000] | Train Loss: 0.9986 | Train Acc: 0.6042 | Val Loss: 1.0846 | Val Acc: 0.5500 | LR: 0.000990
# EarlyStopping Counter: 3/60
# Epoch [065/1000] | Train Loss: 1.0245 | Train Acc: 0.5917 | Val Loss: 1.0863 | Val Acc: 0.5667 | LR: 0.000990
# EarlyStopping Counter: 4/60
# Epoch [066/1000] | Train Loss: 0.9871 | Train Acc: 0.6208 | Val Loss: 1.0912 | Val Acc: 0.5389 | LR: 0.000989
# EarlyStopping Counter: 5/60
# Epoch [067/1000] | Train Loss: 1.0039 | Train Acc: 0.6278 | Val Loss: 1.0573 | Val Acc: 0.5722 | LR: 0.000989
# ✅ Best model updated at epoch 67
# Epoch [068/1000] | Train Loss: 1.0242 | Train Acc: 0.6139 | Val Loss: 1.0974 | Val Acc: 0.5528 | LR: 0.000989
# EarlyStopping Counter: 1/60
# Epoch [069/1000] | Train Loss: 0.9715 | Train Acc: 0.6444 | Val Loss: 1.0863 | Val Acc: 0.5528 | LR: 0.000988
# EarlyStopping Counter: 2/60
# Epoch [070/1000] | Train Loss: 1.0049 | Train Acc: 0.6278 | Val Loss: 1.0867 | Val Acc: 0.5500 | LR: 0.000988
# EarlyStopping Counter: 3/60
# Epoch [071/1000] | Train Loss: 1.0527 | Train Acc: 0.6000 | Val Loss: 1.0957 | Val Acc: 0.5500 | LR: 0.000988
# EarlyStopping Counter: 4/60
# Epoch [072/1000] | Train Loss: 1.0322 | Train Acc: 0.5931 | Val Loss: 1.0762 | Val Acc: 0.5750 | LR: 0.000987
# ✅ Best model updated at epoch 72
# Epoch [073/1000] | Train Loss: 1.0040 | Train Acc: 0.6097 | Val Loss: 1.0980 | Val Acc: 0.5444 | LR: 0.000987
# EarlyStopping Counter: 1/60
# Epoch [074/1000] | Train Loss: 0.9941 | Train Acc: 0.6042 | Val Loss: 1.0843 | Val Acc: 0.5472 | LR: 0.000987
# EarlyStopping Counter: 2/60
# Epoch [075/1000] | Train Loss: 1.0027 | Train Acc: 0.6181 | Val Loss: 1.1025 | Val Acc: 0.5500 | LR: 0.000986
# EarlyStopping Counter: 3/60
# Epoch [076/1000] | Train Loss: 1.0425 | Train Acc: 0.5833 | Val Loss: 1.1116 | Val Acc: 0.5444 | LR: 0.000986
# EarlyStopping Counter: 4/60
# Epoch [077/1000] | Train Loss: 0.9975 | Train Acc: 0.6097 | Val Loss: 1.0842 | Val Acc: 0.5639 | LR: 0.000985
# EarlyStopping Counter: 5/60
# Epoch [078/1000] | Train Loss: 1.0098 | Train Acc: 0.5944 | Val Loss: 1.1065 | Val Acc: 0.5472 | LR: 0.000985
# EarlyStopping Counter: 6/60
# Epoch [079/1000] | Train Loss: 1.0246 | Train Acc: 0.5875 | Val Loss: 1.0743 | Val Acc: 0.5583 | LR: 0.000985
# EarlyStopping Counter: 7/60
# Epoch [080/1000] | Train Loss: 0.9836 | Train Acc: 0.6222 | Val Loss: 1.0930 | Val Acc: 0.5639 | LR: 0.000984
# EarlyStopping Counter: 8/60
# Epoch [081/1000] | Train Loss: 0.9463 | Train Acc: 0.6500 | Val Loss: 1.0944 | Val Acc: 0.5472 | LR: 0.000984
# EarlyStopping Counter: 9/60
# Epoch [082/1000] | Train Loss: 0.9695 | Train Acc: 0.6194 | Val Loss: 1.0910 | Val Acc: 0.5361 | LR: 0.000984
# EarlyStopping Counter: 10/60
# Epoch [083/1000] | Train Loss: 1.0076 | Train Acc: 0.6181 | Val Loss: 1.0881 | Val Acc: 0.5528 | LR: 0.000983
# EarlyStopping Counter: 11/60
# Epoch [084/1000] | Train Loss: 0.9971 | Train Acc: 0.6125 | Val Loss: 1.0885 | Val Acc: 0.5389 | LR: 0.000983
# EarlyStopping Counter: 12/60
# Epoch [085/1000] | Train Loss: 1.0127 | Train Acc: 0.6014 | Val Loss: 1.0971 | Val Acc: 0.5472 | LR: 0.000982
# EarlyStopping Counter: 13/60
# Epoch [086/1000] | Train Loss: 0.9934 | Train Acc: 0.6069 | Val Loss: 1.0831 | Val Acc: 0.5611 | LR: 0.000982
# EarlyStopping Counter: 14/60
# Epoch [087/1000] | Train Loss: 0.9667 | Train Acc: 0.6639 | Val Loss: 1.1031 | Val Acc: 0.5528 | LR: 0.000981
# EarlyStopping Counter: 15/60
# Epoch [088/1000] | Train Loss: 0.9580 | Train Acc: 0.6458 | Val Loss: 1.0969 | Val Acc: 0.5556 | LR: 0.000981
# EarlyStopping Counter: 16/60
# Epoch [089/1000] | Train Loss: 0.9811 | Train Acc: 0.5931 | Val Loss: 1.0700 | Val Acc: 0.5444 | LR: 0.000981
# EarlyStopping Counter: 17/60
# Epoch [090/1000] | Train Loss: 0.9928 | Train Acc: 0.6278 | Val Loss: 1.0599 | Val Acc: 0.5694 | LR: 0.000980
# EarlyStopping Counter: 18/60
# Epoch [091/1000] | Train Loss: 0.9523 | Train Acc: 0.6292 | Val Loss: 1.0669 | Val Acc: 0.5694 | LR: 0.000980
# EarlyStopping Counter: 19/60
# Epoch [092/1000] | Train Loss: 0.9735 | Train Acc: 0.6194 | Val Loss: 1.0999 | Val Acc: 0.5528 | LR: 0.000979
# EarlyStopping Counter: 20/60
# Epoch [093/1000] | Train Loss: 0.9699 | Train Acc: 0.6403 | Val Loss: 1.1171 | Val Acc: 0.5361 | LR: 0.000979
# EarlyStopping Counter: 21/60
# Epoch [094/1000] | Train Loss: 0.9612 | Train Acc: 0.6583 | Val Loss: 1.1053 | Val Acc: 0.5583 | LR: 0.000978
# EarlyStopping Counter: 22/60
# Epoch [095/1000] | Train Loss: 1.0206 | Train Acc: 0.6097 | Val Loss: 1.0688 | Val Acc: 0.5556 | LR: 0.000978
# EarlyStopping Counter: 23/60
# Epoch [096/1000] | Train Loss: 0.9792 | Train Acc: 0.6208 | Val Loss: 1.0848 | Val Acc: 0.5500 | LR: 0.000977
# EarlyStopping Counter: 24/60
# Epoch [097/1000] | Train Loss: 0.9977 | Train Acc: 0.6333 | Val Loss: 1.0659 | Val Acc: 0.5611 | LR: 0.000977
# EarlyStopping Counter: 25/60
# Epoch [098/1000] | Train Loss: 0.9395 | Train Acc: 0.6375 | Val Loss: 1.0695 | Val Acc: 0.5778 | LR: 0.000977
# ✅ Best model updated at epoch 98
# Epoch [099/1000] | Train Loss: 0.9682 | Train Acc: 0.6403 | Val Loss: 1.0598 | Val Acc: 0.5750 | LR: 0.000976
# EarlyStopping Counter: 1/60
# Epoch [100/1000] | Train Loss: 0.9549 | Train Acc: 0.6083 | Val Loss: 1.0617 | Val Acc: 0.5639 | LR: 0.000976
# EarlyStopping Counter: 2/60
# Epoch [101/1000] | Train Loss: 0.9566 | Train Acc: 0.6639 | Val Loss: 1.0665 | Val Acc: 0.5889 | LR: 0.000975
# ✅ Best model updated at epoch 101
# Epoch [102/1000] | Train Loss: 0.9422 | Train Acc: 0.6819 | Val Loss: 1.0666 | Val Acc: 0.5750 | LR: 0.000975
# EarlyStopping Counter: 1/60
# Epoch [103/1000] | Train Loss: 0.9321 | Train Acc: 0.6375 | Val Loss: 1.0565 | Val Acc: 0.5611 | LR: 0.000974
# EarlyStopping Counter: 2/60
# Epoch [104/1000] | Train Loss: 0.9698 | Train Acc: 0.6222 | Val Loss: 1.0730 | Val Acc: 0.5556 | LR: 0.000974
# EarlyStopping Counter: 3/60
# Epoch [105/1000] | Train Loss: 0.9881 | Train Acc: 0.6236 | Val Loss: 1.0559 | Val Acc: 0.5806 | LR: 0.000973
# EarlyStopping Counter: 4/60
# Epoch [106/1000] | Train Loss: 0.9710 | Train Acc: 0.6347 | Val Loss: 1.0501 | Val Acc: 0.5778 | LR: 0.000973
# EarlyStopping Counter: 5/60
# Epoch [107/1000] | Train Loss: 0.9325 | Train Acc: 0.6347 | Val Loss: 1.0592 | Val Acc: 0.5667 | LR: 0.000972
# EarlyStopping Counter: 6/60
# Epoch [108/1000] | Train Loss: 0.9496 | Train Acc: 0.6653 | Val Loss: 1.0608 | Val Acc: 0.5750 | LR: 0.000972
# EarlyStopping Counter: 7/60
# Epoch [109/1000] | Train Loss: 0.9765 | Train Acc: 0.6236 | Val Loss: 1.0648 | Val Acc: 0.5694 | LR: 0.000971
# EarlyStopping Counter: 8/60
# Epoch [110/1000] | Train Loss: 0.9260 | Train Acc: 0.6542 | Val Loss: 1.0394 | Val Acc: 0.5889 | LR: 0.000970
# EarlyStopping Counter: 9/60
# Epoch [111/1000] | Train Loss: 0.9694 | Train Acc: 0.6194 | Val Loss: 1.0427 | Val Acc: 0.5833 | LR: 0.000970
# EarlyStopping Counter: 10/60
# Epoch [112/1000] | Train Loss: 0.9752 | Train Acc: 0.6181 | Val Loss: 1.0660 | Val Acc: 0.5556 | LR: 0.000969
# EarlyStopping Counter: 11/60
# Epoch [113/1000] | Train Loss: 0.9517 | Train Acc: 0.6417 | Val Loss: 1.0476 | Val Acc: 0.5778 | LR: 0.000969
# EarlyStopping Counter: 12/60
# Epoch [114/1000] | Train Loss: 0.9168 | Train Acc: 0.6431 | Val Loss: 1.0597 | Val Acc: 0.5528 | LR: 0.000968
# EarlyStopping Counter: 13/60
# Epoch [115/1000] | Train Loss: 0.9462 | Train Acc: 0.6319 | Val Loss: 1.0511 | Val Acc: 0.5556 | LR: 0.000968
# EarlyStopping Counter: 14/60
# Epoch [116/1000] | Train Loss: 0.9137 | Train Acc: 0.6833 | Val Loss: 1.0490 | Val Acc: 0.5694 | LR: 0.000967
# EarlyStopping Counter: 15/60
# Epoch [117/1000] | Train Loss: 0.9334 | Train Acc: 0.6639 | Val Loss: 1.0425 | Val Acc: 0.5861 | LR: 0.000967
# EarlyStopping Counter: 16/60
# Epoch [118/1000] | Train Loss: 0.9506 | Train Acc: 0.6514 | Val Loss: 1.0339 | Val Acc: 0.5861 | LR: 0.000966
# EarlyStopping Counter: 17/60
# Epoch [119/1000] | Train Loss: 0.9219 | Train Acc: 0.6694 | Val Loss: 1.0570 | Val Acc: 0.5778 | LR: 0.000965
# EarlyStopping Counter: 18/60
# Epoch [120/1000] | Train Loss: 0.9193 | Train Acc: 0.6514 | Val Loss: 1.0462 | Val Acc: 0.5694 | LR: 0.000965
# EarlyStopping Counter: 19/60
# Epoch [121/1000] | Train Loss: 0.9296 | Train Acc: 0.6597 | Val Loss: 1.0411 | Val Acc: 0.5694 | LR: 0.000964
# EarlyStopping Counter: 20/60
# Epoch [122/1000] | Train Loss: 0.9687 | Train Acc: 0.6264 | Val Loss: 1.0457 | Val Acc: 0.5611 | LR: 0.000964
# EarlyStopping Counter: 21/60
# Epoch [123/1000] | Train Loss: 0.9483 | Train Acc: 0.6319 | Val Loss: 1.0543 | Val Acc: 0.5750 | LR: 0.000963
# EarlyStopping Counter: 22/60
# Epoch [124/1000] | Train Loss: 0.9171 | Train Acc: 0.6611 | Val Loss: 1.0505 | Val Acc: 0.5583 | LR: 0.000963
# EarlyStopping Counter: 23/60
# Epoch [125/1000] | Train Loss: 0.9202 | Train Acc: 0.6611 | Val Loss: 1.0299 | Val Acc: 0.5778 | LR: 0.000962
# EarlyStopping Counter: 24/60
# Epoch [126/1000] | Train Loss: 0.9500 | Train Acc: 0.6514 | Val Loss: 1.0240 | Val Acc: 0.5917 | LR: 0.000961
# ✅ Best model updated at epoch 126
# Epoch [127/1000] | Train Loss: 0.9146 | Train Acc: 0.6736 | Val Loss: 1.0333 | Val Acc: 0.5694 | LR: 0.000961
# EarlyStopping Counter: 1/60
# Epoch [128/1000] | Train Loss: 0.9342 | Train Acc: 0.6431 | Val Loss: 1.0302 | Val Acc: 0.5889 | LR: 0.000960
# EarlyStopping Counter: 2/60
# Epoch [129/1000] | Train Loss: 0.9328 | Train Acc: 0.6375 | Val Loss: 1.0148 | Val Acc: 0.5972 | LR: 0.000960
# ✅ Best model updated at epoch 129
# Epoch [130/1000] | Train Loss: 0.9279 | Train Acc: 0.6431 | Val Loss: 1.0186 | Val Acc: 0.6056 | LR: 0.000959
# ✅ Best model updated at epoch 130
# Epoch [131/1000] | Train Loss: 0.9079 | Train Acc: 0.6611 | Val Loss: 1.0234 | Val Acc: 0.5778 | LR: 0.000958
# EarlyStopping Counter: 1/60
# Epoch [132/1000] | Train Loss: 0.9143 | Train Acc: 0.6500 | Val Loss: 1.0224 | Val Acc: 0.5778 | LR: 0.000958
# EarlyStopping Counter: 2/60
# Epoch [133/1000] | Train Loss: 0.9626 | Train Acc: 0.6444 | Val Loss: 1.0210 | Val Acc: 0.5611 | LR: 0.000957
# EarlyStopping Counter: 3/60
# Epoch [134/1000] | Train Loss: 0.9299 | Train Acc: 0.6500 | Val Loss: 1.0417 | Val Acc: 0.5806 | LR: 0.000956
# EarlyStopping Counter: 4/60
# Epoch [135/1000] | Train Loss: 0.9258 | Train Acc: 0.6431 | Val Loss: 1.0344 | Val Acc: 0.5722 | LR: 0.000956
# EarlyStopping Counter: 5/60
# Epoch [136/1000] | Train Loss: 1.0391 | Train Acc: 0.6056 | Val Loss: 1.0216 | Val Acc: 0.5861 | LR: 0.000955
# EarlyStopping Counter: 6/60
# Epoch [137/1000] | Train Loss: 0.8827 | Train Acc: 0.6736 | Val Loss: 1.0196 | Val Acc: 0.5917 | LR: 0.000954
# EarlyStopping Counter: 7/60
# Epoch [138/1000] | Train Loss: 0.9453 | Train Acc: 0.6361 | Val Loss: 1.0414 | Val Acc: 0.5861 | LR: 0.000954
# EarlyStopping Counter: 8/60
# Epoch [139/1000] | Train Loss: 0.9128 | Train Acc: 0.6722 | Val Loss: 1.0213 | Val Acc: 0.5889 | LR: 0.000953
# EarlyStopping Counter: 9/60
# Epoch [140/1000] | Train Loss: 0.9007 | Train Acc: 0.6681 | Val Loss: 1.0359 | Val Acc: 0.5778 | LR: 0.000952
# EarlyStopping Counter: 10/60
# Epoch [141/1000] | Train Loss: 0.9282 | Train Acc: 0.6722 | Val Loss: 1.0382 | Val Acc: 0.5861 | LR: 0.000952
# EarlyStopping Counter: 11/60
# Epoch [142/1000] | Train Loss: 0.9108 | Train Acc: 0.6778 | Val Loss: 1.0162 | Val Acc: 0.5944 | LR: 0.000951
# EarlyStopping Counter: 12/60
# Epoch [143/1000] | Train Loss: 0.9398 | Train Acc: 0.6472 | Val Loss: 1.0359 | Val Acc: 0.5944 | LR: 0.000950
# EarlyStopping Counter: 13/60
# Epoch [144/1000] | Train Loss: 0.9263 | Train Acc: 0.6542 | Val Loss: 1.0258 | Val Acc: 0.6000 | LR: 0.000950
# EarlyStopping Counter: 14/60
# Epoch [145/1000] | Train Loss: 0.8796 | Train Acc: 0.6819 | Val Loss: 1.0204 | Val Acc: 0.6000 | LR: 0.000949
# EarlyStopping Counter: 15/60
# Epoch [146/1000] | Train Loss: 0.9081 | Train Acc: 0.6875 | Val Loss: 1.0504 | Val Acc: 0.6028 | LR: 0.000948
# EarlyStopping Counter: 16/60
# Epoch [147/1000] | Train Loss: 0.9271 | Train Acc: 0.6528 | Val Loss: 1.0126 | Val Acc: 0.6083 | LR: 0.000948
# ✅ Best model updated at epoch 147
# Epoch [148/1000] | Train Loss: 0.9322 | Train Acc: 0.6417 | Val Loss: 1.0481 | Val Acc: 0.5750 | LR: 0.000947
# EarlyStopping Counter: 1/60
# Epoch [149/1000] | Train Loss: 0.8761 | Train Acc: 0.6750 | Val Loss: 1.0300 | Val Acc: 0.5972 | LR: 0.000946
# EarlyStopping Counter: 2/60
# Epoch [150/1000] | Train Loss: 0.9355 | Train Acc: 0.6653 | Val Loss: 1.0199 | Val Acc: 0.5944 | LR: 0.000946
# EarlyStopping Counter: 3/60
# Epoch [151/1000] | Train Loss: 0.9730 | Train Acc: 0.6167 | Val Loss: 1.0079 | Val Acc: 0.6111 | LR: 0.000945
# ✅ Best model updated at epoch 151
# Epoch [152/1000] | Train Loss: 0.8873 | Train Acc: 0.6778 | Val Loss: 1.0033 | Val Acc: 0.6111 | LR: 0.000944
# EarlyStopping Counter: 1/60
# Epoch [153/1000] | Train Loss: 0.9071 | Train Acc: 0.6556 | Val Loss: 1.0256 | Val Acc: 0.5833 | LR: 0.000943
# EarlyStopping Counter: 2/60
# Epoch [154/1000] | Train Loss: 0.9434 | Train Acc: 0.6583 | Val Loss: 1.0086 | Val Acc: 0.6083 | LR: 0.000943
# EarlyStopping Counter: 3/60
# Epoch [155/1000] | Train Loss: 0.9232 | Train Acc: 0.6528 | Val Loss: 1.0061 | Val Acc: 0.5694 | LR: 0.000942
# EarlyStopping Counter: 4/60
# Epoch [156/1000] | Train Loss: 0.9282 | Train Acc: 0.6625 | Val Loss: 1.0171 | Val Acc: 0.5917 | LR: 0.000941
# EarlyStopping Counter: 5/60
# Epoch [157/1000] | Train Loss: 0.8845 | Train Acc: 0.6639 | Val Loss: 0.9972 | Val Acc: 0.6111 | LR: 0.000940
# EarlyStopping Counter: 6/60
# Epoch [158/1000] | Train Loss: 0.9079 | Train Acc: 0.6653 | Val Loss: 1.0157 | Val Acc: 0.5861 | LR: 0.000940
# EarlyStopping Counter: 7/60
# Epoch [159/1000] | Train Loss: 0.8916 | Train Acc: 0.6611 | Val Loss: 1.0253 | Val Acc: 0.5806 | LR: 0.000939
# EarlyStopping Counter: 8/60
# Epoch [160/1000] | Train Loss: 0.8891 | Train Acc: 0.6764 | Val Loss: 1.0161 | Val Acc: 0.5833 | LR: 0.000938
# EarlyStopping Counter: 9/60
# Epoch [161/1000] | Train Loss: 0.9382 | Train Acc: 0.6681 | Val Loss: 1.0194 | Val Acc: 0.5861 | LR: 0.000937
# EarlyStopping Counter: 10/60
# Epoch [162/1000] | Train Loss: 0.9236 | Train Acc: 0.6542 | Val Loss: 1.0063 | Val Acc: 0.5972 | LR: 0.000937
# EarlyStopping Counter: 11/60
# Epoch [163/1000] | Train Loss: 0.9001 | Train Acc: 0.6625 | Val Loss: 0.9933 | Val Acc: 0.6111 | LR: 0.000936
# EarlyStopping Counter: 12/60
# Epoch [164/1000] | Train Loss: 0.9031 | Train Acc: 0.6764 | Val Loss: 1.0011 | Val Acc: 0.5833 | LR: 0.000935
# EarlyStopping Counter: 13/60
# Epoch [165/1000] | Train Loss: 0.8903 | Train Acc: 0.6972 | Val Loss: 1.0172 | Val Acc: 0.5917 | LR: 0.000934
# EarlyStopping Counter: 14/60
# Epoch [166/1000] | Train Loss: 0.8511 | Train Acc: 0.7208 | Val Loss: 1.0161 | Val Acc: 0.5833 | LR: 0.000934
# EarlyStopping Counter: 15/60
# Epoch [167/1000] | Train Loss: 0.9236 | Train Acc: 0.6778 | Val Loss: 1.0055 | Val Acc: 0.5889 | LR: 0.000933
# EarlyStopping Counter: 16/60
# Epoch [168/1000] | Train Loss: 0.8897 | Train Acc: 0.6861 | Val Loss: 1.0027 | Val Acc: 0.6000 | LR: 0.000932
# EarlyStopping Counter: 17/60
# Epoch [169/1000] | Train Loss: 0.9041 | Train Acc: 0.6708 | Val Loss: 1.0002 | Val Acc: 0.6056 | LR: 0.000931
# EarlyStopping Counter: 18/60
# Epoch [170/1000] | Train Loss: 0.8654 | Train Acc: 0.7083 | Val Loss: 0.9961 | Val Acc: 0.6028 | LR: 0.000930
# EarlyStopping Counter: 19/60
# Epoch [171/1000] | Train Loss: 0.9369 | Train Acc: 0.6653 | Val Loss: 0.9798 | Val Acc: 0.6250 | LR: 0.000930
# ✅ Best model updated at epoch 171
# Epoch [172/1000] | Train Loss: 0.8885 | Train Acc: 0.6500 | Val Loss: 1.0239 | Val Acc: 0.5972 | LR: 0.000929
# EarlyStopping Counter: 1/60
# Epoch [173/1000] | Train Loss: 0.9130 | Train Acc: 0.6583 | Val Loss: 1.0058 | Val Acc: 0.6139 | LR: 0.000928
# EarlyStopping Counter: 2/60
# Epoch [174/1000] | Train Loss: 0.8463 | Train Acc: 0.6806 | Val Loss: 1.0072 | Val Acc: 0.5944 | LR: 0.000927
# EarlyStopping Counter: 3/60
# Epoch [175/1000] | Train Loss: 0.9136 | Train Acc: 0.6611 | Val Loss: 0.9949 | Val Acc: 0.5889 | LR: 0.000926
# EarlyStopping Counter: 4/60
# Epoch [176/1000] | Train Loss: 0.8929 | Train Acc: 0.6931 | Val Loss: 0.9910 | Val Acc: 0.6111 | LR: 0.000926
# EarlyStopping Counter: 5/60
# Epoch [177/1000] | Train Loss: 0.8988 | Train Acc: 0.6833 | Val Loss: 0.9973 | Val Acc: 0.5972 | LR: 0.000925
# EarlyStopping Counter: 6/60
# Epoch [178/1000] | Train Loss: 0.9131 | Train Acc: 0.6444 | Val Loss: 1.0034 | Val Acc: 0.5889 | LR: 0.000924
# EarlyStopping Counter: 7/60
# Epoch [179/1000] | Train Loss: 0.9510 | Train Acc: 0.6306 | Val Loss: 1.0035 | Val Acc: 0.5972 | LR: 0.000923
# EarlyStopping Counter: 8/60
# Epoch [180/1000] | Train Loss: 0.9132 | Train Acc: 0.6444 | Val Loss: 1.0045 | Val Acc: 0.6028 | LR: 0.000922
# EarlyStopping Counter: 9/60
# Epoch [181/1000] | Train Loss: 0.8732 | Train Acc: 0.6722 | Val Loss: 1.0073 | Val Acc: 0.5917 | LR: 0.000921
# EarlyStopping Counter: 10/60
# Epoch [182/1000] | Train Loss: 0.8675 | Train Acc: 0.6861 | Val Loss: 1.0187 | Val Acc: 0.5917 | LR: 0.000921
# EarlyStopping Counter: 11/60
# Epoch [183/1000] | Train Loss: 0.8997 | Train Acc: 0.6569 | Val Loss: 0.9880 | Val Acc: 0.6111 | LR: 0.000920
# EarlyStopping Counter: 12/60
# Epoch [184/1000] | Train Loss: 0.9181 | Train Acc: 0.6528 | Val Loss: 0.9990 | Val Acc: 0.5972 | LR: 0.000919
# EarlyStopping Counter: 13/60
# Epoch [185/1000] | Train Loss: 0.8937 | Train Acc: 0.6694 | Val Loss: 0.9869 | Val Acc: 0.5889 | LR: 0.000918
# EarlyStopping Counter: 14/60
# Epoch [186/1000] | Train Loss: 0.8776 | Train Acc: 0.6694 | Val Loss: 0.9894 | Val Acc: 0.6028 | LR: 0.000917
# EarlyStopping Counter: 15/60
# Epoch [187/1000] | Train Loss: 0.8905 | Train Acc: 0.6722 | Val Loss: 0.9881 | Val Acc: 0.6028 | LR: 0.000916
# EarlyStopping Counter: 16/60
# Epoch [188/1000] | Train Loss: 0.8900 | Train Acc: 0.6819 | Val Loss: 0.9938 | Val Acc: 0.6000 | LR: 0.000915
# EarlyStopping Counter: 17/60
# Epoch [189/1000] | Train Loss: 0.8869 | Train Acc: 0.6944 | Val Loss: 0.9935 | Val Acc: 0.6056 | LR: 0.000915
# EarlyStopping Counter: 18/60
# Epoch [190/1000] | Train Loss: 0.8851 | Train Acc: 0.6833 | Val Loss: 0.9899 | Val Acc: 0.6139 | LR: 0.000914
# EarlyStopping Counter: 19/60
# Epoch [191/1000] | Train Loss: 0.8473 | Train Acc: 0.6944 | Val Loss: 1.0195 | Val Acc: 0.6000 | LR: 0.000913
# EarlyStopping Counter: 20/60
# Epoch [192/1000] | Train Loss: 0.8735 | Train Acc: 0.6819 | Val Loss: 1.0053 | Val Acc: 0.5917 | LR: 0.000912
# EarlyStopping Counter: 21/60
# Epoch [193/1000] | Train Loss: 0.9131 | Train Acc: 0.6639 | Val Loss: 1.0046 | Val Acc: 0.5944 | LR: 0.000911
# EarlyStopping Counter: 22/60
# Epoch [194/1000] | Train Loss: 0.8904 | Train Acc: 0.6722 | Val Loss: 0.9895 | Val Acc: 0.6000 | LR: 0.000910
# EarlyStopping Counter: 23/60
# Epoch [195/1000] | Train Loss: 0.8769 | Train Acc: 0.6736 | Val Loss: 0.9983 | Val Acc: 0.5944 | LR: 0.000909
# EarlyStopping Counter: 24/60
# Epoch [196/1000] | Train Loss: 0.8591 | Train Acc: 0.6931 | Val Loss: 1.0069 | Val Acc: 0.5972 | LR: 0.000908
# EarlyStopping Counter: 25/60
# Epoch [197/1000] | Train Loss: 0.8827 | Train Acc: 0.6625 | Val Loss: 0.9926 | Val Acc: 0.5944 | LR: 0.000907
# EarlyStopping Counter: 26/60
# Epoch [198/1000] | Train Loss: 0.8802 | Train Acc: 0.7056 | Val Loss: 1.0027 | Val Acc: 0.5972 | LR: 0.000906
# EarlyStopping Counter: 27/60
# Epoch [199/1000] | Train Loss: 0.8734 | Train Acc: 0.6889 | Val Loss: 0.9929 | Val Acc: 0.5861 | LR: 0.000906
# EarlyStopping Counter: 28/60
# Epoch [200/1000] | Train Loss: 0.8645 | Train Acc: 0.7028 | Val Loss: 0.9871 | Val Acc: 0.6056 | LR: 0.000905
# EarlyStopping Counter: 29/60
# Epoch [201/1000] | Train Loss: 0.8823 | Train Acc: 0.6833 | Val Loss: 1.0008 | Val Acc: 0.5944 | LR: 0.000904
# EarlyStopping Counter: 30/60
# Epoch [202/1000] | Train Loss: 0.8272 | Train Acc: 0.6917 | Val Loss: 1.0013 | Val Acc: 0.5889 | LR: 0.000903
# EarlyStopping Counter: 31/60
# Epoch [203/1000] | Train Loss: 0.8656 | Train Acc: 0.6917 | Val Loss: 1.0073 | Val Acc: 0.6028 | LR: 0.000902
# EarlyStopping Counter: 32/60
# Epoch [204/1000] | Train Loss: 0.8787 | Train Acc: 0.6750 | Val Loss: 1.0228 | Val Acc: 0.5694 | LR: 0.000901
# EarlyStopping Counter: 33/60
# Epoch [205/1000] | Train Loss: 0.8607 | Train Acc: 0.6833 | Val Loss: 0.9866 | Val Acc: 0.6278 | LR: 0.000900
# ✅ Best model updated at epoch 205
# Epoch [206/1000] | Train Loss: 0.8495 | Train Acc: 0.6764 | Val Loss: 1.0134 | Val Acc: 0.6000 | LR: 0.000899
# EarlyStopping Counter: 1/60
# Epoch [207/1000] | Train Loss: 0.9094 | Train Acc: 0.6681 | Val Loss: 1.0068 | Val Acc: 0.5889 | LR: 0.000898
# EarlyStopping Counter: 2/60
# Epoch [208/1000] | Train Loss: 0.8558 | Train Acc: 0.6917 | Val Loss: 0.9896 | Val Acc: 0.6083 | LR: 0.000897
# EarlyStopping Counter: 3/60
# Epoch [209/1000] | Train Loss: 0.8759 | Train Acc: 0.6819 | Val Loss: 0.9974 | Val Acc: 0.5889 | LR: 0.000896
# EarlyStopping Counter: 4/60
# Epoch [210/1000] | Train Loss: 0.8813 | Train Acc: 0.6778 | Val Loss: 0.9959 | Val Acc: 0.5917 | LR: 0.000895
# EarlyStopping Counter: 5/60
# Epoch [211/1000] | Train Loss: 0.8634 | Train Acc: 0.6903 | Val Loss: 0.9810 | Val Acc: 0.6056 | LR: 0.000894
# EarlyStopping Counter: 6/60
# Epoch [212/1000] | Train Loss: 0.8869 | Train Acc: 0.6875 | Val Loss: 0.9892 | Val Acc: 0.6111 | LR: 0.000893
# EarlyStopping Counter: 7/60
# Epoch [213/1000] | Train Loss: 0.8812 | Train Acc: 0.6875 | Val Loss: 0.9743 | Val Acc: 0.6222 | LR: 0.000892
# EarlyStopping Counter: 8/60
# Epoch [214/1000] | Train Loss: 0.8717 | Train Acc: 0.6889 | Val Loss: 0.9773 | Val Acc: 0.6028 | LR: 0.000891
# EarlyStopping Counter: 9/60
# Epoch [215/1000] | Train Loss: 0.8414 | Train Acc: 0.6986 | Val Loss: 0.9895 | Val Acc: 0.6028 | LR: 0.000890
# EarlyStopping Counter: 10/60
# Epoch [216/1000] | Train Loss: 0.8989 | Train Acc: 0.6653 | Val Loss: 0.9903 | Val Acc: 0.6056 | LR: 0.000889
# EarlyStopping Counter: 11/60
# Epoch [217/1000] | Train Loss: 0.8595 | Train Acc: 0.7028 | Val Loss: 0.9755 | Val Acc: 0.6222 | LR: 0.000888
# EarlyStopping Counter: 12/60
# Epoch [218/1000] | Train Loss: 0.8739 | Train Acc: 0.6889 | Val Loss: 0.9828 | Val Acc: 0.6361 | LR: 0.000887
# ✅ Best model updated at epoch 218
# Epoch [219/1000] | Train Loss: 0.8416 | Train Acc: 0.7014 | Val Loss: 0.9969 | Val Acc: 0.6194 | LR: 0.000886
# EarlyStopping Counter: 1/60
# Epoch [220/1000] | Train Loss: 0.8310 | Train Acc: 0.6972 | Val Loss: 0.9810 | Val Acc: 0.6361 | LR: 0.000885
# EarlyStopping Counter: 2/60
# Epoch [221/1000] | Train Loss: 0.8536 | Train Acc: 0.6653 | Val Loss: 0.9936 | Val Acc: 0.6111 | LR: 0.000884
# EarlyStopping Counter: 3/60
# Epoch [222/1000] | Train Loss: 0.8301 | Train Acc: 0.6889 | Val Loss: 0.9851 | Val Acc: 0.6167 | LR: 0.000883
# EarlyStopping Counter: 4/60
# Epoch [223/1000] | Train Loss: 0.8301 | Train Acc: 0.7028 | Val Loss: 0.9904 | Val Acc: 0.6000 | LR: 0.000882
# EarlyStopping Counter: 5/60
# Epoch [224/1000] | Train Loss: 0.8855 | Train Acc: 0.6708 | Val Loss: 0.9734 | Val Acc: 0.6222 | LR: 0.000881
# EarlyStopping Counter: 6/60
# Epoch [225/1000] | Train Loss: 0.8392 | Train Acc: 0.7153 | Val Loss: 0.9676 | Val Acc: 0.6250 | LR: 0.000880
# EarlyStopping Counter: 7/60
# Epoch [226/1000] | Train Loss: 0.8401 | Train Acc: 0.6889 | Val Loss: 0.9861 | Val Acc: 0.6000 | LR: 0.000879
# EarlyStopping Counter: 8/60
# Epoch [227/1000] | Train Loss: 0.8596 | Train Acc: 0.7000 | Val Loss: 0.9927 | Val Acc: 0.6056 | LR: 0.000878
# EarlyStopping Counter: 9/60
# Epoch [228/1000] | Train Loss: 0.8696 | Train Acc: 0.6667 | Val Loss: 0.9854 | Val Acc: 0.6194 | LR: 0.000877
# EarlyStopping Counter: 10/60
# Epoch [229/1000] | Train Loss: 0.8427 | Train Acc: 0.7083 | Val Loss: 1.0022 | Val Acc: 0.5972 | LR: 0.000876
# EarlyStopping Counter: 11/60
# Epoch [230/1000] | Train Loss: 0.8260 | Train Acc: 0.6847 | Val Loss: 1.0028 | Val Acc: 0.5972 | LR: 0.000875
# EarlyStopping Counter: 12/60
# Epoch [231/1000] | Train Loss: 0.8488 | Train Acc: 0.7069 | Val Loss: 0.9977 | Val Acc: 0.5917 | LR: 0.000874
# EarlyStopping Counter: 13/60
# Epoch [232/1000] | Train Loss: 0.9043 | Train Acc: 0.6903 | Val Loss: 0.9901 | Val Acc: 0.6000 | LR: 0.000873
# EarlyStopping Counter: 14/60
# Epoch [233/1000] | Train Loss: 0.8660 | Train Acc: 0.6917 | Val Loss: 0.9962 | Val Acc: 0.5972 | LR: 0.000872
# EarlyStopping Counter: 15/60
# Epoch [234/1000] | Train Loss: 0.8303 | Train Acc: 0.6986 | Val Loss: 1.0046 | Val Acc: 0.6111 | LR: 0.000871
# EarlyStopping Counter: 16/60
# Epoch [235/1000] | Train Loss: 0.8739 | Train Acc: 0.6917 | Val Loss: 0.9990 | Val Acc: 0.5917 | LR: 0.000870
# EarlyStopping Counter: 17/60
# Epoch [236/1000] | Train Loss: 0.8220 | Train Acc: 0.7194 | Val Loss: 1.0147 | Val Acc: 0.6056 | LR: 0.000869
# EarlyStopping Counter: 18/60
# Epoch [237/1000] | Train Loss: 0.8760 | Train Acc: 0.6847 | Val Loss: 1.0120 | Val Acc: 0.6056 | LR: 0.000868
# EarlyStopping Counter: 19/60
# Epoch [238/1000] | Train Loss: 0.8577 | Train Acc: 0.6875 | Val Loss: 0.9871 | Val Acc: 0.6056 | LR: 0.000867
# EarlyStopping Counter: 20/60
# Epoch [239/1000] | Train Loss: 0.8596 | Train Acc: 0.6778 | Val Loss: 0.9971 | Val Acc: 0.6056 | LR: 0.000866
# EarlyStopping Counter: 21/60
# Epoch [240/1000] | Train Loss: 0.8130 | Train Acc: 0.7167 | Val Loss: 1.0389 | Val Acc: 0.5944 | LR: 0.000865
# EarlyStopping Counter: 22/60
# Epoch [241/1000] | Train Loss: 0.8478 | Train Acc: 0.7028 | Val Loss: 1.0046 | Val Acc: 0.5944 | LR: 0.000864
# EarlyStopping Counter: 23/60
# Epoch [242/1000] | Train Loss: 0.8762 | Train Acc: 0.6806 | Val Loss: 0.9989 | Val Acc: 0.6000 | LR: 0.000862
# EarlyStopping Counter: 24/60
# Epoch [243/1000] | Train Loss: 0.8577 | Train Acc: 0.6986 | Val Loss: 0.9973 | Val Acc: 0.5917 | LR: 0.000861
# EarlyStopping Counter: 25/60
# Epoch [244/1000] | Train Loss: 0.8619 | Train Acc: 0.6917 | Val Loss: 0.9942 | Val Acc: 0.6111 | LR: 0.000860
# EarlyStopping Counter: 26/60
# Epoch [245/1000] | Train Loss: 0.8410 | Train Acc: 0.6792 | Val Loss: 0.9832 | Val Acc: 0.6194 | LR: 0.000859
# EarlyStopping Counter: 27/60
# Epoch [246/1000] | Train Loss: 0.8207 | Train Acc: 0.7083 | Val Loss: 0.9653 | Val Acc: 0.6083 | LR: 0.000858
# EarlyStopping Counter: 28/60
# Epoch [247/1000] | Train Loss: 0.8415 | Train Acc: 0.6833 | Val Loss: 0.9810 | Val Acc: 0.5889 | LR: 0.000857
# EarlyStopping Counter: 29/60
# Epoch [248/1000] | Train Loss: 0.8755 | Train Acc: 0.6792 | Val Loss: 0.9832 | Val Acc: 0.6083 | LR: 0.000856
# EarlyStopping Counter: 30/60
# Epoch [249/1000] | Train Loss: 0.8267 | Train Acc: 0.7028 | Val Loss: 0.9968 | Val Acc: 0.5944 | LR: 0.000855
# EarlyStopping Counter: 31/60
# Epoch [250/1000] | Train Loss: 0.8253 | Train Acc: 0.7250 | Val Loss: 0.9758 | Val Acc: 0.6083 | LR: 0.000854
# EarlyStopping Counter: 32/60
# Epoch [251/1000] | Train Loss: 0.8882 | Train Acc: 0.6653 | Val Loss: 0.9724 | Val Acc: 0.6167 | LR: 0.000853
# EarlyStopping Counter: 33/60
# Epoch [252/1000] | Train Loss: 0.8701 | Train Acc: 0.6944 | Val Loss: 0.9917 | Val Acc: 0.6083 | LR: 0.000851
# EarlyStopping Counter: 34/60
# Epoch [253/1000] | Train Loss: 0.9101 | Train Acc: 0.6583 | Val Loss: 0.9758 | Val Acc: 0.6083 | LR: 0.000850
# EarlyStopping Counter: 35/60
# Epoch [254/1000] | Train Loss: 0.8723 | Train Acc: 0.6944 | Val Loss: 0.9770 | Val Acc: 0.6028 | LR: 0.000849
# EarlyStopping Counter: 36/60
# Epoch [255/1000] | Train Loss: 0.8588 | Train Acc: 0.6861 | Val Loss: 1.0082 | Val Acc: 0.6056 | LR: 0.000848
# EarlyStopping Counter: 37/60
# Epoch [256/1000] | Train Loss: 0.8491 | Train Acc: 0.7125 | Val Loss: 0.9802 | Val Acc: 0.6111 | LR: 0.000847
# EarlyStopping Counter: 38/60
# Epoch [257/1000] | Train Loss: 0.8672 | Train Acc: 0.6875 | Val Loss: 0.9817 | Val Acc: 0.6111 | LR: 0.000846
# EarlyStopping Counter: 39/60
# Epoch [258/1000] | Train Loss: 0.8777 | Train Acc: 0.6667 | Val Loss: 1.0036 | Val Acc: 0.6056 | LR: 0.000845
# EarlyStopping Counter: 40/60
# Epoch [259/1000] | Train Loss: 0.8418 | Train Acc: 0.7042 | Val Loss: 0.9714 | Val Acc: 0.6194 | LR: 0.000844
# EarlyStopping Counter: 41/60
# Epoch [260/1000] | Train Loss: 0.8310 | Train Acc: 0.7069 | Val Loss: 0.9869 | Val Acc: 0.6028 | LR: 0.000842
# EarlyStopping Counter: 42/60
# Epoch [261/1000] | Train Loss: 0.8705 | Train Acc: 0.6875 | Val Loss: 1.0006 | Val Acc: 0.5944 | LR: 0.000841
# EarlyStopping Counter: 43/60
# Epoch [262/1000] | Train Loss: 0.8882 | Train Acc: 0.6806 | Val Loss: 0.9838 | Val Acc: 0.6194 | LR: 0.000840
# EarlyStopping Counter: 44/60
# Epoch [263/1000] | Train Loss: 0.8760 | Train Acc: 0.6653 | Val Loss: 0.9954 | Val Acc: 0.6083 | LR: 0.000839
# EarlyStopping Counter: 45/60
# Epoch [264/1000] | Train Loss: 0.8353 | Train Acc: 0.7125 | Val Loss: 0.9796 | Val Acc: 0.6167 | LR: 0.000838
# EarlyStopping Counter: 46/60
# Epoch [265/1000] | Train Loss: 0.8857 | Train Acc: 0.6750 | Val Loss: 0.9879 | Val Acc: 0.6083 | LR: 0.000837
# EarlyStopping Counter: 47/60
# Epoch [266/1000] | Train Loss: 0.8315 | Train Acc: 0.7000 | Val Loss: 0.9662 | Val Acc: 0.6250 | LR: 0.000836
# EarlyStopping Counter: 48/60
# Epoch [267/1000] | Train Loss: 0.8373 | Train Acc: 0.7125 | Val Loss: 0.9901 | Val Acc: 0.5972 | LR: 0.000834
# EarlyStopping Counter: 49/60
# Epoch [268/1000] | Train Loss: 0.8313 | Train Acc: 0.7042 | Val Loss: 0.9849 | Val Acc: 0.6028 | LR: 0.000833
# EarlyStopping Counter: 50/60
# Epoch [269/1000] | Train Loss: 0.8285 | Train Acc: 0.7028 | Val Loss: 0.9851 | Val Acc: 0.6278 | LR: 0.000832
# EarlyStopping Counter: 51/60
# Epoch [270/1000] | Train Loss: 0.8356 | Train Acc: 0.7139 | Val Loss: 0.9739 | Val Acc: 0.6250 | LR: 0.000831
# EarlyStopping Counter: 52/60
# Epoch [271/1000] | Train Loss: 0.8228 | Train Acc: 0.7069 | Val Loss: 0.9704 | Val Acc: 0.6167 | LR: 0.000830
# EarlyStopping Counter: 53/60
# Epoch [272/1000] | Train Loss: 0.8259 | Train Acc: 0.7042 | Val Loss: 0.9888 | Val Acc: 0.5861 | LR: 0.000828
# EarlyStopping Counter: 54/60
# Epoch [273/1000] | Train Loss: 0.8542 | Train Acc: 0.6861 | Val Loss: 0.9856 | Val Acc: 0.6222 | LR: 0.000827
# EarlyStopping Counter: 55/60
# Epoch [274/1000] | Train Loss: 0.8592 | Train Acc: 0.6847 | Val Loss: 0.9651 | Val Acc: 0.6222 | LR: 0.000826
# EarlyStopping Counter: 56/60
# Epoch [275/1000] | Train Loss: 0.8481 | Train Acc: 0.6972 | Val Loss: 0.9646 | Val Acc: 0.6111 | LR: 0.000825
# EarlyStopping Counter: 57/60
# Epoch [276/1000] | Train Loss: 0.7752 | Train Acc: 0.7319 | Val Loss: 0.9836 | Val Acc: 0.6139 | LR: 0.000824
# EarlyStopping Counter: 58/60
# Epoch [277/1000] | Train Loss: 0.8276 | Train Acc: 0.7000 | Val Loss: 0.9791 | Val Acc: 0.6194 | LR: 0.000823
# EarlyStopping Counter: 59/60
# Epoch [278/1000] | Train Loss: 0.8272 | Train Acc: 0.6986 | Val Loss: 0.9928 | Val Acc: 0.5944 | LR: 0.000821
# EarlyStopping Counter: 60/60
#
# 🛑 Early Stopping Triggered!
#
# ============================================================
# Best Epoch        : 218
# Best Val Accuracy : 0.6361
# ============================================================
# --------------------------------------------------
# Test input shape : torch.Size([1, 22, 800])
# Test output shape: torch.Size([1, 4])
# Predicted class  : 0

# %% [markdown]
# ## 绘图（loss/acc/混淆矩阵）

# %%
import matplotlib.pyplot as plt

from sklearn.metrics import (
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report
)


# =====================================================
# 如果前面训练代码里已经定义过，这里可以不用重复定义
# 但为了防止单独运行这个 cell 报错，这里保留一遍
# =====================================================
CROP_LEN = 750
CROP_STARTS = [0, 25, 50]


def crop_tta_predict(model, x, crop_len=750, starts=[0, 25, 50]):
    """
    x shape: (B, C, T)
    对同一个样本取多个 crop，平均 logits。
    """
    logits_sum = 0

    for start in starts:

        end = start + crop_len

        x_crop = x[:, :, start:end]

        logits_sum += model(x_crop)

    return logits_sum / len(starts)


# =====================================================
# 混淆矩阵
# =====================================================
all_preds = []
all_labels = []

model.eval()

with torch.no_grad():

    for val_data, val_label in val_loader:

        val_data = val_data.to(device)
        val_label = val_label.to(device)

        # 关键修改：
        # 原来是 val_output = model(val_data)
        # 现在模型输入长度是 750，所以要用 crop TTA
        val_output = crop_tta_predict(
            model,
            val_data,
            crop_len=CROP_LEN,
            starts=CROP_STARTS
        )

        val_pred = torch.argmax(
            val_output,
            dim=1
        )

        all_preds.extend(
            val_pred.cpu().numpy()
        )

        all_labels.extend(
            val_label.cpu().numpy()
        )


cm = confusion_matrix(
    all_labels,
    all_preds,
    labels=[0, 1, 2, 3]
)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=[
        "Left Hand",
        "Right Hand",
        "Foot",
        "Tongue"
    ]
)

fig, ax = plt.subplots(figsize=(7, 7))

disp.plot(
    cmap="Blues",
    values_format="d",
    ax=ax
)

plt.title("4-Class Confusion Matrix")
plt.show()


# =====================================================
# Classification Report
# =====================================================
print("\nClassification Report:\n")

print(
    classification_report(
        all_labels,
        all_preds,
        target_names=[
            "Left Hand",
            "Right Hand",
            "Foot",
            "Tongue"
        ],
        digits=4
    )
)


# =====================================================
# Test 推理
# =====================================================
model.eval()

with torch.no_grad():

    test_data = next(iter(test_loader))

    test_data = test_data.to(device)

    # 关键修改：
    # 原来是 test_output = model(test_data)
    # 现在也要用 crop TTA
    test_output = crop_tta_predict(
        model,
        test_data,
        crop_len=CROP_LEN,
        starts=CROP_STARTS
    )

    test_pred = torch.argmax(
        test_output,
        dim=1
    )

print("-" * 50)
print("Test input shape :", test_data.shape)
print("Test output shape:", test_output.shape)
print("Predicted class  :", test_pred.item())
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#    Left Hand     0.6806    0.5444    0.6049        90
#   Right Hand     0.5686    0.6444    0.6042        90
#         Foot     0.5755    0.6778    0.6224        90
#       Tongue     0.7125    0.6333    0.6706        90
#
#     accuracy                         0.6250       360
#    macro avg     0.6343    0.6250    0.6255       360
# weighted avg     0.6343    0.6250    0.6255       360
#
# --------------------------------------------------
# Test input shape : torch.Size([1, 22, 800])
# Test output shape: torch.Size([1, 4])
# Predicted class  : 0

# %% [markdown]
# ## 生成并保存 test 预测标签
# 使用当前训练好的 `model` 在测试集推理，把预测类别按“每行一个数字”写入文本文件。

# %%
# =====================================================
# 保存 test 预测标签：每行一个数字
# 使用最佳模型 + crop TTA
# =====================================================
model.load_state_dict(best_model_state)
model.eval()

output_path = r"C:/Users/yyy/Desktop/course project/BCIC2A/BCIC2A.txt"

all_test_labels = []

with torch.no_grad():

    for test_data in test_loader:

        test_data = test_data.to(device)

        # 关键修改：
        # 原来是 test_output = model(test_data)
        # 现在模型输入是 750 点，所以用 crop TTA
        test_output = crop_tta_predict(
            model,
            test_data,
            crop_len=CROP_LEN,
            starts=CROP_STARTS
        )

        test_pred = torch.argmax(
            test_output,
            dim=1
        )

        all_test_labels.extend(
            test_pred.cpu().tolist()
        )

with open(output_path, "w", encoding="utf-8") as f:

    for label in all_test_labels:

        f.write(f"{int(label)}\n")

print(f"Saved {len(all_test_labels)} labels to: {output_path}")
# Out:
# Saved 360 labels to: C:/Users/yyy/Desktop/course project/BCIC2A/BCIC2A.txt
