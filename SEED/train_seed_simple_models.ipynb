# %% [markdown]
# # SEED Simple Models
#
# This notebook compares several simple SEED classifiers. It keeps the best two routes observed in `train_seed_ensemble.ipynb` (`EEGGRU / BiGRU` and `Covariance + LogisticRegression`) and adds lightweight baselines for comparison.
#
# It also adds two lightweight neural ensemble variants: a `SimpleMoEClassifier` and a `HybridExpertRouter`. The DMD residual route remains available, but is optional and disabled by default through `RUN_DMD = False`. The weakest two validation routes from the latest run are removed, and the notebook now runs a compact tuning sweep by default around the strongest MoE/router/BiGRU families; every torch checkpoint also writes a same-basename `.txt` prediction file. It also includes an uncertainty-aware hybrid route that gives expert branches more influence on low-margin, high-entropy samples.

# %% [markdown]
# ## 1) Set data paths and inspect data shape
#
# Use the official SEED train, validation, and test H5 files. The test set is read without labels and must keep its original order.

# %%
import os
import random
from dataclasses import dataclass

import h5py
import numpy as np

DATA_NAME = "SEED"
INDEX_PATH_TRAIN = f"G:/MLproject/course_project/{DATA_NAME}/train.h5"
INDEX_PATH_VAL = f"G:/MLproject/course_project/{DATA_NAME}/val.h5"
INDEX_PATH_TEST = f"G:/MLproject/course_project/{DATA_NAME}/test_x_only.h5"

with h5py.File(INDEX_PATH_TRAIN, "r") as f:
    print("keys:", list(f.keys()))
    print("x dtype:", f["X"].dtype)
    print("x shape:", f["X"].shape)
    print("y dtype:", f["y"].dtype)
    print("y shape:", f["y"].shape)
    print("unique labels:", np.unique(f["y"][()]))
# Out:
# keys: ['X', 'y']
# x dtype: float32
# x shape: (1000, 62, 400)
# y dtype: int64
# y shape: (1000,)
# unique labels: [0 1 2]

# %% [markdown]
# ## 2) Simple feature routes
#
# The sklearn routes are intentionally small: bandpower, statistical summaries, covariance/correlation structure, and frequency-domain SVC baselines.

# %%
DEFAULT_BANDS = (
    ("delta", 1.0, 4.0),
    ("theta", 4.0, 8.0),
    ("alpha", 8.0, 13.0),
    ("beta", 13.0, 30.0),
    ("gamma", 30.0, 75.0),
)


def read_h5_xy(path):
    with h5py.File(path, "r") as f:
        return f["X"][()].astype(np.float32), f["y"][()].astype(np.int64)


def read_h5_x(path):
    with h5py.File(path, "r") as f:
        return f["X"][()].astype(np.float32)


@dataclass
class FeatureStandardizer:
    mean_: np.ndarray | None = None
    scale_: np.ndarray | None = None

    def fit(self, x):
        self.mean_ = x.mean(axis=0, keepdims=True)
        self.scale_ = x.std(axis=0, keepdims=True)
        self.scale_ = np.where(self.scale_ < 1e-12, 1.0, self.scale_)
        return self

    def transform(self, x):
        if self.mean_ is None or self.scale_ is None:
            raise RuntimeError("FeatureStandardizer must be fitted before transform().")
        return (x - self.mean_) / self.scale_

    def fit_transform(self, x):
        return self.fit(x).transform(x)


def make_band_power_matrix(x, sfreq=200.0, bands=DEFAULT_BANDS, eps=1e-12):
    x = np.asarray(x, dtype=np.float64)
    if x.ndim != 3:
        raise ValueError(f"Expected x shape (samples, channels, time), got {x.shape}.")
    n_times = x.shape[-1]
    x = x - x.mean(axis=-1, keepdims=True)
    window = np.hanning(n_times)
    freqs = np.fft.rfftfreq(n_times, d=1.0 / sfreq)
    df = freqs[1] - freqs[0] if len(freqs) > 1 else sfreq
    psd = (np.abs(np.fft.rfft(x * window, axis=-1)) ** 2) / (sfreq * np.sum(window**2))
    features = []
    for _, low, high in bands:
        mask = (freqs >= low) & (freqs < high)
        power = psd[..., mask].sum(axis=-1) * df
        features.append(np.maximum(power, eps))
    return np.stack(features, axis=-1)


def make_bandpower_features(x, sfreq=200.0, bands=DEFAULT_BANDS, log_power=True, relative=True, eps=1e-12):
    band_power = make_band_power_matrix(x, sfreq=sfreq, bands=bands, eps=eps)
    if relative:
        total_power = np.maximum(band_power.sum(axis=-1, keepdims=True), eps)
        band_power = band_power / total_power
    if log_power:
        band_power = np.log(band_power + eps)
    return band_power.reshape(band_power.shape[0], -1).astype(np.float32)


def make_differential_entropy_features(x, sfreq=200.0, bands=DEFAULT_BANDS, eps=1e-12):
    band_power = make_band_power_matrix(x, sfreq=sfreq, bands=bands, eps=eps)
    de = 0.5 * np.log(2.0 * np.pi * np.e * np.maximum(band_power, eps))
    return de.reshape(de.shape[0], -1).astype(np.float32)


def make_bandpower_de_features(x, sfreq=200.0, bands=DEFAULT_BANDS):
    bandpower = make_bandpower_features(x, sfreq=sfreq, bands=bands, log_power=True, relative=True)
    de = make_differential_entropy_features(x, sfreq=sfreq, bands=bands)
    return np.concatenate([bandpower, de], axis=1).astype(np.float32)


def make_statistical_features(x):
    x = np.asarray(x, dtype=np.float64)
    features = [
        x.mean(axis=-1),
        x.std(axis=-1),
        np.sqrt(np.mean(x**2, axis=-1)),
        x.min(axis=-1),
        x.max(axis=-1),
        np.ptp(x, axis=-1),
        np.quantile(x, 0.25, axis=-1),
        np.quantile(x, 0.50, axis=-1),
        np.quantile(x, 0.75, axis=-1),
    ]
    return np.concatenate(features, axis=1).astype(np.float32)


def make_covariance_features(x, eps=1e-6):
    x = np.asarray(x, dtype=np.float64)
    tri = np.triu_indices(x.shape[1])
    features = []
    for sample in x:
        centered = sample - sample.mean(axis=1, keepdims=True)
        cov = centered @ centered.T / max(centered.shape[1] - 1, 1)
        diag_scale = np.sqrt(np.maximum(np.diag(cov), eps))
        corr_like = cov / (diag_scale[:, None] * diag_scale[None, :])
        features.append(corr_like[tri])
    return np.asarray(features, dtype=np.float32)


def accuracy(y_true, y_pred):
    return float(np.mean(np.asarray(y_true) == np.asarray(y_pred)))


def predict_proba_aligned(model, x, classes=np.arange(3)):
    if hasattr(model, "predict_proba"):
        raw = model.predict_proba(x)
    else:
        raw = np.eye(len(classes), dtype=np.float64)[model.predict(x)]
    aligned = np.zeros((x.shape[0], len(classes)), dtype=np.float64)
    for src_idx, cls in enumerate(getattr(model, "classes_", classes)):
        dst_idx = int(np.where(classes == cls)[0][0])
        aligned[:, dst_idx] = raw[:, src_idx]
    return aligned

# %% [markdown]
# ## 2b) DMD residual rank ensemble
#
# This route learns one low-rank DMD transition system per class and per configuration, scores validation/test trials by class-conditional one-step residuals, then rank-normalizes scores before averaging across configurations.

# %%
@dataclass(frozen=True)
class DMDConfig:
    rank: int
    time_window: tuple[int, int]
    normalization: str = "channel_zscore"
    residual_metric: str = "mse"


def ensure_eeg_channel_time(x, expected_channels=None, expected_timepoints=None):
    expected_channels = CHANNELS if expected_channels is None else expected_channels
    expected_timepoints = TIME_POINTS if expected_timepoints is None else expected_timepoints
    x = np.asarray(x, dtype=np.float64)
    if x.ndim == 2:
        x = x[None, ...]
    if x.ndim != 3:
        raise ValueError(f"Expected EEG array with 3 dims, got shape {x.shape}.")
    if x.shape[1] == expected_channels:
        return x
    if x.shape[2] == expected_channels:
        return np.transpose(x, (0, 2, 1))
    if x.shape[1] == expected_timepoints and x.shape[2] != expected_timepoints:
        return np.transpose(x, (0, 2, 1))
    raise ValueError(f"Cannot infer channel/time axes for shape {x.shape}.")


def normalize_dmd_trials(x, normalization, eps=1e-8):
    x = np.asarray(x, dtype=np.float64)
    normalization = normalization.lower().replace("-", "_").replace(" ", "_")
    normalization = {
        "per_trial_z_score": "trial_zscore",
        "per_trial_zscore": "trial_zscore",
        "per_channel_z_score": "channel_zscore",
        "per_channel_zscore": "channel_zscore",
    }.get(normalization, normalization)
    if normalization == "raw":
        return x
    if normalization == "trial_zscore":
        mean = x.mean(axis=(1, 2), keepdims=True)
        scale = x.std(axis=(1, 2), keepdims=True)
    elif normalization == "channel_zscore":
        mean = x.mean(axis=2, keepdims=True)
        scale = x.std(axis=2, keepdims=True)
    else:
        raise ValueError(f"Unknown DMD normalization: {normalization}")
    return (x - mean) / np.maximum(scale, eps)


def select_dmd_window(x, config):
    start, end = config.time_window
    end = min(end, x.shape[-1])
    start = max(0, min(start, end - 2))
    if end - start < 2:
        raise ValueError(f"DMD time_window {config.time_window} is too short for shape {x.shape}.")
    return x[..., start:end]


def fit_dmd_system(X_train_class, config, svd_eps=1e-10):
    x = ensure_eeg_channel_time(X_train_class)
    x = select_dmd_window(x, config)
    x = normalize_dmd_trials(x, config.normalization)
    x_past = np.transpose(x[:, :, :-1], (1, 0, 2)).reshape(x.shape[1], -1)
    x_future = np.transpose(x[:, :, 1:], (1, 0, 2)).reshape(x.shape[1], -1)
    x_past = np.nan_to_num(x_past, copy=False)
    x_future = np.nan_to_num(x_future, copy=False)
    u, s, vt = np.linalg.svd(x_past, full_matrices=False)
    usable = int(np.sum(s > svd_eps))
    r = max(1, min(int(config.rank), usable, u.shape[1]))
    u_r = u[:, :r]
    s_r = s[:r]
    vt_r = vt[:r, :]
    return (x_future @ vt_r.T) @ ((1.0 / s_r)[:, None] * u_r.T)


def compute_dmd_residual(sample, A, config, eps=1e-8):
    residuals = compute_dmd_residual_batch(np.asarray(sample)[None, ...], A, config, eps=eps)
    return float(residuals[0])


def compute_dmd_residual_batch(X, A, config, eps=1e-8):
    metric = config.residual_metric.lower().replace("-", "_").replace(" ", "_")
    x = ensure_eeg_channel_time(X)
    x = select_dmd_window(x, config)
    x = normalize_dmd_trials(x, config.normalization)
    past = x[:, :, :-1]
    future = x[:, :, 1:]
    pred = np.einsum("ij,njt->nit", A, past, optimize=True)
    err = future - pred
    if metric == "mse":
        return np.mean(err**2, axis=(1, 2))
    if metric == "mae":
        return np.mean(np.abs(err), axis=(1, 2))
    if metric == "relative_error":
        num = np.sqrt(np.sum(err**2, axis=(1, 2)))
        den = np.sqrt(np.sum(future**2, axis=(1, 2)))
        return num / np.maximum(den, eps)
    if metric == "correlation_error":
        pred_flat = pred.reshape(pred.shape[0], -1)
        future_flat = future.reshape(future.shape[0], -1)
        pred_flat = pred_flat - pred_flat.mean(axis=1, keepdims=True)
        future_flat = future_flat - future_flat.mean(axis=1, keepdims=True)
        corr = np.sum(pred_flat * future_flat, axis=1) / np.maximum(
            np.linalg.norm(pred_flat, axis=1) * np.linalg.norm(future_flat, axis=1), eps
        )
        return 1.0 - corr
    raise ValueError(f"Unknown DMD residual metric: {config.residual_metric}")


def rank_transform_scores(scores):
    scores = np.asarray(scores, dtype=np.float64)
    ranks = np.empty_like(scores, dtype=np.float64)
    n_samples = scores.shape[0]
    if n_samples <= 1:
        return np.ones_like(scores, dtype=np.float64)
    for class_idx in range(scores.shape[1]):
        order = np.argsort(scores[:, class_idx], kind="mergesort")
        rank = np.empty(n_samples, dtype=np.float64)
        rank[order] = np.arange(n_samples, dtype=np.float64)
        ranks[:, class_idx] = rank / (n_samples - 1)
    return ranks


def build_default_dmd_configs():
    ranks = (2, 4, 6, 8, 10)
    windows = ((0, 400), (80, 320), (100, 300), (240, 400))
    normalizations = ("channel_zscore",)
    metrics = ("mse", "relative_error")
    return [
        DMDConfig(rank=rank, time_window=window, normalization=norm, residual_metric=metric)
        for rank in ranks
        for window in windows
        for norm in normalizations
        for metric in metrics
    ]


class DMDEnsembleClassifier:
    def __init__(self, configs=None, classes=None):
        self.configs = list(configs) if configs is not None else build_default_dmd_configs()
        self.classes = None if classes is None else np.asarray(classes, dtype=np.int64)
        self.systems_ = []

    def fit(self, X_train, y_train):
        X_train = ensure_eeg_channel_time(X_train)
        y_train = np.asarray(y_train, dtype=np.int64)
        self.classes_ = np.unique(y_train) if self.classes is None else self.classes
        self.systems_ = []
        for config in self.configs:
            class_systems = []
            for cls in self.classes_:
                class_x = X_train[y_train == cls]
                if class_x.shape[0] == 0:
                    raise ValueError(f"No training samples for class {cls}.")
                class_systems.append(fit_dmd_system(class_x, config))
            self.systems_.append(class_systems)
        return self

    def predict_scores(self, X):
        if not self.systems_:
            raise RuntimeError("DMDEnsembleClassifier must be fitted before predict_scores().")
        X = ensure_eeg_channel_time(X)
        config_rank_scores = []
        for config, class_systems in zip(self.configs, self.systems_):
            raw_scores = np.column_stack([
                -compute_dmd_residual_batch(X, A, config)
                for A in class_systems
            ])
            config_rank_scores.append(rank_transform_scores(raw_scores))
        return np.mean(config_rank_scores, axis=0)

    def predict(self, X, force_balanced=False):
        scores = self.predict_scores(X)
        if not force_balanced:
            return self.classes_[np.argmax(scores, axis=1)]
        n_samples, n_classes = scores.shape
        base = n_samples // n_classes
        counts = np.full(n_classes, base, dtype=int)
        counts[: n_samples % n_classes] += 1
        pred = np.full(n_samples, -1, dtype=int)
        margins = scores.max(axis=1) - np.partition(scores, -2, axis=1)[:, -2]
        for sample_idx in np.argsort(-margins):
            for class_idx in np.argsort(-scores[sample_idx]):
                if counts[class_idx] > 0:
                    pred[sample_idx] = self.classes_[class_idx]
                    counts[class_idx] -= 1
                    break
        return pred


def softmax_from_scores(scores):
    scores = np.asarray(scores, dtype=np.float64)
    shifted = scores - scores.max(axis=1, keepdims=True)
    exp_scores = np.exp(shifted)
    return exp_scores / np.maximum(exp_scores.sum(axis=1, keepdims=True), 1e-12)


def print_classification_report(name, y_true, y_pred):
    labels = np.arange(CLASSES)
    macro_f1 = f1_score(y_true, y_pred, labels=labels, average="macro", zero_division=0)
    recalls = recall_score(y_true, y_pred, labels=labels, average=None, zero_division=0)
    cm = confusion_matrix(y_true, y_pred, labels=labels)
    ratio = np.bincount(np.asarray(y_pred, dtype=int), minlength=CLASSES) / len(y_pred)
    print(f"{name} validation accuracy: {accuracy(y_true, y_pred):.4f}")
    print(f"{name} macro F1: {macro_f1:.4f}")
    for cls, recall in zip(labels, recalls):
        print(f"{name} recall class {cls}: {recall:.4f}")
    print(f"{name} confusion matrix:\n{cm}")
    print(f"{name} predicted class ratio: {np.round(ratio, 4)}")


def fit_dmd_route(name="DMD Residual Rank Ensemble"):
    print("\n" + "=" * 60)
    print(f"Training {name}")
    classifier = DMDEnsembleClassifier(classes=np.arange(CLASSES))
    print(f"DMD configs: {len(classifier.configs)}")
    classifier.fit(train_x, train_y)
    train_scores = classifier.predict_scores(train_x)
    val_scores = classifier.predict_scores(val_x)
    test_scores = classifier.predict_scores(test_x)
    train_prob = softmax_from_scores(train_scores)
    val_prob = softmax_from_scores(val_scores)
    test_prob = softmax_from_scores(test_scores)
    train_pred = np.argmax(train_prob, axis=1)
    val_pred = np.argmax(val_prob, axis=1)
    train_acc = accuracy(train_y, train_pred)
    val_acc = accuracy(val_y, val_pred)
    print_classification_report(name, val_y, val_pred)
    print(f"{name} Train Accuracy: {train_acc:.4f}")
    print(f"{name} Val Accuracy: {val_acc:.4f}")
    return {"name": name, "train_acc": train_acc, "val_acc": val_acc, "val_prob": val_prob, "test_prob": test_prob}

# %% [markdown]
# ## 3) Neural routes: EEGGRU, Simple MoE, Hybrid Router, Uncertainty-Aware Router
#
# The notebook keeps the known strong `EEGGRU / BiGRU` configuration and adds three compact mixture-style neural baselines that can be trained with the same loop.

# %%
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from RNN import EEGGRU
from course_project.TEST_DATASET import TrainDataset, TestDataset

SEED = 3407
CHANNELS = 62
TIME_POINTS = 400
CLASSES = 3
SFREQ = 200.0
BATCH_SIZE = 32
EPOCHS = 160
PATIENCE = 24
MIN_DELTA = 1e-4
ENSEMBLE_MIN_VAL_ACC = 0.42
ENSEMBLE_WEIGHT_POWER = 2.5
RUN_DMD = True
RUN_TUNING_SWEEP = True
TOP_K_ENSEMBLE = 5
USE_CUDA = torch.cuda.is_available()
device = torch.device("cuda" if USE_CUDA else "cpu")
print("device:", device)


def set_global_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed)


set_global_seed(SEED)


def eeg_stat_features(x, eps=1e-6):
    mean = x.mean(dim=-1)
    std = x.std(dim=-1, unbiased=False)
    rms = torch.sqrt(torch.mean(x.square(), dim=-1) + eps)
    peak_to_peak = x.amax(dim=-1) - x.amin(dim=-1)
    return torch.cat([mean, std, rms, peak_to_peak], dim=1)


class SimpleMoEClassifier(nn.Module):
    def __init__(self, chans=CHANNELS, num_classes=CLASSES, hidden_dim=48, num_experts=4, dropout=0.25):
        super().__init__()
        kernels = (3, 7, 15, 31)[:num_experts]
        self.experts = nn.ModuleList([
            nn.Sequential(
                nn.Conv1d(chans, hidden_dim, kernel_size=kernel, padding=kernel // 2, bias=False),
                nn.BatchNorm1d(hidden_dim),
                nn.GELU(),
                nn.Dropout(dropout),
                nn.Conv1d(hidden_dim, hidden_dim, kernel_size=3, padding=1, groups=hidden_dim, bias=False),
                nn.BatchNorm1d(hidden_dim),
                nn.GELU(),
                nn.AdaptiveAvgPool1d(1),
                nn.Flatten(),
                nn.Linear(hidden_dim, num_classes),
            )
            for kernel in kernels
        ])
        self.router = nn.Sequential(
            nn.Linear(chans * 4, hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, len(self.experts)),
        )

    def forward(self, x):
        route_logits = self.router(eeg_stat_features(x))
        route_weights = torch.softmax(route_logits, dim=1)
        expert_logits = torch.stack([expert(x) for expert in self.experts], dim=1)
        return torch.sum(route_weights.unsqueeze(-1) * expert_logits, dim=1)

    def clip_gradients(self, max_norm=1.0):
        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm)



class UncertaintyAwareHybridRouter(nn.Module):
    def __init__(self, chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, dropout=0.30, uncertainty_threshold=0.18, uncertainty_sharpness=12.0):
        super().__init__()
        self.uncertainty_threshold = uncertainty_threshold
        self.uncertainty_sharpness = uncertainty_sharpness
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=9, padding=4, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=5, padding=2, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
        )
        self.base_head = nn.Sequential(
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(hidden_dim, num_classes),
        )
        self.slow_expert = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=33, padding=16, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(hidden_dim, num_classes),
        )
        self.fast_expert = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=5, padding=2, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.AdaptiveMaxPool1d(1),
            nn.Flatten(),
            nn.Linear(hidden_dim, num_classes),
        )
        self.stat_expert = nn.Sequential(
            nn.Linear(chans * 4, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes),
        )
        self.router = nn.Sequential(
            nn.Linear(chans * 4 + hidden_dim + 3, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 3),
        )

    def uncertainty_features(self, base_logits):
        base_prob = torch.softmax(base_logits, dim=1)
        top2 = torch.topk(base_prob, k=2, dim=1).values
        confidence = top2[:, :1]
        margin = top2[:, :1] - top2[:, 1:2]
        entropy = -(base_prob * torch.log(base_prob.clamp_min(1e-8))).sum(dim=1, keepdim=True) / np.log(base_prob.shape[1])
        return torch.cat([confidence, margin, entropy], dim=1), margin

    def forward(self, x):
        stats = eeg_stat_features(x)
        encoded = self.temporal_encoder(x)
        pooled = encoded.mean(dim=-1)
        base_logits = self.base_head(encoded)
        uncertainty_features, margin = self.uncertainty_features(base_logits)
        route_input = torch.cat([stats, pooled, uncertainty_features], dim=1)
        route_weights = torch.softmax(self.router(route_input), dim=1)
        expert_logits = torch.stack([
            self.slow_expert(x),
            self.fast_expert(x),
            self.stat_expert(stats),
        ], dim=1)
        expert_mix = torch.sum(route_weights.unsqueeze(-1) * expert_logits, dim=1)
        uncertainty_weight = torch.sigmoid((self.uncertainty_threshold - margin) * self.uncertainty_sharpness)
        return (1.0 - uncertainty_weight) * base_logits + uncertainty_weight * expert_mix

    def clip_gradients(self, max_norm=1.0):
        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm)


class HybridExpertRouter(nn.Module):
    def __init__(self, chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, dropout=0.30):
        super().__init__()
        self.temporal_encoder = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=9, padding=4, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Conv1d(hidden_dim, hidden_dim, kernel_size=5, padding=2, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
        )
        self.slow_expert = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=33, padding=16, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.AdaptiveAvgPool1d(1),
            nn.Flatten(),
            nn.Linear(hidden_dim, num_classes),
        )
        self.fast_expert = nn.Sequential(
            nn.Conv1d(chans, hidden_dim, kernel_size=5, padding=2, bias=False),
            nn.BatchNorm1d(hidden_dim),
            nn.GELU(),
            nn.AdaptiveMaxPool1d(1),
            nn.Flatten(),
            nn.Linear(hidden_dim, num_classes),
        )
        self.stat_expert = nn.Sequential(
            nn.Linear(chans * 4, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, num_classes),
        )
        self.router = nn.Sequential(
            nn.Linear(chans * 4 + hidden_dim, hidden_dim),
            nn.LayerNorm(hidden_dim),
            nn.GELU(),
            nn.Dropout(dropout),
            nn.Linear(hidden_dim, 3),
        )

    def forward(self, x):
        stats = eeg_stat_features(x)
        encoded = self.temporal_encoder(x)
        pooled = encoded.mean(dim=-1)
        route_weights = torch.softmax(self.router(torch.cat([stats, pooled], dim=1)), dim=1)
        expert_logits = torch.stack([
            self.slow_expert(x),
            self.fast_expert(x),
            self.stat_expert(stats),
        ], dim=1)
        return torch.sum(route_weights.unsqueeze(-1) * expert_logits, dim=1)

    def clip_gradients(self, max_norm=1.0):
        torch.nn.utils.clip_grad_norm_(self.parameters(), max_norm)
# Out:
# device: cuda

# %% [markdown]
# ## 6) Prepare DataLoader and train/validate
#
# Train every route, record validation accuracy, and prepare probability outputs for final selection.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix, f1_score, recall_score
from sklearn.decomposition import PCA
from sklearn.svm import SVC

train_x, train_y = read_h5_xy(INDEX_PATH_TRAIN)
val_x, val_y = read_h5_xy(INDEX_PATH_VAL)
test_x = read_h5_x(INDEX_PATH_TEST)

train_ds = TrainDataset(INDEX_PATH_TRAIN)
val_ds = TrainDataset(INDEX_PATH_VAL)
test_ds = TestDataset(INDEX_PATH_TEST)

train_generator = torch.Generator().manual_seed(SEED)
train_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=True, generator=train_generator, pin_memory=USE_CUDA)
train_eval_loader = DataLoader(train_ds, batch_size=BATCH_SIZE, shuffle=False, pin_memory=USE_CUDA)
val_loader = DataLoader(val_ds, batch_size=BATCH_SIZE, shuffle=False, pin_memory=USE_CUDA)
test_loader = DataLoader(test_ds, batch_size=1, shuffle=False, pin_memory=USE_CUDA)

print("train X:", train_x.shape, "train y:", train_y.shape)
print("val X:", val_x.shape, "val y:", val_y.shape)
print("test X:", test_x.shape)

def write_labels(path, labels):
    os.makedirs(os.path.dirname(path), exist_ok=True)
    with open(path, "w", encoding="utf-8") as f:
        for label in labels:
            f.write(f"{int(label)}\n")


def prediction_path_for_checkpoint(checkpoint_path):
    root, _ = os.path.splitext(checkpoint_path)
    return root + ".txt"


def write_labels_for_checkpoint(checkpoint_path, test_prob):
    checkpoint_pred_path = prediction_path_for_checkpoint(checkpoint_path)
    checkpoint_labels = np.argmax(test_prob, axis=1).astype(int).tolist()
    assert len(checkpoint_labels) == len(test_ds), f"Prediction count {len(checkpoint_labels)} != test sample count {len(test_ds)}"
    write_labels(checkpoint_pred_path, checkpoint_labels)
    print(f"Wrote checkpoint predictions to {checkpoint_pred_path}")
    return checkpoint_pred_path


def fit_tabular_route(name, feature_fn, model):
    print("\n" + "=" * 60)
    print(f"Training {name}")
    train_features = feature_fn(train_x)
    val_features = feature_fn(val_x)
    test_features = feature_fn(test_x)
    standardizer = FeatureStandardizer()
    train_features = standardizer.fit_transform(train_features)
    val_features = standardizer.transform(val_features)
    test_features = standardizer.transform(test_features)
    model.fit(train_features, train_y)
    train_prob = predict_proba_aligned(model, train_features, classes=np.arange(CLASSES))
    val_prob = predict_proba_aligned(model, val_features, classes=np.arange(CLASSES))
    test_prob = predict_proba_aligned(model, test_features, classes=np.arange(CLASSES))
    train_acc = accuracy(train_y, np.argmax(train_prob, axis=1))
    val_acc = accuracy(val_y, np.argmax(val_prob, axis=1))
    print("feature shape:", train_features.shape)
    print(f"{name} Train Accuracy: {train_acc:.4f}")
    print(f"{name} Val Accuracy: {val_acc:.4f}")
    return {"name": name, "train_acc": train_acc, "val_acc": val_acc, "val_prob": val_prob, "test_prob": test_prob}


def fit_reduced_tabular_route(name, feature_fn, reducer, model):
    print("\n" + "=" * 60)
    print(f"Training {name}")
    train_features = feature_fn(train_x)
    val_features = feature_fn(val_x)
    test_features = feature_fn(test_x)
    standardizer = FeatureStandardizer()
    train_features = standardizer.fit_transform(train_features)
    val_features = standardizer.transform(val_features)
    test_features = standardizer.transform(test_features)
    original_shape = train_features.shape
    train_features = reducer.fit_transform(train_features)
    val_features = reducer.transform(val_features)
    test_features = reducer.transform(test_features)
    model.fit(train_features, train_y)
    train_prob = predict_proba_aligned(model, train_features, classes=np.arange(CLASSES))
    val_prob = predict_proba_aligned(model, val_features, classes=np.arange(CLASSES))
    test_prob = predict_proba_aligned(model, test_features, classes=np.arange(CLASSES))
    train_acc = accuracy(train_y, np.argmax(train_prob, axis=1))
    val_acc = accuracy(val_y, np.argmax(val_prob, axis=1))
    print("feature shape:", original_shape, "->", train_features.shape)
    print(f"{name} Train Accuracy: {train_acc:.4f}")
    print(f"{name} Val Accuracy: {val_acc:.4f}")
    return {"name": name, "train_acc": train_acc, "val_acc": val_acc, "val_prob": val_prob, "test_prob": test_prob}


def train_torch_route(name, build_model, best_model_path, epochs=EPOCHS, lr=6e-4, weight_decay=8e-4, label_smoothing=0.04, scheduler_patience=6):
    print("\n" + "=" * 60)
    print(f"Training {name}")
    set_global_seed(SEED)
    model = build_model().to(device)
    criterion = nn.CrossEntropyLoss(label_smoothing=label_smoothing)
    optimizer = torch.optim.AdamW(model.parameters(), lr=lr, weight_decay=weight_decay)
    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode="max", factor=0.5, patience=scheduler_patience, min_lr=1e-5)
    best_val_acc = -1.0
    best_epoch = 0
    bad_epochs = 0
    os.makedirs(os.path.dirname(best_model_path), exist_ok=True)
    for epoch in range(epochs):
        model.train()
        train_loss_sum = train_correct = train_num = 0
        for data, label in train_loader:
            data = data.to(device, dtype=torch.float32, non_blocking=USE_CUDA)
            label = label.to(device, dtype=torch.long, non_blocking=USE_CUDA)
            optimizer.zero_grad(set_to_none=True)
            output = model(data)
            loss = criterion(output, label)
            loss.backward()
            model.clip_gradients() if hasattr(model, "clip_gradients") else torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            batch_size = label.size(0)
            train_loss_sum += loss.item() * batch_size
            train_correct += (torch.argmax(output.detach(), dim=1) == label).sum().item()
            train_num += batch_size
        model.eval()
        val_loss_sum = val_correct = val_num = 0
        with torch.no_grad():
            for val_data, val_label in val_loader:
                val_data = val_data.to(device, dtype=torch.float32, non_blocking=USE_CUDA)
                val_label = val_label.to(device, dtype=torch.long, non_blocking=USE_CUDA)
                val_output = model(val_data)
                val_loss = criterion(val_output, val_label)
                batch_size = val_label.size(0)
                val_loss_sum += val_loss.item() * batch_size
                val_correct += (torch.argmax(val_output, dim=1) == val_label).sum().item()
                val_num += batch_size
        epoch_train_loss = train_loss_sum / train_num
        epoch_train_acc = train_correct / train_num
        epoch_val_loss = val_loss_sum / val_num
        epoch_val_acc = val_correct / val_num
        scheduler.step(epoch_val_acc)
        if epoch_val_acc > best_val_acc + MIN_DELTA:
            best_val_acc = epoch_val_acc
            best_epoch = epoch + 1
            bad_epochs = 0
            torch.save(model.state_dict(), best_model_path)
        else:
            bad_epochs += 1
        print(f"Epoch [{epoch + 1:03d}/{epochs}] | Train Loss: {epoch_train_loss:.4f} | Train Acc: {epoch_train_acc:.4f} | Val Loss: {epoch_val_loss:.4f} | Val Acc: {epoch_val_acc:.4f} | Best: {best_val_acc:.4f} @ {best_epoch:03d}")
        if bad_epochs >= PATIENCE:
            print(f"Early stopping at epoch {epoch + 1}; best epoch was {best_epoch}.")
            break
    model.load_state_dict(torch.load(best_model_path, map_location=device))
    model.eval()

    def collect_prob(loader):
        probs = []
        with torch.no_grad():
            for batch in loader:
                data = batch[0] if isinstance(batch, (tuple, list)) else batch
                data = data.to(device, dtype=torch.float32, non_blocking=USE_CUDA)
                probs.append(torch.softmax(model(data), dim=1).cpu().numpy())
        return np.concatenate(probs, axis=0)

    train_prob = collect_prob(train_eval_loader)
    val_prob = collect_prob(val_loader)
    test_prob = collect_prob(test_loader)
    checkpoint_pred_path = write_labels_for_checkpoint(best_model_path, test_prob)
    train_acc = accuracy(train_y, np.argmax(train_prob, axis=1))
    val_acc = accuracy(val_y, np.argmax(val_prob, axis=1))
    print(f"{name} Best Val Accuracy: {best_val_acc:.4f} (epoch {best_epoch})")
    print(f"{name} Recomputed Train Accuracy: {train_acc:.4f}")
    print(f"{name} Recomputed Val Accuracy: {val_acc:.4f}")
    return {"name": name, "train_acc": train_acc, "val_acc": val_acc, "val_prob": val_prob, "test_prob": test_prob, "prediction_path": checkpoint_pred_path}


model_results = []
model_results.append(fit_reduced_tabular_route("BandpowerDE + PCA + LogisticRegression", lambda x: make_bandpower_de_features(x, sfreq=SFREQ), PCA(n_components=0.98, random_state=SEED), LogisticRegression(C=0.5, class_weight="balanced", max_iter=1000, random_state=SEED, solver="lbfgs")))
model_results.append(fit_tabular_route("Covariance + LogisticRegression", make_covariance_features, LogisticRegression(C=0.15, class_weight="balanced", max_iter=1000, random_state=SEED, solver="lbfgs")))
model_results.append(fit_tabular_route("Bandpower + SVC", lambda x: make_bandpower_features(x, sfreq=SFREQ), SVC(C=0.8, kernel="rbf", gamma="scale", class_weight="balanced", probability=True, random_state=SEED)))
model_results.append(fit_tabular_route("Statistical + RandomForest", make_statistical_features, RandomForestClassifier(n_estimators=300, max_depth=8, class_weight="balanced", random_state=SEED, n_jobs=-1)))
if RUN_DMD:
    model_results.append(fit_dmd_route("DMD Residual Rank Ensemble"))
else:
    print("\nSkipping DMD Residual Rank Ensemble because RUN_DMD = False.")

torch_route_specs = [
    # Keep the strongest latest single model and search nearby capacity/dropout settings.
    ("Simple MoE", lambda: SimpleMoEClassifier(chans=CHANNELS, num_classes=CLASSES, hidden_dim=48, num_experts=4, dropout=0.25), f"course_project/{DATA_NAME}/best_seed_simple_models_moe.pt", EPOCHS, 7e-4, 8e-4, 0.04, 6),
    ("Simple MoE h64 dp30", lambda: SimpleMoEClassifier(chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, num_experts=4, dropout=0.30), f"course_project/{DATA_NAME}/best_seed_simple_models_moe_h64_dp30.pt", EPOCHS, 6e-4, 1e-3, 0.05, 6),
    ("Simple MoE h64 dp35", lambda: SimpleMoEClassifier(chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, num_experts=4, dropout=0.35), f"course_project/{DATA_NAME}/best_seed_simple_models_moe_h64_dp35.pt", EPOCHS, 5e-4, 1e-3, 0.06, 7),
    ("Simple MoE h80 dp35", lambda: SimpleMoEClassifier(chans=CHANNELS, num_classes=CLASSES, hidden_dim=80, num_experts=4, dropout=0.35), f"course_project/{DATA_NAME}/best_seed_simple_models_moe_h80_dp35.pt", EPOCHS, 4e-4, 1.2e-3, 0.06, 7),
    ("Simple MoE h96 dp40", lambda: SimpleMoEClassifier(chans=CHANNELS, num_classes=CLASSES, hidden_dim=96, num_experts=4, dropout=0.40), f"course_project/{DATA_NAME}/best_seed_simple_models_moe_h96_dp40.pt", EPOCHS, 4e-4, 1.5e-3, 0.07, 8),
    ("Hybrid Router h48 dp30", lambda: HybridExpertRouter(chans=CHANNELS, num_classes=CLASSES, hidden_dim=48, dropout=0.30), f"course_project/{DATA_NAME}/best_seed_simple_models_hybrid_h48_dp30.pt", EPOCHS, 6e-4, 1e-3, 0.05, 6),
    ("EEGGRU / BiGRU", lambda: EEGGRU(chans=CHANNELS, hidden_dim=96, num_layers=2, num_classes=CLASSES, dropout=0.35, bidirectional=True), f"course_project/{DATA_NAME}/best_seed_simple_models_bigru.pt", EPOCHS, 6e-4, 8e-4, 0.04, 6),
    ("EEGGRU h128 dp45", lambda: EEGGRU(chans=CHANNELS, hidden_dim=128, num_layers=2, num_classes=CLASSES, dropout=0.45, bidirectional=True), f"course_project/{DATA_NAME}/best_seed_simple_models_bigru_h128_dp45.pt", EPOCHS, 4e-4, 1.2e-3, 0.06, 7),
    ("Uncertainty Router h64 t18", lambda: UncertaintyAwareHybridRouter(chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, dropout=0.30, uncertainty_threshold=0.18, uncertainty_sharpness=12.0), f"course_project/{DATA_NAME}/best_seed_simple_models_uncertainty_h64_t18.pt", EPOCHS, 6e-4, 1e-3, 0.05, 6),
]

if RUN_TUNING_SWEEP:
    torch_route_specs.extend([
        ("Uncertainty Router h96 t15", lambda: UncertaintyAwareHybridRouter(chans=CHANNELS, num_classes=CLASSES, hidden_dim=96, dropout=0.35, uncertainty_threshold=0.15, uncertainty_sharpness=14.0), f"course_project/{DATA_NAME}/best_seed_simple_models_uncertainty_h96_t15.pt", EPOCHS, 4e-4, 1.2e-3, 0.06, 7),
        ("Uncertainty Router h64 t22", lambda: UncertaintyAwareHybridRouter(chans=CHANNELS, num_classes=CLASSES, hidden_dim=64, dropout=0.25, uncertainty_threshold=0.22, uncertainty_sharpness=10.0), f"course_project/{DATA_NAME}/best_seed_simple_models_uncertainty_h64_t22.pt", EPOCHS, 6e-4, 8e-4, 0.04, 6),
        ("Hybrid Router h96 dp40", lambda: HybridExpertRouter(chans=CHANNELS, num_classes=CLASSES, hidden_dim=96, dropout=0.40), f"course_project/{DATA_NAME}/best_seed_simple_models_hybrid_h96_dp40.pt", EPOCHS, 4e-4, 1.2e-3, 0.06, 7),
    ])

for route_name, build_model, checkpoint_path, epochs, lr, weight_decay, label_smoothing, scheduler_patience in torch_route_specs:
    model_results.append(train_torch_route(route_name, build_model, checkpoint_path, epochs=epochs, lr=lr, weight_decay=weight_decay, label_smoothing=label_smoothing, scheduler_patience=scheduler_patience))
# Out:
# train X: (1000, 62, 400) train y: (1000,)
# val X: (350, 62, 400) val y: (350,)
# test X: (450, 62, 400)
#
# ============================================================
# Training BandpowerDE + PCA + LogisticRegression
# feature shape: (1000, 620) -> (1000, 206)
# BandpowerDE + PCA + LogisticRegression Train Accuracy: 0.6860
# BandpowerDE + PCA + LogisticRegression Val Accuracy: 0.4286
#
# ============================================================
# Training Covariance + LogisticRegression
# feature shape: (1000, 1953)
# Covariance + LogisticRegression Train Accuracy: 0.9900
# Covariance + LogisticRegression Val Accuracy: 0.4800
#
# ============================================================
# Training Bandpower + SVC
# feature shape: (1000, 310)
# Bandpower + SVC Train Accuracy: 0.6820
# Bandpower + SVC Val Accuracy: 0.4057
#
# ============================================================
# Training Statistical + RandomForest
# feature shape: (1000, 558)
# Statistical + RandomForest Train Accuracy: 1.0000
# Statistical + RandomForest Val Accuracy: 0.4571
#
# ============================================================
# Training DMD Residual Rank Ensemble
# DMD configs: 40
# DMD Residual Rank Ensemble validation accuracy: 0.4229
# DMD Residual Rank Ensemble macro F1: 0.4161
# DMD Residual Rank Ensemble recall class 0: 0.5776
# DMD Residual Rank Ensemble recall class 1: 0.3846
# DMD Residual Rank Ensemble recall class 2: 0.3077
# DMD Residual Rank Ensemble confusion matrix:
# [[67 32 17]
#  [37 45 35]
#  [44 37 36]]
# DMD Residual Rank Ensemble predicted class ratio: [0.4229 0.3257 0.2514]
# DMD Residual Rank Ensemble Train Accuracy: 0.5500
# DMD Residual Rank Ensemble Val Accuracy: 0.4229
#
# ============================================================
# Training Simple MoE
# Epoch [001/160] | Train Loss: 1.0969 | Train Acc: 0.3500 | Val Loss: 1.0942 | Val Acc: 0.3514 | Best: 0.3514 @ 001
# Epoch [002/160] | Train Loss: 1.0826 | Train Acc: 0.4060 | Val Loss: 1.0831 | Val Acc: 0.3971 | Best: 0.3971 @ 002
# Epoch [003/160] | Train Loss: 1.0697 | Train Acc: 0.4690 | Val Loss: 1.0774 | Val Acc: 0.4114 | Best: 0.4114 @ 003
# Epoch [004/160] | Train Loss: 1.0610 | Train Acc: 0.4790 | Val Loss: 1.0718 | Val Acc: 0.4800 | Best: 0.4800 @ 004
# Epoch [005/160] | Train Loss: 1.0525 | Train Acc: 0.4890 | Val Loss: 1.0644 | Val Acc: 0.4229 | Best: 0.4800 @ 004
# Epoch [006/160] | Train Loss: 1.0419 | Train Acc: 0.5000 | Val Loss: 1.0594 | Val Acc: 0.4571 | Best: 0.4800 @ 004
# Epoch [007/160] | Train Loss: 1.0324 | Train Acc: 0.5020 | Val Loss: 1.0560 | Val Acc: 0.4657 | Best: 0.4800 @ 004
# Epoch [008/160] | Train Loss: 1.0254 | Train Acc: 0.5360 | Val Loss: 1.0475 | Val Acc: 0.4657 | Best: 0.4800 @ 004
# Epoch [009/160] | Train Loss: 1.0178 | Train Acc: 0.5200 | Val Loss: 1.0441 | Val Acc: 0.4657 | Best: 0.4800 @ 004
# Epoch [010/160] | Train Loss: 1.0156 | Train Acc: 0.5360 | Val Loss: 1.0419 | Val Acc: 0.4829 | Best: 0.4829 @ 010
# Epoch [011/160] | Train Loss: 1.0047 | Train Acc: 0.5370 | Val Loss: 1.0385 | Val Acc: 0.4800 | Best: 0.4829 @ 010
# Epoch [012/160] | Train Loss: 0.9966 | Train Acc: 0.5390 | Val Loss: 1.0320 | Val Acc: 0.4743 | Best: 0.4829 @ 010
# Epoch [013/160] | Train Loss: 0.9883 | Train Acc: 0.5490 | Val Loss: 1.0322 | Val Acc: 0.4771 | Best: 0.4829 @ 010
# Epoch [014/160] | Train Loss: 0.9815 | Train Acc: 0.5600 | Val Loss: 1.0227 | Val Acc: 0.4629 | Best: 0.4829 @ 010
# Epoch [015/160] | Train Loss: 0.9781 | Train Acc: 0.5570 | Val Loss: 1.0225 | Val Acc: 0.4743 | Best: 0.4829 @ 010
# Epoch [016/160] | Train Loss: 0.9693 | Train Acc: 0.5690 | Val Loss: 1.0213 | Val Acc: 0.4800 | Best: 0.4829 @ 010
# Epoch [017/160] | Train Loss: 0.9628 | Train Acc: 0.5650 | Val Loss: 1.0203 | Val Acc: 0.4686 | Best: 0.4829 @ 010
# Epoch [018/160] | Train Loss: 0.9539 | Train Acc: 0.5760 | Val Loss: 1.0139 | Val Acc: 0.4829 | Best: 0.4829 @ 010
# Epoch [019/160] | Train Loss: 0.9484 | Train Acc: 0.5790 | Val Loss: 1.0189 | Val Acc: 0.4800 | Best: 0.4829 @ 010
# Epoch [020/160] | Train Loss: 0.9448 | Train Acc: 0.5910 | Val Loss: 1.0168 | Val Acc: 0.4857 | Best: 0.4857 @ 020
# Epoch [021/160] | Train Loss: 0.9371 | Train Acc: 0.5940 | Val Loss: 1.0164 | Val Acc: 0.4829 | Best: 0.4857 @ 020
# Epoch [022/160] | Train Loss: 0.9371 | Train Acc: 0.6030 | Val Loss: 1.0091 | Val Acc: 0.4943 | Best: 0.4943 @ 022
# Epoch [023/160] | Train Loss: 0.9305 | Train Acc: 0.6030 | Val Loss: 1.0085 | Val Acc: 0.4857 | Best: 0.4943 @ 022
# Epoch [024/160] | Train Loss: 0.9303 | Train Acc: 0.6070 | Val Loss: 1.0083 | Val Acc: 0.4800 | Best: 0.4943 @ 022
# Epoch [025/160] | Train Loss: 0.9238 | Train Acc: 0.6190 | Val Loss: 1.0035 | Val Acc: 0.4829 | Best: 0.4943 @ 022
# Epoch [026/160] | Train Loss: 0.9287 | Train Acc: 0.5980 | Val Loss: 1.0096 | Val Acc: 0.4886 | Best: 0.4943 @ 022
# Epoch [027/160] | Train Loss: 0.9190 | Train Acc: 0.6050 | Val Loss: 1.0043 | Val Acc: 0.4971 | Best: 0.4971 @ 027
# Epoch [028/160] | Train Loss: 0.9126 | Train Acc: 0.6180 | Val Loss: 0.9995 | Val Acc: 0.4829 | Best: 0.4971 @ 027
# Epoch [029/160] | Train Loss: 0.9106 | Train Acc: 0.6230 | Val Loss: 1.0012 | Val Acc: 0.4800 | Best: 0.4971 @ 027
# Epoch [030/160] | Train Loss: 0.9042 | Train Acc: 0.6260 | Val Loss: 1.0007 | Val Acc: 0.4943 | Best: 0.4971 @ 027
# Epoch [031/160] | Train Loss: 0.9021 | Train Acc: 0.6140 | Val Loss: 0.9959 | Val Acc: 0.5057 | Best: 0.5057 @ 031
# Epoch [032/160] | Train Loss: 0.9014 | Train Acc: 0.6290 | Val Loss: 0.9950 | Val Acc: 0.5029 | Best: 0.5057 @ 031
# Epoch [033/160] | Train Loss: 0.8978 | Train Acc: 0.6160 | Val Loss: 0.9969 | Val Acc: 0.4886 | Best: 0.5057 @ 031
# Epoch [034/160] | Train Loss: 0.8996 | Train Acc: 0.6250 | Val Loss: 0.9977 | Val Acc: 0.5000 | Best: 0.5057 @ 031
# Epoch [035/160] | Train Loss: 0.8940 | Train Acc: 0.6330 | Val Loss: 0.9914 | Val Acc: 0.5143 | Best: 0.5143 @ 035
# Epoch [036/160] | Train Loss: 0.8796 | Train Acc: 0.6490 | Val Loss: 0.9926 | Val Acc: 0.5000 | Best: 0.5143 @ 035
# Epoch [037/160] | Train Loss: 0.8815 | Train Acc: 0.6420 | Val Loss: 0.9926 | Val Acc: 0.5143 | Best: 0.5143 @ 035
# Epoch [038/160] | Train Loss: 0.8799 | Train Acc: 0.6350 | Val Loss: 0.9917 | Val Acc: 0.5057 | Best: 0.5143 @ 035
# Epoch [039/160] | Train Loss: 0.8707 | Train Acc: 0.6600 | Val Loss: 0.9933 | Val Acc: 0.5057 | Best: 0.5143 @ 035
# Epoch [040/160] | Train Loss: 0.8764 | Train Acc: 0.6400 | Val Loss: 0.9909 | Val Acc: 0.5057 | Best: 0.5143 @ 035
# Epoch [041/160] | Train Loss: 0.8656 | Train Acc: 0.6540 | Val Loss: 0.9909 | Val Acc: 0.5143 | Best: 0.5143 @ 035
# Epoch [042/160] | Train Loss: 0.8747 | Train Acc: 0.6390 | Val Loss: 0.9876 | Val Acc: 0.5200 | Best: 0.5200 @ 042
# Epoch [043/160] | Train Loss: 0.8578 | Train Acc: 0.6640 | Val Loss: 0.9889 | Val Acc: 0.5114 | Best: 0.5200 @ 042
# Epoch [044/160] | Train Loss: 0.8632 | Train Acc: 0.6440 | Val Loss: 0.9818 | Val Acc: 0.5000 | Best: 0.5200 @ 042
# Epoch [045/160] | Train Loss: 0.8563 | Train Acc: 0.6630 | Val Loss: 0.9806 | Val Acc: 0.5257 | Best: 0.5257 @ 045
# Epoch [046/160] | Train Loss: 0.8527 | Train Acc: 0.6550 | Val Loss: 0.9793 | Val Acc: 0.4886 | Best: 0.5257 @ 045
# Epoch [047/160] | Train Loss: 0.8513 | Train Acc: 0.6530 | Val Loss: 0.9797 | Val Acc: 0.5171 | Best: 0.5257 @ 045
# Epoch [048/160] | Train Loss: 0.8477 | Train Acc: 0.6580 | Val Loss: 0.9830 | Val Acc: 0.5143 | Best: 0.5257 @ 045
# Epoch [049/160] | Train Loss: 0.8423 | Train Acc: 0.6670 | Val Loss: 0.9811 | Val Acc: 0.5143 | Best: 0.5257 @ 045
# Epoch [050/160] | Train Loss: 0.8508 | Train Acc: 0.6700 | Val Loss: 0.9842 | Val Acc: 0.5143 | Best: 0.5257 @ 045
# Epoch [051/160] | Train Loss: 0.8423 | Train Acc: 0.6740 | Val Loss: 0.9758 | Val Acc: 0.5057 | Best: 0.5257 @ 045
# Epoch [052/160] | Train Loss: 0.8391 | Train Acc: 0.6720 | Val Loss: 0.9761 | Val Acc: 0.5114 | Best: 0.5257 @ 045
# Epoch [053/160] | Train Loss: 0.8211 | Train Acc: 0.6910 | Val Loss: 0.9759 | Val Acc: 0.5200 | Best: 0.5257 @ 045
# Epoch [054/160] | Train Loss: 0.8248 | Train Acc: 0.6820 | Val Loss: 0.9728 | Val Acc: 0.5200 | Best: 0.5257 @ 045
# Epoch [055/160] | Train Loss: 0.8221 | Train Acc: 0.6800 | Val Loss: 0.9742 | Val Acc: 0.5229 | Best: 0.5257 @ 045
# Epoch [056/160] | Train Loss: 0.8222 | Train Acc: 0.6970 | Val Loss: 0.9717 | Val Acc: 0.5200 | Best: 0.5257 @ 045
# Epoch [057/160] | Train Loss: 0.8250 | Train Acc: 0.6950 | Val Loss: 0.9696 | Val Acc: 0.5314 | Best: 0.5314 @ 057
# Epoch [058/160] | Train Loss: 0.8219 | Train Acc: 0.6920 | Val Loss: 0.9756 | Val Acc: 0.5143 | Best: 0.5314 @ 057
# Epoch [059/160] | Train Loss: 0.8160 | Train Acc: 0.6980 | Val Loss: 0.9709 | Val Acc: 0.5229 | Best: 0.5314 @ 057
# Epoch [060/160] | Train Loss: 0.8168 | Train Acc: 0.6850 | Val Loss: 0.9722 | Val Acc: 0.5086 | Best: 0.5314 @ 057
# Epoch [061/160] | Train Loss: 0.8119 | Train Acc: 0.6950 | Val Loss: 0.9722 | Val Acc: 0.5429 | Best: 0.5429 @ 061
# Epoch [062/160] | Train Loss: 0.8089 | Train Acc: 0.6990 | Val Loss: 0.9712 | Val Acc: 0.5314 | Best: 0.5429 @ 061
# Epoch [063/160] | Train Loss: 0.8107 | Train Acc: 0.7100 | Val Loss: 0.9722 | Val Acc: 0.5257 | Best: 0.5429 @ 061
# Epoch [064/160] | Train Loss: 0.8074 | Train Acc: 0.6970 | Val Loss: 0.9716 | Val Acc: 0.5257 | Best: 0.5429 @ 061
# Epoch [065/160] | Train Loss: 0.8086 | Train Acc: 0.6920 | Val Loss: 0.9752 | Val Acc: 0.5257 | Best: 0.5429 @ 061
# Epoch [066/160] | Train Loss: 0.8017 | Train Acc: 0.7030 | Val Loss: 0.9721 | Val Acc: 0.5400 | Best: 0.5429 @ 061
# Epoch [067/160] | Train Loss: 0.8054 | Train Acc: 0.6840 | Val Loss: 0.9721 | Val Acc: 0.5229 | Best: 0.5429 @ 061
# Epoch [068/160] | Train Loss: 0.8097 | Train Acc: 0.6890 | Val Loss: 0.9707 | Val Acc: 0.5171 | Best: 0.5429 @ 061
# Epoch [069/160] | Train Loss: 0.7987 | Train Acc: 0.7030 | Val Loss: 0.9680 | Val Acc: 0.5314 | Best: 0.5429 @ 061
# Epoch [070/160] | Train Loss: 0.8005 | Train Acc: 0.7030 | Val Loss: 0.9758 | Val Acc: 0.5171 | Best: 0.5429 @ 061
# Epoch [071/160] | Train Loss: 0.7969 | Train Acc: 0.7090 | Val Loss: 0.9710 | Val Acc: 0.5286 | Best: 0.5429 @ 061
# Epoch [072/160] | Train Loss: 0.8007 | Train Acc: 0.7110 | Val Loss: 0.9669 | Val Acc: 0.5371 | Best: 0.5429 @ 061
# Epoch [073/160] | Train Loss: 0.8056 | Train Acc: 0.6990 | Val Loss: 0.9780 | Val Acc: 0.5229 | Best: 0.5429 @ 061
# Epoch [074/160] | Train Loss: 0.7939 | Train Acc: 0.7120 | Val Loss: 0.9672 | Val Acc: 0.5143 | Best: 0.5429 @ 061
# Epoch [075/160] | Train Loss: 0.7938 | Train Acc: 0.7110 | Val Loss: 0.9680 | Val Acc: 0.5171 | Best: 0.5429 @ 061
# Epoch [076/160] | Train Loss: 0.7916 | Train Acc: 0.7190 | Val Loss: 0.9698 | Val Acc: 0.5343 | Best: 0.5429 @ 061
# Epoch [077/160] | Train Loss: 0.7969 | Train Acc: 0.7090 | Val Loss: 0.9661 | Val Acc: 0.5314 | Best: 0.5429 @ 061
# Epoch [078/160] | Train Loss: 0.7937 | Train Acc: 0.7000 | Val Loss: 0.9688 | Val Acc: 0.5200 | Best: 0.5429 @ 061
# Epoch [079/160] | Train Loss: 0.7981 | Train Acc: 0.6900 | Val Loss: 0.9671 | Val Acc: 0.5114 | Best: 0.5429 @ 061
# Epoch [080/160] | Train Loss: 0.7917 | Train Acc: 0.7070 | Val Loss: 0.9660 | Val Acc: 0.5171 | Best: 0.5429 @ 061
# Epoch [081/160] | Train Loss: 0.7948 | Train Acc: 0.7090 | Val Loss: 0.9672 | Val Acc: 0.5257 | Best: 0.5429 @ 061
# Epoch [082/160] | Train Loss: 0.7907 | Train Acc: 0.7000 | Val Loss: 0.9675 | Val Acc: 0.5371 | Best: 0.5429 @ 061
# Epoch [083/160] | Train Loss: 0.7912 | Train Acc: 0.7140 | Val Loss: 0.9695 | Val Acc: 0.5029 | Best: 0.5429 @ 061
# Epoch [084/160] | Train Loss: 0.7918 | Train Acc: 0.7020 | Val Loss: 0.9733 | Val Acc: 0.5257 | Best: 0.5429 @ 061
# Epoch [085/160] | Train Loss: 0.7825 | Train Acc: 0.7270 | Val Loss: 0.9661 | Val Acc: 0.5200 | Best: 0.5429 @ 061
# Early stopping at epoch 85; best epoch was 61.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_moe.txt
# Simple MoE Best Val Accuracy: 0.5429 (epoch 61)
# Simple MoE Recomputed Train Accuracy: 0.7020
# Simple MoE Recomputed Val Accuracy: 0.5429
#
# ============================================================
# Training Simple MoE h64 dp30
# Epoch [001/160] | Train Loss: 1.0989 | Train Acc: 0.3640 | Val Loss: 1.0895 | Val Acc: 0.4314 | Best: 0.4314 @ 001
# Epoch [002/160] | Train Loss: 1.0807 | Train Acc: 0.4440 | Val Loss: 1.0806 | Val Acc: 0.4371 | Best: 0.4371 @ 002
# Epoch [003/160] | Train Loss: 1.0666 | Train Acc: 0.4780 | Val Loss: 1.0707 | Val Acc: 0.4771 | Best: 0.4771 @ 003
# Epoch [004/160] | Train Loss: 1.0554 | Train Acc: 0.4910 | Val Loss: 1.0663 | Val Acc: 0.4743 | Best: 0.4771 @ 003
# Epoch [005/160] | Train Loss: 1.0467 | Train Acc: 0.4980 | Val Loss: 1.0584 | Val Acc: 0.4629 | Best: 0.4771 @ 003
# Epoch [006/160] | Train Loss: 1.0349 | Train Acc: 0.5040 | Val Loss: 1.0531 | Val Acc: 0.4829 | Best: 0.4829 @ 006
# Epoch [007/160] | Train Loss: 1.0218 | Train Acc: 0.5170 | Val Loss: 1.0491 | Val Acc: 0.4657 | Best: 0.4829 @ 006
# Epoch [008/160] | Train Loss: 1.0156 | Train Acc: 0.5270 | Val Loss: 1.0425 | Val Acc: 0.4743 | Best: 0.4829 @ 006
# Epoch [009/160] | Train Loss: 1.0060 | Train Acc: 0.5380 | Val Loss: 1.0373 | Val Acc: 0.4743 | Best: 0.4829 @ 006
# Epoch [010/160] | Train Loss: 1.0019 | Train Acc: 0.5450 | Val Loss: 1.0345 | Val Acc: 0.4800 | Best: 0.4829 @ 006
# Epoch [011/160] | Train Loss: 0.9967 | Train Acc: 0.5490 | Val Loss: 1.0340 | Val Acc: 0.4886 | Best: 0.4886 @ 011
# Epoch [012/160] | Train Loss: 0.9837 | Train Acc: 0.5590 | Val Loss: 1.0320 | Val Acc: 0.4943 | Best: 0.4943 @ 012
# Epoch [013/160] | Train Loss: 0.9783 | Train Acc: 0.5550 | Val Loss: 1.0253 | Val Acc: 0.5000 | Best: 0.5000 @ 013
# Epoch [014/160] | Train Loss: 0.9693 | Train Acc: 0.5700 | Val Loss: 1.0247 | Val Acc: 0.4771 | Best: 0.5000 @ 013
# Epoch [015/160] | Train Loss: 0.9646 | Train Acc: 0.5670 | Val Loss: 1.0202 | Val Acc: 0.5057 | Best: 0.5057 @ 015
# Epoch [016/160] | Train Loss: 0.9554 | Train Acc: 0.5890 | Val Loss: 1.0159 | Val Acc: 0.5086 | Best: 0.5086 @ 016
# Epoch [017/160] | Train Loss: 0.9507 | Train Acc: 0.5760 | Val Loss: 1.0207 | Val Acc: 0.4971 | Best: 0.5086 @ 016
# Epoch [018/160] | Train Loss: 0.9449 | Train Acc: 0.5830 | Val Loss: 1.0142 | Val Acc: 0.5229 | Best: 0.5229 @ 018
# Epoch [019/160] | Train Loss: 0.9321 | Train Acc: 0.6060 | Val Loss: 1.0110 | Val Acc: 0.4914 | Best: 0.5229 @ 018
# Epoch [020/160] | Train Loss: 0.9370 | Train Acc: 0.5870 | Val Loss: 1.0124 | Val Acc: 0.5143 | Best: 0.5229 @ 018
# Epoch [021/160] | Train Loss: 0.9267 | Train Acc: 0.6030 | Val Loss: 1.0082 | Val Acc: 0.5000 | Best: 0.5229 @ 018
# Epoch [022/160] | Train Loss: 0.9130 | Train Acc: 0.6160 | Val Loss: 1.0146 | Val Acc: 0.5057 | Best: 0.5229 @ 018
# Epoch [023/160] | Train Loss: 0.9096 | Train Acc: 0.6170 | Val Loss: 1.0025 | Val Acc: 0.5257 | Best: 0.5257 @ 023
# Epoch [024/160] | Train Loss: 0.9035 | Train Acc: 0.6210 | Val Loss: 0.9986 | Val Acc: 0.5257 | Best: 0.5257 @ 023
# Epoch [025/160] | Train Loss: 0.8987 | Train Acc: 0.6280 | Val Loss: 1.0032 | Val Acc: 0.5200 | Best: 0.5257 @ 023
# Epoch [026/160] | Train Loss: 0.8937 | Train Acc: 0.6200 | Val Loss: 1.0027 | Val Acc: 0.5086 | Best: 0.5257 @ 023
# Epoch [027/160] | Train Loss: 0.8870 | Train Acc: 0.6380 | Val Loss: 1.0007 | Val Acc: 0.5229 | Best: 0.5257 @ 023
# Epoch [028/160] | Train Loss: 0.8778 | Train Acc: 0.6610 | Val Loss: 1.0026 | Val Acc: 0.5114 | Best: 0.5257 @ 023
# Epoch [029/160] | Train Loss: 0.8843 | Train Acc: 0.6430 | Val Loss: 0.9977 | Val Acc: 0.5029 | Best: 0.5257 @ 023
# Epoch [030/160] | Train Loss: 0.8765 | Train Acc: 0.6400 | Val Loss: 0.9975 | Val Acc: 0.4714 | Best: 0.5257 @ 023
# Epoch [031/160] | Train Loss: 0.8667 | Train Acc: 0.6570 | Val Loss: 0.9858 | Val Acc: 0.5429 | Best: 0.5429 @ 031
# Epoch [032/160] | Train Loss: 0.8575 | Train Acc: 0.6530 | Val Loss: 0.9814 | Val Acc: 0.5486 | Best: 0.5486 @ 032
# Epoch [033/160] | Train Loss: 0.8499 | Train Acc: 0.6640 | Val Loss: 0.9865 | Val Acc: 0.5229 | Best: 0.5486 @ 032
# Epoch [034/160] | Train Loss: 0.8492 | Train Acc: 0.6810 | Val Loss: 0.9853 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [035/160] | Train Loss: 0.8439 | Train Acc: 0.6680 | Val Loss: 0.9821 | Val Acc: 0.5400 | Best: 0.5486 @ 032
# Epoch [036/160] | Train Loss: 0.8435 | Train Acc: 0.6710 | Val Loss: 0.9836 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [037/160] | Train Loss: 0.8426 | Train Acc: 0.6740 | Val Loss: 0.9837 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [038/160] | Train Loss: 0.8366 | Train Acc: 0.6800 | Val Loss: 0.9861 | Val Acc: 0.5457 | Best: 0.5486 @ 032
# Epoch [039/160] | Train Loss: 0.8328 | Train Acc: 0.6750 | Val Loss: 0.9803 | Val Acc: 0.5400 | Best: 0.5486 @ 032
# Epoch [040/160] | Train Loss: 0.8185 | Train Acc: 0.7020 | Val Loss: 0.9856 | Val Acc: 0.5286 | Best: 0.5486 @ 032
# Epoch [041/160] | Train Loss: 0.8255 | Train Acc: 0.6770 | Val Loss: 0.9840 | Val Acc: 0.5343 | Best: 0.5486 @ 032
# Epoch [042/160] | Train Loss: 0.8292 | Train Acc: 0.6800 | Val Loss: 0.9805 | Val Acc: 0.5257 | Best: 0.5486 @ 032
# Epoch [043/160] | Train Loss: 0.8185 | Train Acc: 0.6880 | Val Loss: 0.9874 | Val Acc: 0.5286 | Best: 0.5486 @ 032
# Epoch [044/160] | Train Loss: 0.8182 | Train Acc: 0.7050 | Val Loss: 0.9789 | Val Acc: 0.5314 | Best: 0.5486 @ 032
# Epoch [045/160] | Train Loss: 0.8165 | Train Acc: 0.6860 | Val Loss: 0.9825 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [046/160] | Train Loss: 0.8157 | Train Acc: 0.6950 | Val Loss: 0.9814 | Val Acc: 0.5257 | Best: 0.5486 @ 032
# Epoch [047/160] | Train Loss: 0.8189 | Train Acc: 0.6820 | Val Loss: 0.9813 | Val Acc: 0.5343 | Best: 0.5486 @ 032
# Epoch [048/160] | Train Loss: 0.8117 | Train Acc: 0.7110 | Val Loss: 0.9785 | Val Acc: 0.5314 | Best: 0.5486 @ 032
# Epoch [049/160] | Train Loss: 0.8125 | Train Acc: 0.7100 | Val Loss: 0.9781 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [050/160] | Train Loss: 0.8096 | Train Acc: 0.7030 | Val Loss: 0.9770 | Val Acc: 0.5286 | Best: 0.5486 @ 032
# Epoch [051/160] | Train Loss: 0.8051 | Train Acc: 0.7140 | Val Loss: 0.9763 | Val Acc: 0.5457 | Best: 0.5486 @ 032
# Epoch [052/160] | Train Loss: 0.8018 | Train Acc: 0.7040 | Val Loss: 0.9796 | Val Acc: 0.5257 | Best: 0.5486 @ 032
# Epoch [053/160] | Train Loss: 0.8113 | Train Acc: 0.7000 | Val Loss: 0.9785 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Epoch [054/160] | Train Loss: 0.8064 | Train Acc: 0.6960 | Val Loss: 0.9786 | Val Acc: 0.5314 | Best: 0.5486 @ 032
# Epoch [055/160] | Train Loss: 0.8117 | Train Acc: 0.7000 | Val Loss: 0.9789 | Val Acc: 0.5400 | Best: 0.5486 @ 032
# Epoch [056/160] | Train Loss: 0.8113 | Train Acc: 0.6950 | Val Loss: 0.9745 | Val Acc: 0.5429 | Best: 0.5486 @ 032
# Early stopping at epoch 56; best epoch was 32.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_moe_h64_dp30.txt
# Simple MoE h64 dp30 Best Val Accuracy: 0.5486 (epoch 32)
# Simple MoE h64 dp30 Recomputed Train Accuracy: 0.6890
# Simple MoE h64 dp30 Recomputed Val Accuracy: 0.5486
#
# ============================================================
# Training Simple MoE h64 dp35
# Epoch [001/160] | Train Loss: 1.1005 | Train Acc: 0.3630 | Val Loss: 1.0940 | Val Acc: 0.3771 | Best: 0.3771 @ 001
# Epoch [002/160] | Train Loss: 1.0860 | Train Acc: 0.3920 | Val Loss: 1.0900 | Val Acc: 0.3800 | Best: 0.3800 @ 002
# Epoch [003/160] | Train Loss: 1.0735 | Train Acc: 0.4330 | Val Loss: 1.0827 | Val Acc: 0.4086 | Best: 0.4086 @ 003
# Epoch [004/160] | Train Loss: 1.0601 | Train Acc: 0.4730 | Val Loss: 1.0760 | Val Acc: 0.4314 | Best: 0.4314 @ 004
# Epoch [005/160] | Train Loss: 1.0419 | Train Acc: 0.5100 | Val Loss: 1.0677 | Val Acc: 0.4657 | Best: 0.4657 @ 005
# Epoch [006/160] | Train Loss: 1.0271 | Train Acc: 0.5100 | Val Loss: 1.0603 | Val Acc: 0.4571 | Best: 0.4657 @ 005
# Epoch [007/160] | Train Loss: 1.0121 | Train Acc: 0.5400 | Val Loss: 1.0570 | Val Acc: 0.4771 | Best: 0.4771 @ 007
# Epoch [008/160] | Train Loss: 1.0061 | Train Acc: 0.5300 | Val Loss: 1.0540 | Val Acc: 0.4743 | Best: 0.4771 @ 007
# Epoch [009/160] | Train Loss: 0.9868 | Train Acc: 0.5920 | Val Loss: 1.0506 | Val Acc: 0.4743 | Best: 0.4771 @ 007
# Epoch [010/160] | Train Loss: 0.9777 | Train Acc: 0.5970 | Val Loss: 1.0491 | Val Acc: 0.4743 | Best: 0.4771 @ 007
# Epoch [011/160] | Train Loss: 0.9702 | Train Acc: 0.6020 | Val Loss: 1.0455 | Val Acc: 0.4829 | Best: 0.4829 @ 011
# Epoch [012/160] | Train Loss: 0.9571 | Train Acc: 0.6200 | Val Loss: 1.0436 | Val Acc: 0.4971 | Best: 0.4971 @ 012
# Epoch [013/160] | Train Loss: 0.9496 | Train Acc: 0.6300 | Val Loss: 1.0402 | Val Acc: 0.4771 | Best: 0.4971 @ 012
# Epoch [014/160] | Train Loss: 0.9363 | Train Acc: 0.6420 | Val Loss: 1.0387 | Val Acc: 0.4686 | Best: 0.4971 @ 012
# Epoch [015/160] | Train Loss: 0.9283 | Train Acc: 0.6200 | Val Loss: 1.0410 | Val Acc: 0.4571 | Best: 0.4971 @ 012
# Epoch [016/160] | Train Loss: 0.9134 | Train Acc: 0.6610 | Val Loss: 1.0326 | Val Acc: 0.4800 | Best: 0.4971 @ 012
# Epoch [017/160] | Train Loss: 0.9051 | Train Acc: 0.6380 | Val Loss: 1.0340 | Val Acc: 0.4743 | Best: 0.4971 @ 012
# Epoch [018/160] | Train Loss: 0.8968 | Train Acc: 0.6640 | Val Loss: 1.0339 | Val Acc: 0.4800 | Best: 0.4971 @ 012
# Epoch [019/160] | Train Loss: 0.8836 | Train Acc: 0.6700 | Val Loss: 1.0256 | Val Acc: 0.4886 | Best: 0.4971 @ 012
# Epoch [020/160] | Train Loss: 0.8740 | Train Acc: 0.6690 | Val Loss: 1.0340 | Val Acc: 0.4800 | Best: 0.4971 @ 012
# Epoch [021/160] | Train Loss: 0.8542 | Train Acc: 0.7140 | Val Loss: 1.0253 | Val Acc: 0.4771 | Best: 0.4971 @ 012
# Epoch [022/160] | Train Loss: 0.8433 | Train Acc: 0.7170 | Val Loss: 1.0203 | Val Acc: 0.4971 | Best: 0.4971 @ 012
# Epoch [023/160] | Train Loss: 0.8383 | Train Acc: 0.7180 | Val Loss: 1.0182 | Val Acc: 0.4943 | Best: 0.4971 @ 012
# Epoch [024/160] | Train Loss: 0.8393 | Train Acc: 0.7300 | Val Loss: 1.0248 | Val Acc: 0.4886 | Best: 0.4971 @ 012
# Epoch [025/160] | Train Loss: 0.8265 | Train Acc: 0.7400 | Val Loss: 1.0296 | Val Acc: 0.4829 | Best: 0.4971 @ 012
# Epoch [026/160] | Train Loss: 0.8254 | Train Acc: 0.7350 | Val Loss: 1.0165 | Val Acc: 0.4914 | Best: 0.4971 @ 012
# Epoch [027/160] | Train Loss: 0.8195 | Train Acc: 0.7350 | Val Loss: 1.0203 | Val Acc: 0.4943 | Best: 0.4971 @ 012
# Epoch [028/160] | Train Loss: 0.8152 | Train Acc: 0.7510 | Val Loss: 1.0139 | Val Acc: 0.5086 | Best: 0.5086 @ 028
# Epoch [029/160] | Train Loss: 0.8048 | Train Acc: 0.7510 | Val Loss: 1.0233 | Val Acc: 0.4829 | Best: 0.5086 @ 028
# Epoch [030/160] | Train Loss: 0.8038 | Train Acc: 0.7510 | Val Loss: 1.0160 | Val Acc: 0.4943 | Best: 0.5086 @ 028
# Epoch [031/160] | Train Loss: 0.7960 | Train Acc: 0.7660 | Val Loss: 1.0188 | Val Acc: 0.4943 | Best: 0.5086 @ 028
# Epoch [032/160] | Train Loss: 0.7940 | Train Acc: 0.7500 | Val Loss: 1.0194 | Val Acc: 0.4829 | Best: 0.5086 @ 028
# Epoch [033/160] | Train Loss: 0.7897 | Train Acc: 0.7560 | Val Loss: 1.0135 | Val Acc: 0.4943 | Best: 0.5086 @ 028
# Epoch [034/160] | Train Loss: 0.7823 | Train Acc: 0.7970 | Val Loss: 1.0162 | Val Acc: 0.4800 | Best: 0.5086 @ 028
# Epoch [035/160] | Train Loss: 0.7763 | Train Acc: 0.7660 | Val Loss: 1.0162 | Val Acc: 0.4886 | Best: 0.5086 @ 028
# Epoch [036/160] | Train Loss: 0.7740 | Train Acc: 0.7800 | Val Loss: 1.0200 | Val Acc: 0.4886 | Best: 0.5086 @ 028
# Epoch [037/160] | Train Loss: 0.7601 | Train Acc: 0.7810 | Val Loss: 1.0092 | Val Acc: 0.4914 | Best: 0.5086 @ 028
# Epoch [038/160] | Train Loss: 0.7534 | Train Acc: 0.7880 | Val Loss: 1.0110 | Val Acc: 0.4943 | Best: 0.5086 @ 028
# Epoch [039/160] | Train Loss: 0.7527 | Train Acc: 0.7950 | Val Loss: 1.0109 | Val Acc: 0.4886 | Best: 0.5086 @ 028
# Epoch [040/160] | Train Loss: 0.7520 | Train Acc: 0.7970 | Val Loss: 1.0086 | Val Acc: 0.5029 | Best: 0.5086 @ 028
# Epoch [041/160] | Train Loss: 0.7444 | Train Acc: 0.7970 | Val Loss: 1.0099 | Val Acc: 0.4943 | Best: 0.5086 @ 028
# Epoch [042/160] | Train Loss: 0.7425 | Train Acc: 0.8090 | Val Loss: 1.0081 | Val Acc: 0.5143 | Best: 0.5143 @ 042
# Epoch [043/160] | Train Loss: 0.7429 | Train Acc: 0.8130 | Val Loss: 1.0140 | Val Acc: 0.4943 | Best: 0.5143 @ 042
# Epoch [044/160] | Train Loss: 0.7445 | Train Acc: 0.8000 | Val Loss: 1.0102 | Val Acc: 0.4971 | Best: 0.5143 @ 042
# Epoch [045/160] | Train Loss: 0.7406 | Train Acc: 0.8060 | Val Loss: 1.0066 | Val Acc: 0.5114 | Best: 0.5143 @ 042
# Epoch [046/160] | Train Loss: 0.7333 | Train Acc: 0.8120 | Val Loss: 1.0057 | Val Acc: 0.5143 | Best: 0.5143 @ 042
# Epoch [047/160] | Train Loss: 0.7291 | Train Acc: 0.8090 | Val Loss: 1.0079 | Val Acc: 0.5029 | Best: 0.5143 @ 042
# Epoch [048/160] | Train Loss: 0.7260 | Train Acc: 0.8250 | Val Loss: 1.0069 | Val Acc: 0.5114 | Best: 0.5143 @ 042
# Epoch [049/160] | Train Loss: 0.7259 | Train Acc: 0.8180 | Val Loss: 1.0072 | Val Acc: 0.5143 | Best: 0.5143 @ 042
# Epoch [050/160] | Train Loss: 0.7237 | Train Acc: 0.8190 | Val Loss: 1.0096 | Val Acc: 0.5086 | Best: 0.5143 @ 042
# Epoch [051/160] | Train Loss: 0.7148 | Train Acc: 0.8240 | Val Loss: 1.0064 | Val Acc: 0.5057 | Best: 0.5143 @ 042
# Epoch [052/160] | Train Loss: 0.7095 | Train Acc: 0.8290 | Val Loss: 1.0093 | Val Acc: 0.4943 | Best: 0.5143 @ 042
# Epoch [053/160] | Train Loss: 0.7160 | Train Acc: 0.8240 | Val Loss: 1.0040 | Val Acc: 0.5086 | Best: 0.5143 @ 042
# Epoch [054/160] | Train Loss: 0.7124 | Train Acc: 0.8220 | Val Loss: 1.0055 | Val Acc: 0.4971 | Best: 0.5143 @ 042
# Epoch [055/160] | Train Loss: 0.7179 | Train Acc: 0.8180 | Val Loss: 1.0055 | Val Acc: 0.5086 | Best: 0.5143 @ 042
# Epoch [056/160] | Train Loss: 0.7081 | Train Acc: 0.8280 | Val Loss: 1.0046 | Val Acc: 0.5114 | Best: 0.5143 @ 042
# Epoch [057/160] | Train Loss: 0.7064 | Train Acc: 0.8270 | Val Loss: 1.0026 | Val Acc: 0.5057 | Best: 0.5143 @ 042
# Epoch [058/160] | Train Loss: 0.7139 | Train Acc: 0.8310 | Val Loss: 1.0098 | Val Acc: 0.4971 | Best: 0.5143 @ 042
# Epoch [059/160] | Train Loss: 0.7077 | Train Acc: 0.8370 | Val Loss: 1.0117 | Val Acc: 0.5029 | Best: 0.5143 @ 042
# Epoch [060/160] | Train Loss: 0.6993 | Train Acc: 0.8400 | Val Loss: 1.0070 | Val Acc: 0.5086 | Best: 0.5143 @ 042
# Epoch [061/160] | Train Loss: 0.7037 | Train Acc: 0.8340 | Val Loss: 1.0049 | Val Acc: 0.5200 | Best: 0.5200 @ 061
# Epoch [062/160] | Train Loss: 0.7018 | Train Acc: 0.8350 | Val Loss: 1.0119 | Val Acc: 0.4971 | Best: 0.5200 @ 061
# Epoch [063/160] | Train Loss: 0.7045 | Train Acc: 0.8430 | Val Loss: 1.0061 | Val Acc: 0.5086 | Best: 0.5200 @ 061
# Epoch [064/160] | Train Loss: 0.7087 | Train Acc: 0.8300 | Val Loss: 1.0067 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [065/160] | Train Loss: 0.6999 | Train Acc: 0.8360 | Val Loss: 1.0048 | Val Acc: 0.5086 | Best: 0.5200 @ 061
# Epoch [066/160] | Train Loss: 0.6955 | Train Acc: 0.8450 | Val Loss: 1.0056 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [067/160] | Train Loss: 0.7044 | Train Acc: 0.8430 | Val Loss: 1.0030 | Val Acc: 0.5057 | Best: 0.5200 @ 061
# Epoch [068/160] | Train Loss: 0.6997 | Train Acc: 0.8460 | Val Loss: 1.0038 | Val Acc: 0.5057 | Best: 0.5200 @ 061
# Epoch [069/160] | Train Loss: 0.6956 | Train Acc: 0.8390 | Val Loss: 1.0028 | Val Acc: 0.5143 | Best: 0.5200 @ 061
# Epoch [070/160] | Train Loss: 0.6972 | Train Acc: 0.8390 | Val Loss: 1.0053 | Val Acc: 0.5143 | Best: 0.5200 @ 061
# Epoch [071/160] | Train Loss: 0.6988 | Train Acc: 0.8390 | Val Loss: 1.0037 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [072/160] | Train Loss: 0.6996 | Train Acc: 0.8380 | Val Loss: 1.0039 | Val Acc: 0.5057 | Best: 0.5200 @ 061
# Epoch [073/160] | Train Loss: 0.6895 | Train Acc: 0.8570 | Val Loss: 1.0044 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [074/160] | Train Loss: 0.6954 | Train Acc: 0.8350 | Val Loss: 1.0029 | Val Acc: 0.5086 | Best: 0.5200 @ 061
# Epoch [075/160] | Train Loss: 0.6995 | Train Acc: 0.8420 | Val Loss: 1.0038 | Val Acc: 0.5029 | Best: 0.5200 @ 061
# Epoch [076/160] | Train Loss: 0.6867 | Train Acc: 0.8560 | Val Loss: 1.0083 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [077/160] | Train Loss: 0.6958 | Train Acc: 0.8390 | Val Loss: 1.0115 | Val Acc: 0.5057 | Best: 0.5200 @ 061
# Epoch [078/160] | Train Loss: 0.6938 | Train Acc: 0.8410 | Val Loss: 1.0070 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [079/160] | Train Loss: 0.6964 | Train Acc: 0.8510 | Val Loss: 1.0054 | Val Acc: 0.5086 | Best: 0.5200 @ 061
# Epoch [080/160] | Train Loss: 0.6977 | Train Acc: 0.8350 | Val Loss: 1.0059 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [081/160] | Train Loss: 0.6999 | Train Acc: 0.8430 | Val Loss: 1.0014 | Val Acc: 0.5086 | Best: 0.5200 @ 061
# Epoch [082/160] | Train Loss: 0.6914 | Train Acc: 0.8370 | Val Loss: 1.0046 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Epoch [083/160] | Train Loss: 0.6927 | Train Acc: 0.8400 | Val Loss: 1.0034 | Val Acc: 0.5000 | Best: 0.5200 @ 061
# Epoch [084/160] | Train Loss: 0.6925 | Train Acc: 0.8430 | Val Loss: 1.0056 | Val Acc: 0.5000 | Best: 0.5200 @ 061
# Epoch [085/160] | Train Loss: 0.6917 | Train Acc: 0.8480 | Val Loss: 1.0065 | Val Acc: 0.5114 | Best: 0.5200 @ 061
# Early stopping at epoch 85; best epoch was 61.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_moe_h64_dp35.txt
# Simple MoE h64 dp35 Best Val Accuracy: 0.5200 (epoch 61)
# Simple MoE h64 dp35 Recomputed Train Accuracy: 0.8540
# Simple MoE h64 dp35 Recomputed Val Accuracy: 0.5200
#
# ============================================================
# Training Simple MoE h80 dp35
# Epoch [001/160] | Train Loss: 1.1044 | Train Acc: 0.3430 | Val Loss: 1.0923 | Val Acc: 0.3486 | Best: 0.3486 @ 001
# Epoch [002/160] | Train Loss: 1.0814 | Train Acc: 0.4530 | Val Loss: 1.0852 | Val Acc: 0.3800 | Best: 0.3800 @ 002
# Epoch [003/160] | Train Loss: 1.0701 | Train Acc: 0.4890 | Val Loss: 1.0808 | Val Acc: 0.3686 | Best: 0.3800 @ 002
# Epoch [004/160] | Train Loss: 1.0594 | Train Acc: 0.4850 | Val Loss: 1.0746 | Val Acc: 0.4114 | Best: 0.4114 @ 004
# Epoch [005/160] | Train Loss: 1.0479 | Train Acc: 0.5100 | Val Loss: 1.0693 | Val Acc: 0.4343 | Best: 0.4343 @ 005
# Epoch [006/160] | Train Loss: 1.0371 | Train Acc: 0.5350 | Val Loss: 1.0637 | Val Acc: 0.4400 | Best: 0.4400 @ 006
# Epoch [007/160] | Train Loss: 1.0288 | Train Acc: 0.5320 | Val Loss: 1.0601 | Val Acc: 0.4400 | Best: 0.4400 @ 006
# Epoch [008/160] | Train Loss: 1.0230 | Train Acc: 0.5340 | Val Loss: 1.0564 | Val Acc: 0.4686 | Best: 0.4686 @ 008
# Epoch [009/160] | Train Loss: 1.0128 | Train Acc: 0.5550 | Val Loss: 1.0532 | Val Acc: 0.4571 | Best: 0.4686 @ 008
# Epoch [010/160] | Train Loss: 1.0028 | Train Acc: 0.5660 | Val Loss: 1.0505 | Val Acc: 0.4486 | Best: 0.4686 @ 008
# Epoch [011/160] | Train Loss: 0.9958 | Train Acc: 0.5520 | Val Loss: 1.0477 | Val Acc: 0.4571 | Best: 0.4686 @ 008
# Epoch [012/160] | Train Loss: 0.9894 | Train Acc: 0.5770 | Val Loss: 1.0440 | Val Acc: 0.4629 | Best: 0.4686 @ 008
# Epoch [013/160] | Train Loss: 0.9824 | Train Acc: 0.5680 | Val Loss: 1.0420 | Val Acc: 0.4857 | Best: 0.4857 @ 013
# Epoch [014/160] | Train Loss: 0.9722 | Train Acc: 0.5840 | Val Loss: 1.0495 | Val Acc: 0.4686 | Best: 0.4857 @ 013
# Epoch [015/160] | Train Loss: 0.9666 | Train Acc: 0.5820 | Val Loss: 1.0379 | Val Acc: 0.4600 | Best: 0.4857 @ 013
# Epoch [016/160] | Train Loss: 0.9581 | Train Acc: 0.5960 | Val Loss: 1.0335 | Val Acc: 0.4657 | Best: 0.4857 @ 013
# Epoch [017/160] | Train Loss: 0.9485 | Train Acc: 0.6060 | Val Loss: 1.0362 | Val Acc: 0.4943 | Best: 0.4943 @ 017
# Epoch [018/160] | Train Loss: 0.9424 | Train Acc: 0.5930 | Val Loss: 1.0317 | Val Acc: 0.4714 | Best: 0.4943 @ 017
# Epoch [019/160] | Train Loss: 0.9349 | Train Acc: 0.6060 | Val Loss: 1.0316 | Val Acc: 0.4771 | Best: 0.4943 @ 017
# Epoch [020/160] | Train Loss: 0.9261 | Train Acc: 0.6180 | Val Loss: 1.0273 | Val Acc: 0.4857 | Best: 0.4943 @ 017
# Epoch [021/160] | Train Loss: 0.9258 | Train Acc: 0.6290 | Val Loss: 1.0275 | Val Acc: 0.4800 | Best: 0.4943 @ 017
# Epoch [022/160] | Train Loss: 0.9149 | Train Acc: 0.6300 | Val Loss: 1.0217 | Val Acc: 0.4857 | Best: 0.4943 @ 017
# Epoch [023/160] | Train Loss: 0.9022 | Train Acc: 0.6450 | Val Loss: 1.0237 | Val Acc: 0.4743 | Best: 0.4943 @ 017
# Epoch [024/160] | Train Loss: 0.9031 | Train Acc: 0.6260 | Val Loss: 1.0167 | Val Acc: 0.4857 | Best: 0.4943 @ 017
# Epoch [025/160] | Train Loss: 0.8997 | Train Acc: 0.6470 | Val Loss: 1.0177 | Val Acc: 0.4800 | Best: 0.4943 @ 017
# Epoch [026/160] | Train Loss: 0.8876 | Train Acc: 0.6590 | Val Loss: 1.0156 | Val Acc: 0.4886 | Best: 0.4943 @ 017
# Epoch [027/160] | Train Loss: 0.8798 | Train Acc: 0.6590 | Val Loss: 1.0164 | Val Acc: 0.4886 | Best: 0.4943 @ 017
# Epoch [028/160] | Train Loss: 0.8751 | Train Acc: 0.6790 | Val Loss: 1.0113 | Val Acc: 0.4914 | Best: 0.4943 @ 017
# Epoch [029/160] | Train Loss: 0.8678 | Train Acc: 0.6790 | Val Loss: 1.0118 | Val Acc: 0.4771 | Best: 0.4943 @ 017
# Epoch [030/160] | Train Loss: 0.8608 | Train Acc: 0.6860 | Val Loss: 1.0117 | Val Acc: 0.5000 | Best: 0.5000 @ 030
# Epoch [031/160] | Train Loss: 0.8602 | Train Acc: 0.6880 | Val Loss: 1.0091 | Val Acc: 0.4914 | Best: 0.5000 @ 030
# Epoch [032/160] | Train Loss: 0.8618 | Train Acc: 0.6730 | Val Loss: 1.0076 | Val Acc: 0.5057 | Best: 0.5057 @ 032
# Epoch [033/160] | Train Loss: 0.8608 | Train Acc: 0.6780 | Val Loss: 1.0106 | Val Acc: 0.4857 | Best: 0.5057 @ 032
# Epoch [034/160] | Train Loss: 0.8458 | Train Acc: 0.6770 | Val Loss: 1.0039 | Val Acc: 0.5114 | Best: 0.5114 @ 034
# Epoch [035/160] | Train Loss: 0.8536 | Train Acc: 0.6820 | Val Loss: 1.0066 | Val Acc: 0.5086 | Best: 0.5114 @ 034
# Epoch [036/160] | Train Loss: 0.8482 | Train Acc: 0.6830 | Val Loss: 1.0056 | Val Acc: 0.4971 | Best: 0.5114 @ 034
# Epoch [037/160] | Train Loss: 0.8419 | Train Acc: 0.6900 | Val Loss: 1.0046 | Val Acc: 0.4914 | Best: 0.5114 @ 034
# Epoch [038/160] | Train Loss: 0.8430 | Train Acc: 0.7020 | Val Loss: 1.0056 | Val Acc: 0.5029 | Best: 0.5114 @ 034
# Epoch [039/160] | Train Loss: 0.8361 | Train Acc: 0.6900 | Val Loss: 1.0034 | Val Acc: 0.5114 | Best: 0.5114 @ 034
# Epoch [040/160] | Train Loss: 0.8323 | Train Acc: 0.6990 | Val Loss: 1.0020 | Val Acc: 0.5229 | Best: 0.5229 @ 040
# Epoch [041/160] | Train Loss: 0.8319 | Train Acc: 0.7060 | Val Loss: 1.0048 | Val Acc: 0.4914 | Best: 0.5229 @ 040
# Epoch [042/160] | Train Loss: 0.8230 | Train Acc: 0.7180 | Val Loss: 1.0138 | Val Acc: 0.4886 | Best: 0.5229 @ 040
# Epoch [043/160] | Train Loss: 0.8202 | Train Acc: 0.7020 | Val Loss: 0.9995 | Val Acc: 0.5171 | Best: 0.5229 @ 040
# Epoch [044/160] | Train Loss: 0.8182 | Train Acc: 0.7250 | Val Loss: 0.9982 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [045/160] | Train Loss: 0.8110 | Train Acc: 0.7320 | Val Loss: 1.0074 | Val Acc: 0.4857 | Best: 0.5229 @ 040
# Epoch [046/160] | Train Loss: 0.8165 | Train Acc: 0.7280 | Val Loss: 0.9966 | Val Acc: 0.5143 | Best: 0.5229 @ 040
# Epoch [047/160] | Train Loss: 0.8105 | Train Acc: 0.7300 | Val Loss: 1.0017 | Val Acc: 0.5029 | Best: 0.5229 @ 040
# Epoch [048/160] | Train Loss: 0.8014 | Train Acc: 0.7230 | Val Loss: 0.9975 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [049/160] | Train Loss: 0.7950 | Train Acc: 0.7440 | Val Loss: 0.9966 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [050/160] | Train Loss: 0.7949 | Train Acc: 0.7440 | Val Loss: 0.9961 | Val Acc: 0.5029 | Best: 0.5229 @ 040
# Epoch [051/160] | Train Loss: 0.7964 | Train Acc: 0.7290 | Val Loss: 0.9953 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [052/160] | Train Loss: 0.7914 | Train Acc: 0.7480 | Val Loss: 0.9979 | Val Acc: 0.4943 | Best: 0.5229 @ 040
# Epoch [053/160] | Train Loss: 0.7947 | Train Acc: 0.7380 | Val Loss: 0.9987 | Val Acc: 0.4971 | Best: 0.5229 @ 040
# Epoch [054/160] | Train Loss: 0.7986 | Train Acc: 0.7280 | Val Loss: 0.9942 | Val Acc: 0.5000 | Best: 0.5229 @ 040
# Epoch [055/160] | Train Loss: 0.7895 | Train Acc: 0.7390 | Val Loss: 0.9958 | Val Acc: 0.5029 | Best: 0.5229 @ 040
# Epoch [056/160] | Train Loss: 0.7882 | Train Acc: 0.7500 | Val Loss: 0.9931 | Val Acc: 0.5086 | Best: 0.5229 @ 040
# Epoch [057/160] | Train Loss: 0.7804 | Train Acc: 0.7610 | Val Loss: 0.9947 | Val Acc: 0.5057 | Best: 0.5229 @ 040
# Epoch [058/160] | Train Loss: 0.7846 | Train Acc: 0.7530 | Val Loss: 0.9937 | Val Acc: 0.5086 | Best: 0.5229 @ 040
# Epoch [059/160] | Train Loss: 0.7775 | Train Acc: 0.7550 | Val Loss: 0.9943 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [060/160] | Train Loss: 0.7796 | Train Acc: 0.7350 | Val Loss: 0.9925 | Val Acc: 0.5114 | Best: 0.5229 @ 040
# Epoch [061/160] | Train Loss: 0.7813 | Train Acc: 0.7380 | Val Loss: 0.9984 | Val Acc: 0.4943 | Best: 0.5229 @ 040
# Epoch [062/160] | Train Loss: 0.7752 | Train Acc: 0.7550 | Val Loss: 0.9971 | Val Acc: 0.5086 | Best: 0.5229 @ 040
# Epoch [063/160] | Train Loss: 0.7779 | Train Acc: 0.7410 | Val Loss: 0.9966 | Val Acc: 0.5029 | Best: 0.5229 @ 040
# Epoch [064/160] | Train Loss: 0.7803 | Train Acc: 0.7510 | Val Loss: 0.9936 | Val Acc: 0.5029 | Best: 0.5229 @ 040
# Early stopping at epoch 64; best epoch was 40.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_moe_h80_dp35.txt
# Simple MoE h80 dp35 Best Val Accuracy: 0.5229 (epoch 40)
# Simple MoE h80 dp35 Recomputed Train Accuracy: 0.7320
# Simple MoE h80 dp35 Recomputed Val Accuracy: 0.5229
#
# ============================================================
# Training Simple MoE h96 dp40
# Epoch [001/160] | Train Loss: 1.0977 | Train Acc: 0.3560 | Val Loss: 1.0923 | Val Acc: 0.4000 | Best: 0.4000 @ 001
# Epoch [002/160] | Train Loss: 1.0894 | Train Acc: 0.4020 | Val Loss: 1.0876 | Val Acc: 0.3829 | Best: 0.4000 @ 001
# Epoch [003/160] | Train Loss: 1.0806 | Train Acc: 0.4460 | Val Loss: 1.0849 | Val Acc: 0.4143 | Best: 0.4143 @ 003
# Epoch [004/160] | Train Loss: 1.0742 | Train Acc: 0.4600 | Val Loss: 1.0826 | Val Acc: 0.4257 | Best: 0.4257 @ 004
# Epoch [005/160] | Train Loss: 1.0682 | Train Acc: 0.4830 | Val Loss: 1.0812 | Val Acc: 0.4200 | Best: 0.4257 @ 004
# Epoch [006/160] | Train Loss: 1.0644 | Train Acc: 0.4760 | Val Loss: 1.0756 | Val Acc: 0.4371 | Best: 0.4371 @ 006
# Epoch [007/160] | Train Loss: 1.0573 | Train Acc: 0.4940 | Val Loss: 1.0707 | Val Acc: 0.4600 | Best: 0.4600 @ 007
# Epoch [008/160] | Train Loss: 1.0524 | Train Acc: 0.4960 | Val Loss: 1.0683 | Val Acc: 0.4571 | Best: 0.4600 @ 007
# Epoch [009/160] | Train Loss: 1.0472 | Train Acc: 0.5030 | Val Loss: 1.0657 | Val Acc: 0.4657 | Best: 0.4657 @ 009
# Epoch [010/160] | Train Loss: 1.0411 | Train Acc: 0.4990 | Val Loss: 1.0645 | Val Acc: 0.4629 | Best: 0.4657 @ 009
# Epoch [011/160] | Train Loss: 1.0355 | Train Acc: 0.5240 | Val Loss: 1.0577 | Val Acc: 0.4657 | Best: 0.4657 @ 009
# Epoch [012/160] | Train Loss: 1.0289 | Train Acc: 0.5070 | Val Loss: 1.0565 | Val Acc: 0.4714 | Best: 0.4714 @ 012
# Epoch [013/160] | Train Loss: 1.0252 | Train Acc: 0.5250 | Val Loss: 1.0545 | Val Acc: 0.4829 | Best: 0.4829 @ 013
# Epoch [014/160] | Train Loss: 1.0223 | Train Acc: 0.5170 | Val Loss: 1.0508 | Val Acc: 0.4686 | Best: 0.4829 @ 013
# Epoch [015/160] | Train Loss: 1.0097 | Train Acc: 0.5390 | Val Loss: 1.0515 | Val Acc: 0.4771 | Best: 0.4829 @ 013
# Epoch [016/160] | Train Loss: 1.0151 | Train Acc: 0.5120 | Val Loss: 1.0477 | Val Acc: 0.4771 | Best: 0.4829 @ 013
# Epoch [017/160] | Train Loss: 1.0073 | Train Acc: 0.5230 | Val Loss: 1.0437 | Val Acc: 0.4514 | Best: 0.4829 @ 013
# Epoch [018/160] | Train Loss: 1.0070 | Train Acc: 0.5300 | Val Loss: 1.0424 | Val Acc: 0.4743 | Best: 0.4829 @ 013
# Epoch [019/160] | Train Loss: 1.0019 | Train Acc: 0.5300 | Val Loss: 1.0392 | Val Acc: 0.4771 | Best: 0.4829 @ 013
# Epoch [020/160] | Train Loss: 0.9957 | Train Acc: 0.5470 | Val Loss: 1.0403 | Val Acc: 0.4429 | Best: 0.4829 @ 013
# Epoch [021/160] | Train Loss: 0.9895 | Train Acc: 0.5480 | Val Loss: 1.0344 | Val Acc: 0.4800 | Best: 0.4829 @ 013
# Epoch [022/160] | Train Loss: 0.9880 | Train Acc: 0.5470 | Val Loss: 1.0338 | Val Acc: 0.5029 | Best: 0.5029 @ 022
# Epoch [023/160] | Train Loss: 0.9809 | Train Acc: 0.5560 | Val Loss: 1.0323 | Val Acc: 0.4743 | Best: 0.5029 @ 022
# Epoch [024/160] | Train Loss: 0.9745 | Train Acc: 0.5680 | Val Loss: 1.0305 | Val Acc: 0.4857 | Best: 0.5029 @ 022
# Epoch [025/160] | Train Loss: 0.9766 | Train Acc: 0.5520 | Val Loss: 1.0299 | Val Acc: 0.5029 | Best: 0.5029 @ 022
# Epoch [026/160] | Train Loss: 0.9670 | Train Acc: 0.5670 | Val Loss: 1.0317 | Val Acc: 0.4800 | Best: 0.5029 @ 022
# Epoch [027/160] | Train Loss: 0.9676 | Train Acc: 0.5720 | Val Loss: 1.0283 | Val Acc: 0.4714 | Best: 0.5029 @ 022
# Epoch [028/160] | Train Loss: 0.9638 | Train Acc: 0.5640 | Val Loss: 1.0256 | Val Acc: 0.4800 | Best: 0.5029 @ 022
# Epoch [029/160] | Train Loss: 0.9607 | Train Acc: 0.5580 | Val Loss: 1.0228 | Val Acc: 0.4829 | Best: 0.5029 @ 022
# Epoch [030/160] | Train Loss: 0.9569 | Train Acc: 0.5790 | Val Loss: 1.0203 | Val Acc: 0.4800 | Best: 0.5029 @ 022
# Epoch [031/160] | Train Loss: 0.9533 | Train Acc: 0.5710 | Val Loss: 1.0210 | Val Acc: 0.4829 | Best: 0.5029 @ 022
# Epoch [032/160] | Train Loss: 0.9476 | Train Acc: 0.5760 | Val Loss: 1.0182 | Val Acc: 0.4943 | Best: 0.5029 @ 022
# Epoch [033/160] | Train Loss: 0.9496 | Train Acc: 0.5880 | Val Loss: 1.0153 | Val Acc: 0.4800 | Best: 0.5029 @ 022
# Epoch [034/160] | Train Loss: 0.9476 | Train Acc: 0.5840 | Val Loss: 1.0148 | Val Acc: 0.4914 | Best: 0.5029 @ 022
# Epoch [035/160] | Train Loss: 0.9423 | Train Acc: 0.6030 | Val Loss: 1.0173 | Val Acc: 0.4886 | Best: 0.5029 @ 022
# Epoch [036/160] | Train Loss: 0.9434 | Train Acc: 0.5820 | Val Loss: 1.0148 | Val Acc: 0.4800 | Best: 0.5029 @ 022
# Epoch [037/160] | Train Loss: 0.9375 | Train Acc: 0.5840 | Val Loss: 1.0156 | Val Acc: 0.4857 | Best: 0.5029 @ 022
# Epoch [038/160] | Train Loss: 0.9393 | Train Acc: 0.5930 | Val Loss: 1.0152 | Val Acc: 0.5000 | Best: 0.5029 @ 022
# Epoch [039/160] | Train Loss: 0.9389 | Train Acc: 0.5860 | Val Loss: 1.0143 | Val Acc: 0.4943 | Best: 0.5029 @ 022
# Epoch [040/160] | Train Loss: 0.9289 | Train Acc: 0.6030 | Val Loss: 1.0171 | Val Acc: 0.4743 | Best: 0.5029 @ 022
# Epoch [041/160] | Train Loss: 0.9325 | Train Acc: 0.6000 | Val Loss: 1.0141 | Val Acc: 0.4943 | Best: 0.5029 @ 022
# Epoch [042/160] | Train Loss: 0.9299 | Train Acc: 0.5950 | Val Loss: 1.0094 | Val Acc: 0.4971 | Best: 0.5029 @ 022
# Epoch [043/160] | Train Loss: 0.9279 | Train Acc: 0.6020 | Val Loss: 1.0139 | Val Acc: 0.4886 | Best: 0.5029 @ 022
# Epoch [044/160] | Train Loss: 0.9242 | Train Acc: 0.6230 | Val Loss: 1.0138 | Val Acc: 0.4943 | Best: 0.5029 @ 022
# Epoch [045/160] | Train Loss: 0.9288 | Train Acc: 0.5880 | Val Loss: 1.0122 | Val Acc: 0.5057 | Best: 0.5057 @ 045
# Epoch [046/160] | Train Loss: 0.9290 | Train Acc: 0.6100 | Val Loss: 1.0131 | Val Acc: 0.4829 | Best: 0.5057 @ 045
# Epoch [047/160] | Train Loss: 0.9270 | Train Acc: 0.5960 | Val Loss: 1.0108 | Val Acc: 0.4886 | Best: 0.5057 @ 045
# Epoch [048/160] | Train Loss: 0.9174 | Train Acc: 0.6050 | Val Loss: 1.0104 | Val Acc: 0.4971 | Best: 0.5057 @ 045
# Epoch [049/160] | Train Loss: 0.9251 | Train Acc: 0.6160 | Val Loss: 1.0074 | Val Acc: 0.4971 | Best: 0.5057 @ 045
# Epoch [050/160] | Train Loss: 0.9150 | Train Acc: 0.6180 | Val Loss: 1.0086 | Val Acc: 0.4829 | Best: 0.5057 @ 045
# Epoch [051/160] | Train Loss: 0.9162 | Train Acc: 0.6200 | Val Loss: 1.0131 | Val Acc: 0.4714 | Best: 0.5057 @ 045
# Epoch [052/160] | Train Loss: 0.9245 | Train Acc: 0.6050 | Val Loss: 1.0097 | Val Acc: 0.4829 | Best: 0.5057 @ 045
# Epoch [053/160] | Train Loss: 0.9142 | Train Acc: 0.6080 | Val Loss: 1.0085 | Val Acc: 0.4914 | Best: 0.5057 @ 045
# Epoch [054/160] | Train Loss: 0.9202 | Train Acc: 0.6070 | Val Loss: 1.0066 | Val Acc: 0.5029 | Best: 0.5057 @ 045
# Epoch [055/160] | Train Loss: 0.9233 | Train Acc: 0.6150 | Val Loss: 1.0110 | Val Acc: 0.5000 | Best: 0.5057 @ 045
# Epoch [056/160] | Train Loss: 0.9116 | Train Acc: 0.6160 | Val Loss: 1.0084 | Val Acc: 0.4971 | Best: 0.5057 @ 045
# Epoch [057/160] | Train Loss: 0.9151 | Train Acc: 0.6250 | Val Loss: 1.0051 | Val Acc: 0.5086 | Best: 0.5086 @ 057
# Epoch [058/160] | Train Loss: 0.9119 | Train Acc: 0.6260 | Val Loss: 1.0049 | Val Acc: 0.4971 | Best: 0.5086 @ 057
# Epoch [059/160] | Train Loss: 0.9208 | Train Acc: 0.6130 | Val Loss: 1.0102 | Val Acc: 0.4771 | Best: 0.5086 @ 057
# Epoch [060/160] | Train Loss: 0.9139 | Train Acc: 0.6210 | Val Loss: 1.0087 | Val Acc: 0.4886 | Best: 0.5086 @ 057
# Epoch [061/160] | Train Loss: 0.9092 | Train Acc: 0.6230 | Val Loss: 1.0065 | Val Acc: 0.4914 | Best: 0.5086 @ 057
# Epoch [062/160] | Train Loss: 0.9095 | Train Acc: 0.6210 | Val Loss: 1.0111 | Val Acc: 0.4971 | Best: 0.5086 @ 057
# Epoch [063/160] | Train Loss: 0.9110 | Train Acc: 0.6230 | Val Loss: 1.0084 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [064/160] | Train Loss: 0.9115 | Train Acc: 0.6130 | Val Loss: 1.0052 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [065/160] | Train Loss: 0.9050 | Train Acc: 0.6240 | Val Loss: 1.0100 | Val Acc: 0.4800 | Best: 0.5086 @ 057
# Epoch [066/160] | Train Loss: 0.9156 | Train Acc: 0.6010 | Val Loss: 1.0064 | Val Acc: 0.4886 | Best: 0.5086 @ 057
# Epoch [067/160] | Train Loss: 0.9098 | Train Acc: 0.6080 | Val Loss: 1.0086 | Val Acc: 0.4914 | Best: 0.5086 @ 057
# Epoch [068/160] | Train Loss: 0.9104 | Train Acc: 0.6250 | Val Loss: 1.0054 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [069/160] | Train Loss: 0.9090 | Train Acc: 0.6190 | Val Loss: 1.0109 | Val Acc: 0.5000 | Best: 0.5086 @ 057
# Epoch [070/160] | Train Loss: 0.9109 | Train Acc: 0.6030 | Val Loss: 1.0059 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [071/160] | Train Loss: 0.9072 | Train Acc: 0.6240 | Val Loss: 1.0129 | Val Acc: 0.4800 | Best: 0.5086 @ 057
# Epoch [072/160] | Train Loss: 0.9034 | Train Acc: 0.6220 | Val Loss: 1.0050 | Val Acc: 0.5057 | Best: 0.5086 @ 057
# Epoch [073/160] | Train Loss: 0.9110 | Train Acc: 0.6170 | Val Loss: 1.0081 | Val Acc: 0.4886 | Best: 0.5086 @ 057
# Epoch [074/160] | Train Loss: 0.9046 | Train Acc: 0.6280 | Val Loss: 1.0066 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [075/160] | Train Loss: 0.9154 | Train Acc: 0.6100 | Val Loss: 1.0048 | Val Acc: 0.4886 | Best: 0.5086 @ 057
# Epoch [076/160] | Train Loss: 0.9030 | Train Acc: 0.6160 | Val Loss: 1.0071 | Val Acc: 0.4914 | Best: 0.5086 @ 057
# Epoch [077/160] | Train Loss: 0.9044 | Train Acc: 0.6230 | Val Loss: 1.0049 | Val Acc: 0.4914 | Best: 0.5086 @ 057
# Epoch [078/160] | Train Loss: 0.9061 | Train Acc: 0.6190 | Val Loss: 1.0099 | Val Acc: 0.4857 | Best: 0.5086 @ 057
# Epoch [079/160] | Train Loss: 0.9066 | Train Acc: 0.6190 | Val Loss: 1.0044 | Val Acc: 0.4943 | Best: 0.5086 @ 057
# Epoch [080/160] | Train Loss: 0.9016 | Train Acc: 0.6190 | Val Loss: 1.0059 | Val Acc: 0.5171 | Best: 0.5171 @ 080
# Epoch [081/160] | Train Loss: 0.9052 | Train Acc: 0.6180 | Val Loss: 1.0085 | Val Acc: 0.4829 | Best: 0.5171 @ 080
# Epoch [082/160] | Train Loss: 0.9018 | Train Acc: 0.6340 | Val Loss: 1.0079 | Val Acc: 0.4857 | Best: 0.5171 @ 080
# Epoch [083/160] | Train Loss: 0.9046 | Train Acc: 0.6260 | Val Loss: 1.0078 | Val Acc: 0.4886 | Best: 0.5171 @ 080
# Epoch [084/160] | Train Loss: 0.8999 | Train Acc: 0.6330 | Val Loss: 1.0099 | Val Acc: 0.4971 | Best: 0.5171 @ 080
# Epoch [085/160] | Train Loss: 0.9078 | Train Acc: 0.6190 | Val Loss: 1.0122 | Val Acc: 0.4771 | Best: 0.5171 @ 080
# Epoch [086/160] | Train Loss: 0.9105 | Train Acc: 0.6060 | Val Loss: 1.0094 | Val Acc: 0.4800 | Best: 0.5171 @ 080
# Epoch [087/160] | Train Loss: 0.9064 | Train Acc: 0.6270 | Val Loss: 1.0075 | Val Acc: 0.4857 | Best: 0.5171 @ 080
# Epoch [088/160] | Train Loss: 0.9100 | Train Acc: 0.6110 | Val Loss: 1.0037 | Val Acc: 0.5057 | Best: 0.5171 @ 080
# Epoch [089/160] | Train Loss: 0.9001 | Train Acc: 0.6390 | Val Loss: 1.0049 | Val Acc: 0.4886 | Best: 0.5171 @ 080
# Epoch [090/160] | Train Loss: 0.9014 | Train Acc: 0.6300 | Val Loss: 1.0071 | Val Acc: 0.4971 | Best: 0.5171 @ 080
# Epoch [091/160] | Train Loss: 0.9014 | Train Acc: 0.6250 | Val Loss: 1.0036 | Val Acc: 0.4943 | Best: 0.5171 @ 080
# Epoch [092/160] | Train Loss: 0.8999 | Train Acc: 0.6150 | Val Loss: 1.0052 | Val Acc: 0.4914 | Best: 0.5171 @ 080
# Epoch [093/160] | Train Loss: 0.9046 | Train Acc: 0.6250 | Val Loss: 1.0043 | Val Acc: 0.4943 | Best: 0.5171 @ 080
# Epoch [094/160] | Train Loss: 0.8986 | Train Acc: 0.6290 | Val Loss: 1.0039 | Val Acc: 0.5086 | Best: 0.5171 @ 080
# Epoch [095/160] | Train Loss: 0.9048 | Train Acc: 0.6280 | Val Loss: 1.0046 | Val Acc: 0.4943 | Best: 0.5171 @ 080
# Epoch [096/160] | Train Loss: 0.8955 | Train Acc: 0.6290 | Val Loss: 1.0032 | Val Acc: 0.4914 | Best: 0.5171 @ 080
# Epoch [097/160] | Train Loss: 0.9013 | Train Acc: 0.6140 | Val Loss: 1.0019 | Val Acc: 0.5000 | Best: 0.5171 @ 080
# Epoch [098/160] | Train Loss: 0.9112 | Train Acc: 0.6230 | Val Loss: 1.0052 | Val Acc: 0.4800 | Best: 0.5171 @ 080
# Epoch [099/160] | Train Loss: 0.9057 | Train Acc: 0.6100 | Val Loss: 1.0065 | Val Acc: 0.4886 | Best: 0.5171 @ 080
# ...
# Epoch [018/160] | Train Loss: 0.5942 | Train Acc: 0.8720 | Val Loss: 1.0956 | Val Acc: 0.4314 | Best: 0.4686 @ 012
# Epoch [019/160] | Train Loss: 0.5789 | Train Acc: 0.8850 | Val Loss: 1.0861 | Val Acc: 0.4457 | Best: 0.4686 @ 012
# Epoch [020/160] | Train Loss: 0.5529 | Train Acc: 0.9150 | Val Loss: 1.0770 | Val Acc: 0.4257 | Best: 0.4686 @ 012
# Epoch [021/160] | Train Loss: 0.5502 | Train Acc: 0.9100 | Val Loss: 1.0778 | Val Acc: 0.4543 | Best: 0.4686 @ 012
# Epoch [022/160] | Train Loss: 0.5450 | Train Acc: 0.9150 | Val Loss: 1.0788 | Val Acc: 0.4286 | Best: 0.4686 @ 012
# Epoch [023/160] | Train Loss: 0.5308 | Train Acc: 0.9130 | Val Loss: 1.0890 | Val Acc: 0.4286 | Best: 0.4686 @ 012
# Epoch [024/160] | Train Loss: 0.5268 | Train Acc: 0.9220 | Val Loss: 1.0755 | Val Acc: 0.4371 | Best: 0.4686 @ 012
# Epoch [025/160] | Train Loss: 0.5212 | Train Acc: 0.9220 | Val Loss: 1.0820 | Val Acc: 0.4229 | Best: 0.4686 @ 012
# Epoch [026/160] | Train Loss: 0.5147 | Train Acc: 0.9270 | Val Loss: 1.0750 | Val Acc: 0.4343 | Best: 0.4686 @ 012
# Epoch [027/160] | Train Loss: 0.4990 | Train Acc: 0.9350 | Val Loss: 1.0819 | Val Acc: 0.4200 | Best: 0.4686 @ 012
# Epoch [028/160] | Train Loss: 0.5033 | Train Acc: 0.9250 | Val Loss: 1.0706 | Val Acc: 0.4371 | Best: 0.4686 @ 012
# Epoch [029/160] | Train Loss: 0.4992 | Train Acc: 0.9410 | Val Loss: 1.0749 | Val Acc: 0.4343 | Best: 0.4686 @ 012
# Epoch [030/160] | Train Loss: 0.4894 | Train Acc: 0.9420 | Val Loss: 1.0808 | Val Acc: 0.4257 | Best: 0.4686 @ 012
# Epoch [031/160] | Train Loss: 0.4908 | Train Acc: 0.9420 | Val Loss: 1.0835 | Val Acc: 0.4200 | Best: 0.4686 @ 012
# Epoch [032/160] | Train Loss: 0.4954 | Train Acc: 0.9360 | Val Loss: 1.0725 | Val Acc: 0.4343 | Best: 0.4686 @ 012
# Epoch [033/160] | Train Loss: 0.4861 | Train Acc: 0.9440 | Val Loss: 1.0792 | Val Acc: 0.4314 | Best: 0.4686 @ 012
# Epoch [034/160] | Train Loss: 0.4757 | Train Acc: 0.9420 | Val Loss: 1.0855 | Val Acc: 0.4400 | Best: 0.4686 @ 012
# Epoch [035/160] | Train Loss: 0.4750 | Train Acc: 0.9530 | Val Loss: 1.0826 | Val Acc: 0.4343 | Best: 0.4686 @ 012
# Epoch [036/160] | Train Loss: 0.4736 | Train Acc: 0.9400 | Val Loss: 1.0862 | Val Acc: 0.4171 | Best: 0.4686 @ 012
# Early stopping at epoch 36; best epoch was 12.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_uncertainty_h64_t18.txt
# Uncertainty Router h64 t18 Best Val Accuracy: 0.4686 (epoch 12)
# Uncertainty Router h64 t18 Recomputed Train Accuracy: 0.8710
# Uncertainty Router h64 t18 Recomputed Val Accuracy: 0.4686
#
# ============================================================
# Training Uncertainty Router h96 t15
# Epoch [001/160] | Train Loss: 1.1009 | Train Acc: 0.3570 | Val Loss: 1.1041 | Val Acc: 0.4143 | Best: 0.4143 @ 001
# Epoch [002/160] | Train Loss: 1.0553 | Train Acc: 0.4360 | Val Loss: 1.0809 | Val Acc: 0.4200 | Best: 0.4200 @ 002
# Epoch [003/160] | Train Loss: 0.9855 | Train Acc: 0.5520 | Val Loss: 1.0867 | Val Acc: 0.4314 | Best: 0.4314 @ 003
# Epoch [004/160] | Train Loss: 0.9166 | Train Acc: 0.6410 | Val Loss: 1.0768 | Val Acc: 0.4371 | Best: 0.4371 @ 004
# Epoch [005/160] | Train Loss: 0.8611 | Train Acc: 0.6920 | Val Loss: 1.1226 | Val Acc: 0.3457 | Best: 0.4371 @ 004
# Epoch [006/160] | Train Loss: 0.8347 | Train Acc: 0.7090 | Val Loss: 1.0717 | Val Acc: 0.3914 | Best: 0.4371 @ 004
# Epoch [007/160] | Train Loss: 0.7885 | Train Acc: 0.7720 | Val Loss: 1.1047 | Val Acc: 0.4314 | Best: 0.4371 @ 004
# Epoch [008/160] | Train Loss: 0.7670 | Train Acc: 0.7670 | Val Loss: 1.0770 | Val Acc: 0.4286 | Best: 0.4371 @ 004
# Epoch [009/160] | Train Loss: 0.7402 | Train Acc: 0.8190 | Val Loss: 1.0883 | Val Acc: 0.4229 | Best: 0.4371 @ 004
# Epoch [010/160] | Train Loss: 0.7163 | Train Acc: 0.8300 | Val Loss: 1.0830 | Val Acc: 0.4171 | Best: 0.4371 @ 004
# Epoch [011/160] | Train Loss: 0.6978 | Train Acc: 0.8330 | Val Loss: 1.0942 | Val Acc: 0.4114 | Best: 0.4371 @ 004
# Epoch [012/160] | Train Loss: 0.6699 | Train Acc: 0.8560 | Val Loss: 1.1061 | Val Acc: 0.4229 | Best: 0.4371 @ 004
# Epoch [013/160] | Train Loss: 0.6381 | Train Acc: 0.8850 | Val Loss: 1.0966 | Val Acc: 0.4086 | Best: 0.4371 @ 004
# Epoch [014/160] | Train Loss: 0.6250 | Train Acc: 0.9030 | Val Loss: 1.0835 | Val Acc: 0.4171 | Best: 0.4371 @ 004
# Epoch [015/160] | Train Loss: 0.6130 | Train Acc: 0.9150 | Val Loss: 1.0876 | Val Acc: 0.4286 | Best: 0.4371 @ 004
# Epoch [016/160] | Train Loss: 0.6004 | Train Acc: 0.9150 | Val Loss: 1.0838 | Val Acc: 0.4000 | Best: 0.4371 @ 004
# Epoch [017/160] | Train Loss: 0.5954 | Train Acc: 0.9250 | Val Loss: 1.0890 | Val Acc: 0.4343 | Best: 0.4371 @ 004
# Epoch [018/160] | Train Loss: 0.5886 | Train Acc: 0.9150 | Val Loss: 1.0832 | Val Acc: 0.4114 | Best: 0.4371 @ 004
# Epoch [019/160] | Train Loss: 0.5739 | Train Acc: 0.9350 | Val Loss: 1.1074 | Val Acc: 0.4286 | Best: 0.4371 @ 004
# Epoch [020/160] | Train Loss: 0.5623 | Train Acc: 0.9400 | Val Loss: 1.0961 | Val Acc: 0.4343 | Best: 0.4371 @ 004
# Epoch [021/160] | Train Loss: 0.5458 | Train Acc: 0.9610 | Val Loss: 1.0886 | Val Acc: 0.4171 | Best: 0.4371 @ 004
# Epoch [022/160] | Train Loss: 0.5424 | Train Acc: 0.9490 | Val Loss: 1.0937 | Val Acc: 0.4000 | Best: 0.4371 @ 004
# Epoch [023/160] | Train Loss: 0.5344 | Train Acc: 0.9570 | Val Loss: 1.0897 | Val Acc: 0.4114 | Best: 0.4371 @ 004
# Epoch [024/160] | Train Loss: 0.5285 | Train Acc: 0.9640 | Val Loss: 1.1033 | Val Acc: 0.4171 | Best: 0.4371 @ 004
# Epoch [025/160] | Train Loss: 0.5271 | Train Acc: 0.9620 | Val Loss: 1.0947 | Val Acc: 0.4200 | Best: 0.4371 @ 004
# Epoch [026/160] | Train Loss: 0.5213 | Train Acc: 0.9650 | Val Loss: 1.1013 | Val Acc: 0.4229 | Best: 0.4371 @ 004
# Epoch [027/160] | Train Loss: 0.5205 | Train Acc: 0.9520 | Val Loss: 1.0893 | Val Acc: 0.4200 | Best: 0.4371 @ 004
# Epoch [028/160] | Train Loss: 0.5130 | Train Acc: 0.9690 | Val Loss: 1.0956 | Val Acc: 0.4371 | Best: 0.4371 @ 004
# Early stopping at epoch 28; best epoch was 4.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_uncertainty_h96_t15.txt
# Uncertainty Router h96 t15 Best Val Accuracy: 0.4371 (epoch 4)
# Uncertainty Router h96 t15 Recomputed Train Accuracy: 0.7040
# Uncertainty Router h96 t15 Recomputed Val Accuracy: 0.4371
#
# ============================================================
# Training Uncertainty Router h64 t22
# Epoch [001/160] | Train Loss: 1.1075 | Train Acc: 0.3580 | Val Loss: 1.0821 | Val Acc: 0.3886 | Best: 0.3886 @ 001
# Epoch [002/160] | Train Loss: 1.0524 | Train Acc: 0.4610 | Val Loss: 1.0567 | Val Acc: 0.4371 | Best: 0.4371 @ 002
# Epoch [003/160] | Train Loss: 0.9902 | Train Acc: 0.5220 | Val Loss: 1.0676 | Val Acc: 0.4286 | Best: 0.4371 @ 002
# Epoch [004/160] | Train Loss: 0.9075 | Train Acc: 0.6120 | Val Loss: 1.0481 | Val Acc: 0.4600 | Best: 0.4600 @ 004
# Epoch [005/160] | Train Loss: 0.8537 | Train Acc: 0.6690 | Val Loss: 1.0587 | Val Acc: 0.4429 | Best: 0.4600 @ 004
# Epoch [006/160] | Train Loss: 0.8064 | Train Acc: 0.6930 | Val Loss: 1.0411 | Val Acc: 0.4543 | Best: 0.4600 @ 004
# Epoch [007/160] | Train Loss: 0.7746 | Train Acc: 0.7250 | Val Loss: 1.0715 | Val Acc: 0.4343 | Best: 0.4600 @ 004
# Epoch [008/160] | Train Loss: 0.7374 | Train Acc: 0.7620 | Val Loss: 1.0530 | Val Acc: 0.4400 | Best: 0.4600 @ 004
# Epoch [009/160] | Train Loss: 0.7102 | Train Acc: 0.7730 | Val Loss: 1.0649 | Val Acc: 0.4571 | Best: 0.4600 @ 004
# Epoch [010/160] | Train Loss: 0.7000 | Train Acc: 0.7850 | Val Loss: 1.0821 | Val Acc: 0.3971 | Best: 0.4600 @ 004
# Epoch [011/160] | Train Loss: 0.6705 | Train Acc: 0.8090 | Val Loss: 1.0570 | Val Acc: 0.4343 | Best: 0.4600 @ 004
# Epoch [012/160] | Train Loss: 0.6264 | Train Acc: 0.8380 | Val Loss: 1.0558 | Val Acc: 0.4457 | Best: 0.4600 @ 004
# Epoch [013/160] | Train Loss: 0.6042 | Train Acc: 0.8540 | Val Loss: 1.0486 | Val Acc: 0.4086 | Best: 0.4600 @ 004
# Epoch [014/160] | Train Loss: 0.5842 | Train Acc: 0.8750 | Val Loss: 1.0685 | Val Acc: 0.4143 | Best: 0.4600 @ 004
# Epoch [015/160] | Train Loss: 0.5843 | Train Acc: 0.8640 | Val Loss: 1.0620 | Val Acc: 0.4429 | Best: 0.4600 @ 004
# Epoch [016/160] | Train Loss: 0.5504 | Train Acc: 0.8790 | Val Loss: 1.0507 | Val Acc: 0.4514 | Best: 0.4600 @ 004
# Epoch [017/160] | Train Loss: 0.5396 | Train Acc: 0.8870 | Val Loss: 1.0862 | Val Acc: 0.4371 | Best: 0.4600 @ 004
# Epoch [018/160] | Train Loss: 0.5260 | Train Acc: 0.8910 | Val Loss: 1.0856 | Val Acc: 0.4543 | Best: 0.4600 @ 004
# Epoch [019/160] | Train Loss: 0.5068 | Train Acc: 0.9010 | Val Loss: 1.0756 | Val Acc: 0.4286 | Best: 0.4600 @ 004
# Epoch [020/160] | Train Loss: 0.4992 | Train Acc: 0.9060 | Val Loss: 1.0692 | Val Acc: 0.4400 | Best: 0.4600 @ 004
# Epoch [021/160] | Train Loss: 0.4843 | Train Acc: 0.9140 | Val Loss: 1.0760 | Val Acc: 0.4343 | Best: 0.4600 @ 004
# Epoch [022/160] | Train Loss: 0.4841 | Train Acc: 0.9150 | Val Loss: 1.0712 | Val Acc: 0.4343 | Best: 0.4600 @ 004
# Epoch [023/160] | Train Loss: 0.4702 | Train Acc: 0.9150 | Val Loss: 1.0943 | Val Acc: 0.4314 | Best: 0.4600 @ 004
# Epoch [024/160] | Train Loss: 0.4698 | Train Acc: 0.9200 | Val Loss: 1.0774 | Val Acc: 0.4257 | Best: 0.4600 @ 004
# Epoch [025/160] | Train Loss: 0.4606 | Train Acc: 0.9330 | Val Loss: 1.0833 | Val Acc: 0.4429 | Best: 0.4600 @ 004
# Epoch [026/160] | Train Loss: 0.4492 | Train Acc: 0.9350 | Val Loss: 1.0824 | Val Acc: 0.4400 | Best: 0.4600 @ 004
# Epoch [027/160] | Train Loss: 0.4497 | Train Acc: 0.9280 | Val Loss: 1.0911 | Val Acc: 0.4229 | Best: 0.4600 @ 004
# Epoch [028/160] | Train Loss: 0.4435 | Train Acc: 0.9350 | Val Loss: 1.0878 | Val Acc: 0.4114 | Best: 0.4600 @ 004
# Early stopping at epoch 28; best epoch was 4.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_uncertainty_h64_t22.txt
# Uncertainty Router h64 t22 Best Val Accuracy: 0.4600 (epoch 4)
# Uncertainty Router h64 t22 Recomputed Train Accuracy: 0.6830
# Uncertainty Router h64 t22 Recomputed Val Accuracy: 0.4600
#
# ============================================================
# Training Hybrid Router h96 dp40
# Epoch [001/160] | Train Loss: 1.1100 | Train Acc: 0.3420 | Val Loss: 1.0893 | Val Acc: 0.4257 | Best: 0.4257 @ 001
# Epoch [002/160] | Train Loss: 1.0536 | Train Acc: 0.4770 | Val Loss: 1.0906 | Val Acc: 0.3857 | Best: 0.4257 @ 001
# Epoch [003/160] | Train Loss: 0.9890 | Train Acc: 0.5430 | Val Loss: 1.1293 | Val Acc: 0.3457 | Best: 0.4257 @ 001
# Epoch [004/160] | Train Loss: 0.9268 | Train Acc: 0.5990 | Val Loss: 1.1474 | Val Acc: 0.3657 | Best: 0.4257 @ 001
# Epoch [005/160] | Train Loss: 0.8773 | Train Acc: 0.6660 | Val Loss: 1.1308 | Val Acc: 0.3943 | Best: 0.4257 @ 001
# Epoch [006/160] | Train Loss: 0.8316 | Train Acc: 0.7130 | Val Loss: 1.1282 | Val Acc: 0.3543 | Best: 0.4257 @ 001
# Epoch [007/160] | Train Loss: 0.7915 | Train Acc: 0.7680 | Val Loss: 1.1284 | Val Acc: 0.3343 | Best: 0.4257 @ 001
# Epoch [008/160] | Train Loss: 0.7691 | Train Acc: 0.7550 | Val Loss: 1.1412 | Val Acc: 0.3600 | Best: 0.4257 @ 001
# Epoch [009/160] | Train Loss: 0.7328 | Train Acc: 0.8010 | Val Loss: 1.1480 | Val Acc: 0.3600 | Best: 0.4257 @ 001
# Epoch [010/160] | Train Loss: 0.6962 | Train Acc: 0.8420 | Val Loss: 1.1165 | Val Acc: 0.4200 | Best: 0.4257 @ 001
# Epoch [011/160] | Train Loss: 0.6771 | Train Acc: 0.8720 | Val Loss: 1.1250 | Val Acc: 0.4286 | Best: 0.4286 @ 011
# Epoch [012/160] | Train Loss: 0.6611 | Train Acc: 0.8620 | Val Loss: 1.1217 | Val Acc: 0.4143 | Best: 0.4286 @ 011
# Epoch [013/160] | Train Loss: 0.6506 | Train Acc: 0.8890 | Val Loss: 1.1303 | Val Acc: 0.4114 | Best: 0.4286 @ 011
# Epoch [014/160] | Train Loss: 0.6475 | Train Acc: 0.8760 | Val Loss: 1.1198 | Val Acc: 0.4086 | Best: 0.4286 @ 011
# Epoch [015/160] | Train Loss: 0.6250 | Train Acc: 0.9150 | Val Loss: 1.1274 | Val Acc: 0.4314 | Best: 0.4314 @ 015
# Epoch [016/160] | Train Loss: 0.6134 | Train Acc: 0.9100 | Val Loss: 1.1215 | Val Acc: 0.4171 | Best: 0.4314 @ 015
# Epoch [017/160] | Train Loss: 0.6011 | Train Acc: 0.9180 | Val Loss: 1.1266 | Val Acc: 0.4143 | Best: 0.4314 @ 015
# Epoch [018/160] | Train Loss: 0.5952 | Train Acc: 0.9120 | Val Loss: 1.1446 | Val Acc: 0.4257 | Best: 0.4314 @ 015
# Epoch [019/160] | Train Loss: 0.5880 | Train Acc: 0.9060 | Val Loss: 1.1504 | Val Acc: 0.4543 | Best: 0.4543 @ 019
# Epoch [020/160] | Train Loss: 0.5676 | Train Acc: 0.9300 | Val Loss: 1.1179 | Val Acc: 0.4343 | Best: 0.4543 @ 019
# Epoch [021/160] | Train Loss: 0.5580 | Train Acc: 0.9450 | Val Loss: 1.1229 | Val Acc: 0.4400 | Best: 0.4543 @ 019
# Epoch [022/160] | Train Loss: 0.5513 | Train Acc: 0.9380 | Val Loss: 1.1209 | Val Acc: 0.4429 | Best: 0.4543 @ 019
# Epoch [023/160] | Train Loss: 0.5392 | Train Acc: 0.9440 | Val Loss: 1.1313 | Val Acc: 0.4486 | Best: 0.4543 @ 019
# Epoch [024/160] | Train Loss: 0.5369 | Train Acc: 0.9420 | Val Loss: 1.1332 | Val Acc: 0.4343 | Best: 0.4543 @ 019
# Epoch [025/160] | Train Loss: 0.5213 | Train Acc: 0.9560 | Val Loss: 1.1372 | Val Acc: 0.4314 | Best: 0.4543 @ 019
# Epoch [026/160] | Train Loss: 0.5100 | Train Acc: 0.9570 | Val Loss: 1.1456 | Val Acc: 0.4714 | Best: 0.4714 @ 026
# Epoch [027/160] | Train Loss: 0.5039 | Train Acc: 0.9650 | Val Loss: 1.1474 | Val Acc: 0.4114 | Best: 0.4714 @ 026
# Epoch [028/160] | Train Loss: 0.4944 | Train Acc: 0.9630 | Val Loss: 1.1424 | Val Acc: 0.4286 | Best: 0.4714 @ 026
# Epoch [029/160] | Train Loss: 0.4864 | Train Acc: 0.9690 | Val Loss: 1.1416 | Val Acc: 0.4257 | Best: 0.4714 @ 026
# Epoch [030/160] | Train Loss: 0.4780 | Train Acc: 0.9700 | Val Loss: 1.1664 | Val Acc: 0.4143 | Best: 0.4714 @ 026
# Epoch [031/160] | Train Loss: 0.4758 | Train Acc: 0.9640 | Val Loss: 1.1725 | Val Acc: 0.4200 | Best: 0.4714 @ 026
# Epoch [032/160] | Train Loss: 0.4652 | Train Acc: 0.9710 | Val Loss: 1.1539 | Val Acc: 0.4343 | Best: 0.4714 @ 026
# Epoch [033/160] | Train Loss: 0.4575 | Train Acc: 0.9690 | Val Loss: 1.1752 | Val Acc: 0.4514 | Best: 0.4714 @ 026
# Epoch [034/160] | Train Loss: 0.4553 | Train Acc: 0.9610 | Val Loss: 1.1550 | Val Acc: 0.4571 | Best: 0.4714 @ 026
# Epoch [035/160] | Train Loss: 0.4402 | Train Acc: 0.9790 | Val Loss: 1.1437 | Val Acc: 0.4343 | Best: 0.4714 @ 026
# Epoch [036/160] | Train Loss: 0.4283 | Train Acc: 0.9820 | Val Loss: 1.1632 | Val Acc: 0.4286 | Best: 0.4714 @ 026
# Epoch [037/160] | Train Loss: 0.4271 | Train Acc: 0.9820 | Val Loss: 1.1614 | Val Acc: 0.4371 | Best: 0.4714 @ 026
# Epoch [038/160] | Train Loss: 0.4216 | Train Acc: 0.9830 | Val Loss: 1.1614 | Val Acc: 0.4400 | Best: 0.4714 @ 026
# Epoch [039/160] | Train Loss: 0.4185 | Train Acc: 0.9870 | Val Loss: 1.1697 | Val Acc: 0.4371 | Best: 0.4714 @ 026
# Epoch [040/160] | Train Loss: 0.4179 | Train Acc: 0.9830 | Val Loss: 1.1529 | Val Acc: 0.4257 | Best: 0.4714 @ 026
# Epoch [041/160] | Train Loss: 0.4132 | Train Acc: 0.9870 | Val Loss: 1.1656 | Val Acc: 0.4371 | Best: 0.4714 @ 026
# Epoch [042/160] | Train Loss: 0.4070 | Train Acc: 0.9870 | Val Loss: 1.1675 | Val Acc: 0.4314 | Best: 0.4714 @ 026
# Epoch [043/160] | Train Loss: 0.4051 | Train Acc: 0.9940 | Val Loss: 1.1715 | Val Acc: 0.4286 | Best: 0.4714 @ 026
# Epoch [044/160] | Train Loss: 0.4031 | Train Acc: 0.9840 | Val Loss: 1.1745 | Val Acc: 0.4343 | Best: 0.4714 @ 026
# Epoch [045/160] | Train Loss: 0.3984 | Train Acc: 0.9920 | Val Loss: 1.1689 | Val Acc: 0.4286 | Best: 0.4714 @ 026
# Epoch [046/160] | Train Loss: 0.3939 | Train Acc: 0.9890 | Val Loss: 1.1601 | Val Acc: 0.4286 | Best: 0.4714 @ 026
# Epoch [047/160] | Train Loss: 0.3944 | Train Acc: 0.9900 | Val Loss: 1.1665 | Val Acc: 0.4257 | Best: 0.4714 @ 026
# Epoch [048/160] | Train Loss: 0.3919 | Train Acc: 0.9890 | Val Loss: 1.1838 | Val Acc: 0.4257 | Best: 0.4714 @ 026
# Epoch [049/160] | Train Loss: 0.3915 | Train Acc: 0.9910 | Val Loss: 1.1689 | Val Acc: 0.4314 | Best: 0.4714 @ 026
# Epoch [050/160] | Train Loss: 0.3909 | Train Acc: 0.9930 | Val Loss: 1.1791 | Val Acc: 0.4314 | Best: 0.4714 @ 026
# Early stopping at epoch 50; best epoch was 26.
# Wrote checkpoint predictions to course_project/SEED/best_seed_simple_models_hybrid_h96_dp40.txt
# Hybrid Router h96 dp40 Best Val Accuracy: 0.4714 (epoch 26)
# Hybrid Router h96 dp40 Recomputed Train Accuracy: 0.9550
# Hybrid Router h96 dp40 Recomputed Val Accuracy: 0.4714

# %% [markdown]
# ## 7) Select final method and write SEED.txt
#
# Compare the best single model with validation-weighted soft voting. Write one integer label per test sample in `shuffle=False` order.

# %%
weights = np.array([max(result["val_acc"] - ENSEMBLE_MIN_VAL_ACC, 0.0) ** ENSEMBLE_WEIGHT_POWER for result in model_results], dtype=np.float64)
top_mask = np.ones(len(model_results), dtype=bool)
if TOP_K_ENSEMBLE is not None and TOP_K_ENSEMBLE > 0 and len(model_results) > TOP_K_ENSEMBLE:
    top_indices = np.argsort([result["val_acc"] for result in model_results])[-TOP_K_ENSEMBLE:]
    top_mask = np.zeros(len(model_results), dtype=bool)
    top_mask[top_indices] = True
    weights = np.where(top_mask, weights, 0.0)
if np.allclose(weights.sum(), 0.0):
    weights = top_mask.astype(np.float64) / max(top_mask.sum(), 1)
else:
    weights = weights / weights.sum()

weighted_val_prob = sum(weight * result["val_prob"] for weight, result in zip(weights, model_results))
weighted_test_prob = sum(weight * result["test_prob"] for weight, result in zip(weights, model_results))
ensemble_val_pred = np.argmax(weighted_val_prob, axis=1)
ensemble_test_pred = np.argmax(weighted_test_prob, axis=1)
ensemble_val_acc = accuracy(val_y, ensemble_val_pred)

best_single_idx = int(np.argmax([result["val_acc"] for result in model_results]))
best_single = model_results[best_single_idx]
best_single_val_acc = best_single["val_acc"]

print("\nModel validation summary")
for result, weight in zip(model_results, weights):
    print(f"{result['name']}: train_acc={result['train_acc']:.4f}, val_acc={result['val_acc']:.4f}, ensemble_weight={weight:.4f}")
print(f"Ensemble Val Accuracy: {ensemble_val_acc:.4f}")
print(f"Best Single Model: {best_single['name']} ({best_single_val_acc:.4f})")

if ensemble_val_acc >= best_single_val_acc:
    selected_method_name = "Validation-weighted soft voting ensemble"
    selected_val_acc = ensemble_val_acc
    selected_test_prob = weighted_test_prob
else:
    selected_method_name = best_single["name"]
    selected_val_acc = best_single_val_acc
    selected_test_prob = best_single["test_prob"]

selected_test_pred = np.argmax(selected_test_prob, axis=1)
all_test_labels = selected_test_pred.astype(int).tolist()
assert len(all_test_labels) == len(test_ds), f"Prediction count {len(all_test_labels)} != test sample count {len(test_ds)}"



output_path = f"course_project/{DATA_NAME}/{DATA_NAME}.txt"
write_labels(output_path, all_test_labels)
print(f"Final selected method: {selected_method_name} | Val Accuracy: {selected_val_acc:.4f}")
print(f"Wrote {len(all_test_labels)} predictions to {output_path}")
# Out:
# Model validation summary
# BandpowerDE + PCA + LogisticRegression: train_acc=0.6860, val_acc=0.4286, ensemble_weight=0.0000
# Covariance + LogisticRegression: train_acc=0.9900, val_acc=0.4800, ensemble_weight=0.0000
# Bandpower + SVC: train_acc=0.6820, val_acc=0.4057, ensemble_weight=0.0000
# Statistical + RandomForest: train_acc=1.0000, val_acc=0.4571, ensemble_weight=0.0000
# DMD Residual Rank Ensemble: train_acc=0.5500, val_acc=0.4229, ensemble_weight=0.0000
# Simple MoE: train_acc=0.7020, val_acc=0.5429, ensemble_weight=0.2554
# Simple MoE h64 dp30: train_acc=0.6890, val_acc=0.5486, ensemble_weight=0.2861
# Simple MoE h64 dp35: train_acc=0.8540, val_acc=0.5200, ensemble_weight=0.1527
# Simple MoE h80 dp35: train_acc=0.7320, val_acc=0.5229, ensemble_weight=0.1638
# Simple MoE h96 dp40: train_acc=0.6320, val_acc=0.5171, ensemble_weight=0.1420
# Hybrid Router h48 dp30: train_acc=0.9340, val_acc=0.4800, ensemble_weight=0.0000
# EEGGRU / BiGRU: train_acc=0.5500, val_acc=0.4743, ensemble_weight=0.0000
# EEGGRU h128 dp45: train_acc=0.4380, val_acc=0.4171, ensemble_weight=0.0000
# Uncertainty Router h64 t18: train_acc=0.8710, val_acc=0.4686, ensemble_weight=0.0000
# Uncertainty Router h96 t15: train_acc=0.7040, val_acc=0.4371, ensemble_weight=0.0000
# Uncertainty Router h64 t22: train_acc=0.6830, val_acc=0.4600, ensemble_weight=0.0000
# Hybrid Router h96 dp40: train_acc=0.9550, val_acc=0.4714, ensemble_weight=0.0000
# Ensemble Val Accuracy: 0.5314
# Best Single Model: Simple MoE h64 dp30 (0.5486)
# Final selected method: Simple MoE h64 dp30 | Val Accuracy: 0.5486
# Wrote 450 predictions to course_project/SEED/SEED.txt
